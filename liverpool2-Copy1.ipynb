# %%
import requests
#page = requests.get('https://www.premierleague.com/news/2015249')
page = requests.get('https://www.turboscores.com/match/691402/Liverpool-v-Arsenal')
#page = requests.get('https://www.liverpoolfc.com/team/first-team')
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n  <head>\r\n\t<title>&nbsp;Liverpool v Arsenal </title>\r\n\t<meta http-equiv="content-type" content="text/html; charset=utf-8" />\r\n\t<meta name="description" content="Get live football scores, results & fixtures from the Premier League plus latest football live scores from loads more competitions. All live footy here!"/>\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0"/>\r\n\t<meta name="apple-mobile-web-app-capable" content="yes" />\r\n\t<meta name="HandheldFriendly" content="true" />\r\n\t<meta name="propeller" content="9e96f7163a151535a64fbc39730be398" />\r\n\t<meta property="og:title" content="Liverpool v Arsenal" />\r\n\t<meta property="og:description" content="Football statistics and live scores." />\r\n\t<meta property="og:image" content="http://www.turboscores.com/images/fblogo.png" />\r\n\t<link rel="shortcut icon" href="/stats_cust/images/icon2.png"/>\r\n\t<link type="text/css" rel="stylesheet" href="
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title> Liverpool v Arsenal </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Get live football scores, results &amp; fixtures from the Premier League plus latest football live scores from loads more competitions. All live footy here!" name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="9e96f7163a151535a64fbc39730be398" name="propeller"/>
# <meta content="Liverpool v Arsenal" property="og:title"/>
# <meta content="Football statistics and live scores." property="og:description"/>
# <meta content="http://www.turboscores.com/images/fblogo.png" property="og:image"/>
# <link href="/stats_cust/images/icon2.png" rel="shortcut icon"/>
# ...

# %%
children = list(soup.children)
print(children)
# Out:
# ['\n', 'html', '\n', <html lang="en">
# <head>
# <title> Liverpool v Arsenal </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Get live football scores, results &amp; fixtures from the Premier League plus latest football live scores from loads more competitions. All live footy here!" name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="9e96f7163a151535a64fbc39730be398" name="propeller"/>
# <meta content="Liverpool v Arsenal" property="og:title"/>
# <meta content="Football statistics and live scores." property="og:description"/>
# <meta content="http://www.turboscores.com/images/fblogo.png" property="og:image"/>
# <link href="/stats_cust/images/icon2.png" rel="shortcut icon"/>
# ...

# %%
print([type(item) for item in list(soup.children)])
# Out:
# [<class 'bs4.element.NavigableString'>, <class 'bs4.element.Doctype'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Tag'>]

# %%
html = list(soup.children)[3]

# %%
html
# Out:
# <html lang="en">
# <head>
# <title> Liverpool v Arsenal </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="Get live football scores, results &amp; fixtures from the Premier League plus latest football live scores from loads more competitions. All live footy here!" name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="9e96f7163a151535a64fbc39730be398" name="propeller"/>
# <meta content="Liverpool v Arsenal" property="og:title"/>
# <meta content="Football statistics and live scores." property="og:description"/>
# <meta content="http://www.turboscores.com/images/fblogo.png" property="og:image"/>
# <link href="/stats_cust/images/icon2.png" rel="shortcut icon"/>
# <link href="https://fonts.googleapis.com/css?family=Droid+Sans:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title> Liverpool v Arsenal </title>
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#  <meta content="Get live football scores, results &amp; fixtures from the Premier League plus latest football live scores from loads more competitions. All live footy here!" name="description"/>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#  <meta content="yes" name="apple-mobile-web-app-capable"/>
#  <meta content="true" name="HandheldFriendly"/>
#  <meta content="9e96f7163a151535a64fbc39730be398" name="propeller"/>
#  <meta content="Liverpool v Arsenal" property="og:title"/>
#  <meta content="Football statistics and live scores." property="og:description"/>
#  <meta content="http://www.turboscores.com/images/fblogo.png" property="og:image"/>
#  <link href="/stats_cust/images/icon2.png" rel="shortcut icon"/>
#  <link href="https://fonts.googleapis.com/css?family=Droid+Sans:400,700" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.find('title').get_text())
# Out:
#  Liverpool v Arsenal

# %%
soup.find_all('div', id='s1')
# Out:
# [<div class="toggle_box" id="s1"><div class="toggle_content" id="events"><div class="me H" data-ord="77_228_1_47084576"><span class="me_time"> 77' </span><a class="me_plyr" data-shirt-name="Minamino" data-short-name="Minamino, T" href="/player/234810/228/4/Takumi-Minamino" onclick="return open_href('/player/234810/228/4/Takumi-Minamino',event)"><span>Takumi Minamino</span></a><span class="me_type"> <img alt="" src="/images/G.png"/></span></div><div class="me H" data-ord="73_228_1_47099803"><span class="me_time"> 73' </span><a class="me_plyr" data-shirt-name="Salah" data-short-name="Salah, M" href="/player/231544/228/4/Mohamed-Salah" onclick="return open_href('/player/231544/228/4/Mohamed-Salah',event)"><span>Mohamed Salah</span></a><span class="me_type"> <img alt="" src="/images/G.png"/></span></div><div class="me H" data-ord="70_228_4_47084370"><span class="me_time"> 70' </span><a class="me_plyr" data-shirt-name="Fabinho" data-short-name="Fabinho, F" href="/player/233206/228/4/Fabio
# ...

# %%
player = soup.find_all("div", {'id':'s1'})

# %%
for k in player:
     print(k.get_text(strip=True, separator=' '))
# Out:
# 77' Takumi Minamino 73' Mohamed Salah 70' Fabio Fabinho 52' Diogo Jota 44' Sadio Mané 39' Sadio Mané

# %%
for i in soup.find_all( 'h2'):
    print(soup.get_text())
# Out:
# Liverpool statistics, latest results and form 2021/2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LEAGUES
#
#
# MATCHES
#
#
# STATS
#
#
# BLOG
#
#
# FAV
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MEMBERS
#
#
#
#
#
# ARATAUBEBRCHCZDED2DKENE2E3E4E5ESE2FIFRF2GRKRNLITI2JPNOPLPTRUSCSETRUA
#
#
#
#
# Premier League
#
#
# ----------------------
#
# Dashboard
#
# ----------------------
#
# ENG - Premier League
# ITA - Serie A
# SPA - La Liga
# FRA - Ligue 1
# GER - Bundesliga
#
#
# Champions League
# Europa League
# Copa Libertadores
# Champions League (W)
#
#
# EURO 2020
# World Cup 2018
# WC Qualification Europe
# WC Qual. South-America
# Euro 2020 Qualification
# UEFA Nations League
#
# ----------------------
#
# See 'Search league' box
# Display all leagues
#
# ----------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Premier League
#
#
#
#
# 2021/22 ▼
#
# 2021/22
# 2020/21
# 2019/20
# 2018/19
# 2017/18
# 2016/17
# 2015/16
# 2014/15
# 2013/14
#
#
#
#
#
#
#
# ...

# %%
page = soup.find_all("div",{"class":"name"})
for j in page:
    item = j.find('span')
    text = item.get_text().strip()
    print(text)
# Out:
# Alisson
# Adrian
# Loris
# Caoimhin
# Marcelo
# Virgil
# Ibrahima
# Joe
# Kostas
# Andy
# Joel
# Nathaniel
# Trent
# Neco
# Fabinho
# Thiago
# James
# Naby
# Jordan
# Alex
# Curtis
# Roberto
# Sadio
# Mohamed
# Takumi
# Diogo
# Divock
# Harvey
# Ben
# Rhys
# Sheyi
# Ben
# Sepp

# %%
for pg in soup.find_all(class_="name"):
    print(pg.get_text(strip=True, separator=' '))
# Out:
# Alisson Becker
# Adrian
# Loris Karius
# Caoimhin Kelleher
# Marcelo Pitaluga
# Virgil van Dijk
# Ibrahima Konate
# Joe Gomez
# Kostas Tsimikas
# Andy Robertson
# Joel Matip
# Nathaniel Phillips
# Trent Alexander-Arnold
# Neco Williams
# Fabinho
# Thiago Alcantara
# James Milner
# Naby Keita
# Jordan Henderson
# Alex Oxlade-Chamberlain
# Curtis Jones
# Roberto Firmino
# Sadio Mane
# Mohamed Salah
# Takumi Minamino
# Diogo Jota
# Divock Origi
# Harvey Elliott
# Ben Davies
# Rhys Williams
# Sheyi Ojo
# Ben Woodburn
# Sepp van den Berg

# %%
df = []
page2 = soup.find_all("div", {"class":"postbody"})
for k in page2:
    item2 = k.find('blockquote', class_="postcontent restore")
    post = k.find('span', class_='date')
    post_text = post.get_text().strip()
    text2 = item2.get_text().strip()
    print(post_text)
    print(text2)
    df.append([post_text, text2])
# Out:
# 13-11-21,19:02
# Back in action one week today at Anfield for the visit of Mikel Artetas Arsenal side.
#
# 4th v 5th in the league, which seemed rather unlikely a few weeks ago.
#
# Harvey Elliott, Naby Keita, Roberto Firmino and James Milner are the only definite absentees at this moment. Question marks over Joe Gomez and Curtis Jones.
#
# Game is live on Sky Sports.
# 13-11-21,19:08
# Alisson
#
# Trent
# Matip
# Van Dijk
# Tsimikas
#
# Henderson
# Fabinho
# Thiago
#
# Salah
# Mane
# Jota
# 13-11-21,19:59
# Mane has broken ribs, or back, or sacroiliac doesnt he?
# 14-11-21,09:47
# Originally Posted by FIOS
#
#
# Mane has broken ribs, or back, or sacroiliac doesnt he?
#
#
# Swap Mane for the fan who wins a raffle an hour before kick off.
# 14-11-21,10:10
# So Hendo now has an injury. Jones, Milner, Keita all in doubt. Looks like Fab, Thiago and Ox for Arsenal.
# 14-11-21,10:32
# ...

# %%
import pandas as pd
df = pd.DataFrame(df)
df.columns = ['date','post']
df[['date', 'time']] = df['date'].str.split(',',expand=True)

# %%
df = df[['date', 'time', 'post']]
df.dtypes
# Out:
# date    object
# time    object
# post    object
# dtype: object

# %%
df['date']= pd.to_datetime(df['date'])
df['time']= pd.to_datetime(df['time'])
df['post']= df['post'].astype(str)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/nqp9stcn0mj7kkyqr_jt__4r0000gn/T/ipykernel_57292/770897825.py in <module>
# ----> 1 df
#       2
#
# NameError: name 'df' is not defined

# %%
df2 = df

# %%
df2['post'] = df2['post'].str.lstrip('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/nqp9stcn0mj7kkyqr_jt__4r0000gn/T/ipykernel_57292/836963292.py in <module>
# ----> 1 df2['post'] = df2['post'].str.lstrip('\n')
#
# NameError: name 'df2' is not defined
