# %%
import requests
page = requests.get('https://www.premierleague.com/news/2015249')
#page = requests.get('https://www.soccerstats.com/team.asp?league=england&stats=16-liverpool')
page = requests.get('https://www.liverpoolfc.com/team/first-team')
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie6 oldie"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie7 oldie"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie8 oldie"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html id="top" class="no-js"> <!--<![endif]-->\n<script>\n    (function(H){H.className=H.className.replace(/\\bno-js\\b/,\'js\')})(document.documentElement);\n\n    if (window.history.replaceState && window.location.href.slice(-1) === \'#\') {\n        window.history.replaceState({},document.title,window.location.href.slice(0,-1));\n    }\n</script>\n        <head >\n        <!-- OneTrust Cookies Consent Notice start for liverpoolfc.com -->\r\n<script type="text/javascript" src="https://cdn-ukwest.onetrust.com/consent/aa158886-777d-463e-8082-e384a26718f6/OtAutoBlock.js" ></script>\r\n<script src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js"  type="text/javascript" charset="UTF-8" data-domain-script="aa158886-777d-463e-8082-e384a26718f6" ></script>\r\n<script type="text/javascript">\r\nfunction OptanonWrapper() { }\r\n</script>\r\n<link rel="stylesheet" type="text/css" href="https://d3j2s6hdd6a7rg.cloudfront.net/css/cookie-consent-5.css" />\r\n<!-- OneTrust Cookies Consent Notice end for liverpoolfc.com -->\n\n                        <title>Liverpool FC - Team</title>\n        <meta name="keywords" content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" />\n<meta name="description" content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." />\n<meta name="robots" content="index, follow" />\n<meta property="og:site_name" content="Liverpool FC" />\n<meta property="og:description" content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." />\n<meta property="og:type" content="article" />\n<meta property="fb:pages" content="67920382572" />\n<meta property="og:title" content="Liverpool FC - Team" />\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta charset="UTF-8" />\n\n\n        <meta name="viewport" content="initial-scale=1.0, width=device-width" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n                          <link rel="shortcut icon" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/favicon.png" type="image/png" />\n                  \n\n        <link rel="stylesheet" href="https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css">\n\n                <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles.css" />\n        \n                <!--[if  (lt IE 9) & (!IEMobile)]>\n            <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles-ie8.css" />\n        <![endif]-->\n        \n                \n                <!--[if lt IE 9]>\n            <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie8.min.js"></script>\n        <![endif]-->\n        \n                <!--[if IE 9]>\n        <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie9.min.js"></script>\n        <![endif]-->\n        \n        \n    \n            ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie6 oldie"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie7 oldie"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie8 oldie"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" id="top"> <!--<![endif]-->
# <script>
#     (function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#
#     if (window.history.replaceState && window.location.href.slice(-1) === '#') {
#         window.history.replaceState({},document.title,window.location.href.slice(0,-1));
#     }
# </script>
# <head>
# <!-- OneTrust Cookies Consent Notice start for liverpoolfc.com -->
# <script src="https://cdn-ukwest.onetrust.com/consent/aa158886-777d-463e-8082-e384a26718f6/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-domain-script="aa158886-777d-463e-8082-e384a26718f6" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# function OptanonWrapper() { }
# </script>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/css/cookie-consent-5.css" rel="stylesheet" type="text/css"/>
# <!-- OneTrust Cookies Consent Notice end for liverpoolfc.com -->
# <title>Liverpool FC - Team</title>
# <meta content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" name="keywords"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Liverpool FC" property="og:site_name"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="67920382572" property="fb:pages"/>
# <meta content="Liverpool FC - Team" property="og:title"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/favicon.png" rel="shortcut icon" type="image/png"/>
# <link href="https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css" rel="stylesheet"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles.css" rel="stylesheet">
# <!--[if  (lt IE 9) & (!IEMobile)]>
#             <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles-ie8.css" />
#         <![endif]-->
# <!--[if lt IE 9]>
#             <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie8.min.js"></script>
#         <![endif]-->
# <!--[if IE 9]>
#         <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie9.min.js"></script>
#         <![endif]-->
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/base.js"></script>
# <link href="//cdn.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//st.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//rcom.dynamicyield.com" rel="dns-prefetch"/>
# <script>
#
# window.DY = window.DY || {};
# DY.recommendationContext = {type: 'OTHER'};
#
# </script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_dynamic.js" type="text/javascript"></script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_static.js" type="text/javascript"></script>
# <style type="text/css">
# a.post-next.post-next-top {
#    display:none;
# }
#
# div.post-next.post-next-bottom {
#    display:none;
# }
# </style>
# <script>
#  // create Lfc element with GPT command queue
#  var Lfc = Lfc || {};
#  Lfc.gtmAdQueue = Lfc.gtmAdQueue || [];
#
#  // Load GPT asynchronously
#  var googletag = googletag || {};
#  googletag.cmd = googletag.cmd || [];
#  (function() {
#    var gads = document.createElement('script');
#    gads.async = true;
#    var useSSL = 'https:' == document.location.protocol;
#    gads.src = (useSSL ? 'https:' : 'http:') +
#        '//www.googletagservices.com/tag/js/gpt.js';
#    var node = document.getElementsByTagName('script')[0];
#    node.parentNode.insertBefore(gads, node);
#  })();
# </script>
# <script>
# $( document ).ready(function() {
#
# $('.masthead .link-login a').attr('href', 'https://www.liverpoolfc.com/my-lfc/login?fragment=&referer='+(document.URL));
#
# // remove age restricted footer logos
# var checkString = window.location.href;
# if( checkString.indexOf("academy") !== -1 || checkString.indexOf("under-23") !== -1 || checkString.indexOf("under-18") !== -1 || checkString.indexOf("soccerschools") !== -1  || checkString.indexOf("soccer-schools") !== -1  || checkString.indexOf("u23") !== -1  || checkString.indexOf("u18") !== -1){
# $('a[title="Carlsberg"], a[title="Betvictor"], a[title="Liverpool Vodka"], a[title="Draft Kings"], a[title="1XBET"]').remove();
# }
#
# if( checkString.indexOf("/women/") !== -1 || checkString.indexOf("/news/women") !== -1 || checkString.indexOf("/team/women") !== -1 || checkString.indexOf("/fans/liverpool-fc-women") !== -1) {
#     $('a[title="Western Union"], a[title="Carlsberg"],a[title="MG"],a[title="Nivea"],a[title="Falken Tyres"],a[title="TigerWit"],a[title="EA Sports"],a[title="Chaokoh"],a[title="NH Foods"],a[title="Lavazza"],a[title="Petro-Canada"],a[title="Liverpool Vodka"],a[title="Levis"],a[title="iugis"],a[title="Mitel"],a[title="Verbier"],a[title="Tribus"],a[title="Cadbury UK"],a[title="Cadbury ROW"],a[title="Holly Frontier"],a[title="Quorn"],a[title="Mauritius"],a[title="Acronis"]').remove();
# }
#
# // remove link
# $('a[title="1XBET"]'). removeAttr("href");
#
# // HOT FIX - REMOVING MORE MENU FROM INTERNATIONAL SITES
# var urlHostName = window.location.hostname;
# if (urlHostName.indexOf('indonesia') !== -1 || urlHostName.indexOf('thailand') !== -1 || urlHostName.indexOf('japan') !== -1) {
# $('.main-menu ul.more-menu').hide();
# }
#
#           })
# </script>
# <style>
# .site-header-inner .masthead .masthead-links .more-menu ul li a {
#   background: none!important;
# }
# .site-header-inner .social-links li.skype {
#   display: none;
# }
# .vixlet, .dugout {
#    display:none !important;
# }
# .video-error__content {
# padding-top:3%!important;
# }
# .video-error__listing {
# margin:15px 0!important;
# }
#
# .video-error__subtitle-mobile,
# .video-error__registered {
# color:white!important;
# }
#
# .video-player-embeddable .video-error--embed .video-error__listing-group ul li {
# margin:0 0 5px 0!important;
# }
# .video-error__call-to-action a.js-subscribe-button {
# font-size:0.8em!important;
# background:white!important;
# text-transform:uppercase!important;
# }
# .video-error__call-to-action a.js-subscribe-button:hover {
# color:#e31b23!important;
# }
#
# @media only screen and (min-width: 551px) {
# .video-error__subtitle-mobile {
# margin:10px 0!important;
# padding:0!important;
# }
# }
#
# @media only screen and (min-width: 775px) and (max-width: 975px) {
# .video-error__listing-group {
# display:none!important;
# }
# }
#
# /*@media screen and (min-width: 700px) {
# .site-header-inner .main-menu .more-menu .more-menu-link>ul li {
# display:block !important;
# }
# }*/
#
# @media screen and (min-width: 1000px) {
# .site-header-inner .masthead .masthead-links .more-menu.noLogin ul {
# top: 100%!important;
# }
# }
#
# /* IE ONLY */
# @media screen\0 {
# .video-player-embeddable .video .shard-overlay {position: absolute !important;}
# }
#
# .home .featured-news-carousel .media-image-wrap .indent {text-indent: -99999px;}
#
# .dy_unit .dy-sliding-drawer-container{bottom: 25%;}
# </style>
# <script>
# var Lfc = Lfc || {};
#
# Lfc.messagesConfig = {
#     messages: [
#
#         // ANDROID APP BANNER
#         {
#             id: 'android-app-banner',
#             maximumDisplayCount: 1,
#             displayCondition: function() {
#                 // don't show on non-Android devices
#                 if (navigator.userAgent.match(/Android/i) === null || navigator.userAgent.indexOf('Windows') > -1) {
#                     return false;
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show if valid app id meta tag exists
#                 //  (e.g. <meta name="google-play-app" content="app-id=tv.liverpoolfc">)
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         return true;
#                     }
#                 }
#             },
#             content: function() {
#                 // get app id from meta tag
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         var linkUrl = 'https://play.google.com/store/apps/details?id=' + appId[1] +
#                                 '&referrer=utm_source%3DWebsite%26utm_medium%3DHEADER_APP_CARD_MAIN_SITE%26utm_content%3DDigital%26utm_campaign%3DClub%2520App';
#
#                         return '<div id="android-app-banner">' +
#                             '<a href="javascript:void(0);" class="close">&times;</a>' +
#                             '<a href="' + linkUrl + '">' +
#                                 '<span class="app-icon"></span>' +
#                                 '<div class="app-info">' +
#                                     '<strong>LFC Official App</strong>' +
#                                     '<span>Liverpool Football Club</span>' +
#                                     '<span>FREE in Google Play</span>' +
#                                 '</div>' +
#                                 '<span class="view">VIEW</span>' +
#                             '</a>' +
#                         '</div>';
#                     }
#                 }
#             },
#             style: "styled-header"
#         },
#
#         // REGISTRATION POP-UP
#         {
#             id : 'registration-popup',
#             minimumInterval : 10*24*60*60*1000, // 10 days = 10*24*60*60*1000
#             displayCondition: function() {
# // temp fix to not display
# return false;
#                 // don't show to logged in users
#                 if (Lfc.Login.isLoggedIn()) {
#                     Lfc.Cookie.set("registration-popup-logout-time", "logged in");
#                     return false;
#                 }
#                 // don't show immediately after logout -- wait 1 day
#                 var now = (new Date()).getTime(),
#                     logOutTime = Lfc.Cookie.get("registration-popup-logout-time");
#
#                 if (logOutTime == "logged in") {
#                     // immediately after logout, store timestamp
#                     Lfc.Cookie.set("registration-popup-logout-time", now);
#                     return false;
#                 } else {
#                     // if one day has not yet passed since first known logged out time, don't show
#                     if (logOutTime && (now - logOutTime < 24*60*60*1000)) { // 1 day = 24*60*60*1000
#                         return false;
#                     };
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show to "A" group people
#                 var abGroup = Lfc.Cookie.getABGroup("registration-popup");
#                 if (!abGroup) {
#                     abGroup = Lfc.Cookie.setABGroup("registration-popup");
#                     dataLayer.push({'event': 'registration-popup-ab-assignment', 'abGroup': abGroup });
#                 }
#                 return abGroup === "A";
#             },
#             onShow: function() {
#                 dataLayer.push({'event': 'registration-popup-shown'});
#             },
#             content : function() {
#                 if ($(window).width() < 1000) {
#                     // header message
#                     return regMessageHeaderMarkup + regMessageHeaderStyling;
#                 } else {
#                     // big popup with login
#                     return regMessagePopupMarkup + regMessagePopupStyling;
#                 }
#             },
#             style: function() {
#                 if ($(window).width() < 1000) {
#                     return 'default-header';
#                 } else {
#                     return 'popup';
#                 }
#             }
#         },
#     ],
#     minimumMessageInterval : 60*60*1000, // 1 hour = 60*60*1000
# }
#
#
# // REGISTRATION POPUP MARKUP & STYLING
# var regMessagePopupMarkup = '<div class="registration-popup-message"> <h1>GET MORE FROM LFC.</h1> <div id="not-logged-in-actions"> <h2>Register and get immediate access to:</h2> <fieldset class="reg-signup"> <div class="new-user-content"> <div class="signUpMessage registerText" style="line-height: 24px;"> <ul> <li class="image-bullet video">Free LFC videos</li> <li class="image-bullet match">Listen to live match commentary</li> <li class="image-bullet win">Exclusive competitions</li> <li class="image-bullet news">Receive the official club newsletter - All in Red</li> <li class="image-bullet forum">Join the conversation on the official LFC forums</li> <li class="image-bullet shirt">The Official Online Store</li> </ul> <p>...and it&rsquo;s completely <span>FREE!</span></p> </div> </div> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild"> <div class="buttonPlaceholder buttonPlaceholderPopUp"> <input type="button" value="Register" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </a> </fieldset> </div> <div id="LoginBox"> <h2>Login</h2> <div class="LoginFormBox"> <form id="WholesaleContact" title="Login" method="post" name="Login" action="/scripts/login.php?login=LfcTVLogin"> <fieldset> <div class="login-content"> <table class="lfcMembershipTable"> <tr class="LoginTableSpacing"> <th><label for="LoginUsernameId">Username</label></th> <td><input id="LoginUsernameId" class="InputLoginBox " type="text" name="username" /></td> <td class="formHelp">Email address</td> </tr> <tr class="LoginTableSpacing"> <th><label for="LoginPasswordId">Password</label></th> <td><input id="LoginPasswordId" class="InputLoginBox" type="password" name="password" /></td> <td class="formHelp"> <p><a href="/my-lfc/login/forgotten-password">Forgotten password?</a></p> </td> </tr> <tr class="remember LoginTableSpacing"> <th><label for="remember_me">Remember</label></th> <td style="vertical-align: middle;" class="rememberSideText formHelp" colspan="2"> <input type="checkbox" name="remember_me" class="remember_checkbox" /> <p class="rememberSideText formHelp">Remember your details on this machine?</p> </td> </tr> </table> </div> <div class="ArticleContent"> <div class="buttonPlaceholder"> <input type="submit" value="Login" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </div> <input type="hidden" name="referer" value="http://www.liverpoolfc.com/" /> </fieldset> </form> <script type="text/javascript"> $("#LoginUsernameId, #LoginPasswordId").on("keydown", function (evt) { if(evt.keyCode == 13) { $("#LoginForm").submit(); } }); <\/script> </div> </div></div>';
#
# var regMessagePopupStyling = '<style> /* header */ #cboxLoadedContent .registration-popup-message h1 { background: #E31B23; color: #FFF; padding: 0px 20px; line-height: 64px; font-size: 30px; } #colorbox #cboxClose { background: none; height: 58px; width: 50px; top: 3px!important; right: 3px; border: none; } #colorbox #cboxClose::after { content: "\\2716"; position: absolute; top: 0; left: 0; right: 0; line-height: 58px; text-align: center; font-size: 24px; text-indent: 0; color: #fff; } /* layout */ #cboxLoadedContent .registration-popup-message #not-logged-in-actions { width: 65%; padding: 20px; } #cboxLoadedContent .registration-popup-message #LoginBox { width: 35%; padding: 20px; } #cboxLoadedContent .registration-popup-message .login-content, #cboxLoadedContent .registration-popup-message .new-user-content { height: 250px; } #cboxLoadedContent .registration-popup-message h2 { border-bottom: 1px solid #DDD; margin: 0; padding: 2px 0 8px; } /* registration benefits */ #cboxLoadedContent .registration-popup-message .signUpMessage > p, #cboxLoadedContent .registration-popup-message .signUpMessage > ul { line-height: 36px; font-size: 16px; margin-bottom: 12px; } #cboxLoadedContent .registration-popup-message .signUpMessage > ul li.image-bullet { background-size: 24px; padding-left: 36px; } #cboxLoadedContent .registration-popup-message .signUpMessage > p { line-height: 36px; font-size: 16px; } /* login form */ #cboxLoadedContent .registration-popup-message #socialSignOn { margin: -10px 0 0; } #cboxLoadedContent .registration-popup-message .socialLogin { text-indent: -9999px; width: 40px; height: 40px; background-size: auto 40px; margin: 0 0 0 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable { clear: both; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th, #cboxLoadedContent .registration-popup-message .lfcMembershipTable td { float: left; width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable input { width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th { text-align: left; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable td.formHelp { text-align: right; padding: 5px 0; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember input { width: 19px; margin-right: 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember td { text-align: left; }<style>';
#
# var regMessageHeaderMarkup = '<div class="richtext"> <h1>GET MORE FROM LFC</h1> <p class="small-content">Register or log in now to access <strong>FREE</strong> benefits</p> <p class="medium-content">Log in now, or register to access a range of <strong>FREE</strong> benefits including videos and exclusive competitions.</p> <p class="buttons"> <a href="javascript:void(0);" class="main-button close">No thanks</a> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild" class="main-button">Yes, please!</a> </p></div>';
#
# var regMessageHeaderStyling = '<style> .header-message { background: #FFF; text-align: center; border-bottom: 2px solid #FFF; overflow: hidden; } .header-message::after { background: #C8C8C8; height: 6px; } .header-message > a.close { display: none; } .header-message .richtext a { text-decoration: none; } .header-message .buttons { margin: 10px 0; } .header-message .buttons a.main-button { margin: 0.2em 0.5em 0; padding: 0.8em 2em; } .header-message .buttons a.main-button.close { background: #FFF; color: #E31B23; border: 1px solid #E31B23; } .header-message p.medium-content { display: none; } @media screen and (min-width: 500px) { .header-message p.small-content { display: none; } .header-message p.medium-content { display: block; margin-bottom: 0; } .header-message .buttons { position: absolute; top: 0; right: 0; width: 11.5em; margin-bottom: 0; margin-right: 20px; } .header-message { min-height: 9em; } .header-message .richtext { margin-right: 14em; } .header-message .buttons a.main-button { display: block; margin: 0.6em 0; } }</style>';
#
# </script>
# <script type="text/javascript">
#
#  googletag.cmd.push(function() {
#
#   //general size mapping
#   var mapResMainRightOne = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
#   var mapResMainRightTwo = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# var mapResMainFixtures = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [468, 60]).
#    addSize([776, 0], [728, 90]).build();
# }
#
#
# 	 //general slots
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_ONE', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_ONE').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightOne).
# 				addService(googletag.pubads());
#
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_TWO', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_TWO').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightTwo).
# 				addService(googletag.pubads());
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# googletag.defineSlot('/87687331/RES_MAIN_FIXTURES', [320, 50], 'div-gpt-ad-RES_MAIN_FIXTURES').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainFixtures).
# 				addService(googletag.pubads());
# }
#
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().enableSingleRequest();
#   googletag.enableServices();
#  });
# </script>
# <style type="text/css">
# .facebookButton{
# display:none!important;
# }
# </style>
# </link></head>
# <body class="main-site-layout sonata-bc template-standard_two_column standard-two-column">
# <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KCFJMVP" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KCFJMVP');
#             </script>
# <!-- End Google Tag Manager -->
# <div class="wrapper">
# <a id="page-top"></a>
# <header class="site-header" id="site-header" role="banner">
# <div class="site-header-inner">
# <div class="masthead">
# <ul class="account-links logged-out-only">
# <li class="subnav">
# <a>Log In</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="link-separator"> </li>
# <li class="subnav">
# <a>Register</a>
# <ul>
# <li class="first"> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=free" target="">Free Registration</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/membership" target="">Join Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=lfctvo" target="">Join LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not Sure?</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="account-links logged-in-only">
# <li>
# <a class="link-logout" href="https://www.liverpoolfc.com/scripts/logout.php" title="Logout">Log out</a>
# </li>
# <li class="link-separator"> </li>
# <li>
# <a class="link-my-lfc" href="https://www.liverpoolfc.com/my-lfc" title="My LFC">My LFC</a>
# </li>
# </ul>
# <div class="masthead-links" id="masthead-links">
# <ul class="more-menu">
# <li class="more-menu-link">
# <a>More</a>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="logo">
# <a class="logo-large" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-medium" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-small" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo-small.png"/>
# </a></div>
# <a class="sponsor" href="//www.sc.com/en/" target="main-sponsor">
#     Main Club Sponsor: Standard Chartered
# </a>
# <div class="search">
# </div>
# <nav class="main-menu">
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="more-menu">
# <li class="more-menu-link">
# <a><span>More</span></a>
# <div class="icon-menu moreIconCss"></div>
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="my-account logged-out-only">
# <a href="https://www.liverpoolfc.com/my-lfc/login" title="Log in">LOG IN</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="my-account logged-in-only">
# <a href="https://www.liverpoolfc.com/my-lfc" title="My LFC">MY LFC</a>
# </li>
# </ul>
# </nav>
# <ul class="social-links">
# <li class="vixlet">
# <a href="http://lfc.onelink.me/684654549?pid=LFC&amp;c=SOCIALICON" target="_blank" title="Go to The Official Liverpool Football Club Xtra page"></a>
# </li>
# <li class="facebook">
# <a href="https://www.facebook.com/LiverpoolFC" target="_blank" title="Go to The Official Liverpool Football Club Facebook page"></a>
# </li>
# <li class="twitter">
# <a href="https://twitter.com/lfc" target="_blank" title="Go to The Official Liverpool Football Club Twitter page"></a>
# </li>
# <li class="dugout">
# ...
# </div>
# <div class="number">9</div>
# <div class="about">
# <div class="name">
# <span>Roberto</span> <span>Firmino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sadio-mane">
# <div class="img-wrap">
# <img alt="Sadio Mane" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125153_misc_general_500.jpeg"/>
# </div>
# <div class="number">10</div>
# <div class="about">
# <div class="name">
# <span>Sadio</span> <span>Mane</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/mohamed-salah">
# <div class="img-wrap">
# <img alt="Mohamed Salah" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125158_misc_general_500.jpeg"/>
# </div>
# <div class="number">11</div>
# <div class="about">
# <div class="name">
# <span>Mohamed</span> <span>Salah</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/takumi-minamino">
# <div class="img-wrap">
# <img alt="Takumi Minamino" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125154_misc_general_500.jpeg"/>
# </div>
# <div class="number">18</div>
# <div class="about">
# <div class="name">
# <span>Takumi</span> <span>Minamino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/diogo-jota">
# <div class="img-wrap">
# <img alt="Diogo Jota" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125136_misc_general_500.jpeg"/>
# </div>
# <div class="number">20</div>
# <div class="about">
# <div class="name">
# <span>Diogo</span> <span>Jota</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/divock-origi">
# <div class="img-wrap">
# <img alt="Divock Origi" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125137_misc_general_500.jpeg"/>
# </div>
# <div class="number">27</div>
# <div class="about">
# <div class="name">
# <span>Divock</span> <span>Origi</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/harvey-elliott">
# <div class="img-wrap">
# <img alt="Harvey Elliott" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125147_misc_general_500.jpeg"/>
# </div>
# <div class="number">67</div>
# <div class="about">
# <div class="name">
# <span>Harvey</span> <span>Elliott</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.fixtures.listing.block.player" id="cms-block-17819">
# <div class="team-player-list">
# <h2>ON LOAN</h2>
# <ul>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-davies">
# <div class="img-wrap">
# <img alt="Ben Davies" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125132_misc_general_500.jpeg"/>
# </div>
# <div class="number">28</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Davies</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/rhys-williams">
# <div class="img-wrap">
# <img alt="Rhys Williams" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125151_misc_general_500.jpeg"/>
# </div>
# <div class="number">46</div>
# <div class="about">
# <div class="name">
# <span>Rhys</span> <span>Williams</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sheyi-ojo">
# <div class="img-wrap">
# <img alt="Sheyi Ojo" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg"/>
# </div>
# <div class="number">54</div>
# <div class="about">
# <div class="name">
# <span>Sheyi</span> <span>Ojo</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-woodburn">
# <div class="img-wrap">
# <img alt="Ben Woodburn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125133_misc_general_500.jpeg"/>
# </div>
# <div class="number">58</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Woodburn</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sepp-van-den-berg">
# <div class="img-wrap">
# <img alt="Sepp van den Berg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/14/thumb_113613_misc_general_500.jpeg"/>
# </div>
# <div class="number">72</div>
# <div class="about">
# <div class="name">
# <span>Sepp</span> <span>van</span> <span>den</span> <span>Berg</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-3194">
# <div class="container-block block-3194">
# </div>
# </div>
# </div>
# </div>
# <div class="rightCol">
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_ONE">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_ONE');
# </script>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-2919">
# <div class="container-block block-2919">
# <div class="cms-block cms-block-element" data-block-type="sonata.block.service.text" id="cms-block-3332">
# <style type="text/css">
#
#     .richtext.linkList a {
#         display: block;
#         padding: 6px;
#         margin-bottom: 0;
#         overflow: hidden;
#         padding-right: 30px;
#         position: relative;
#         color: #333;
#         font-weight: normal;
#     }
#
#     .richtext.linkList a:nth-child(odd) {
#         background: #F6F6F6;
#     }
#
#     .richtext.linkList a:after {
#         border-bottom: 8px solid transparent;
#         border-left: 12px solid #E31B23;
#         border-top: 8px solid transparent;
#         content: "";
#         display: inline-block;
#         height: 0;
#         position: absolute;
#         width: 0;
#         right: 10px;
#         margin-top: -8px;
#         top: 50%;
#     }
#
# @media screen and (max-width: 699px){
# .mainColInner .richtext img {
# width: 100%!important;
# height: auto!important;
# float: left!important;
# margin-bottom: 30px!important;
# }
#
# </style>
# <div class="richtext linkList">
# <h2>First Team Staff</h2>
# <a href="/team/first-team/staff/jurgen-klopp">Jürgen Klopp</a>
# <a href="/team/first-team/staff/peter-krawietz">Peter Krawietz</a>
# <a href="/team/first-team/staff/pepijn-lijnders">Pepijn Lijnders</a>
# <a href="/team/first-team/staff/john-achterberg">John Achterberg</a>
# <a href="/team/first-team/staff/jack-robinson">Jack Robinson</a>
# <a href="/team/first-team/staff/claudio-taffarel">Claudio Taffarel</a>
# <a href="/team/first-team/staff/vitor-matos">Vitor Matos</a>
# <a href="/team/first-team/staff/andreas-kornmayer">Andreas Kornmayer</a>
# <a href="/team/first-team/staff/dr-andreas-schlumberger">Dr Andreas Schlumberger</a>
# <a href="/team/first-team/staff/dr-jim-moxon">Dr Jim Moxon</a>
# <a href="/team/first-team/staff/lee-nobes">Lee Nobes</a>
# <a href="/team/first-team/staff/conall-murtagh">Dr Conall Murtagh</a>
# <a href="/team/first-team/staff/jordan-fairclough">Jordan Fairclough</a>
# <a href="/team/first-team/staff/paul-small">Paul Small </a>
# <a href="/team/first-team/staff/lee-radcliffe">Lee Radcliffe</a>
# <a href="/team/first-team/staff/brendan-mcilduff">Brendan McIlduff</a>
# <a href="/team/first-team/staff/david-rydings">Dr David Rydings</a>
# <a href="/team/first-team/staff/mona-nemmer">Mona Nemmer</a>
# <a href="/team/first-team/staff/mark-leyland">Mark Leyland</a>
# <a href="/team/first-team/staff/daniel-spearritt">Daniel Spearritt</a>
# <a href="/team/first-team/staff/greg-mathieson">Greg Mathieson</a>
# <a href="/team/first-team/staff/james-french">James French</a>
# <a href="/team/first-team/staff/chris-morgan">Chris Morgan</a>
# <a href="/team/first-team/staff/steve-lilley">Steve Lilley</a>
# <a href="/team/first-team/staff/joe-lewis">Joe Lewis</a>
# <a href="/team/first-team/staff/michelle-hudson">Michelle Hudson</a>
# <a href="/team/first-team/staff/motonori-watanabe">Motonori Watanabe</a>
# <a href="/team/first-team/staff/lena-aschenbrenner">Lena Aschenbrenner</a>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.opta.standings.block.service" id="cms-block-3333">
# <section class="opta-wrapper" id="league-table">
# <opta-widget breakpoints="550" competition="8" competition_naming="full" data_detail="full" date_format="dddd D MMMM YYYY" default_nav="1" live="true" lose_before_draw="false" points_in_first_column="false" season="2021" show_crests="false" show_form="0" show_key="false" show_live="true" show_logo="false" show_relegation_average="false" show_title="false" side="combined" sorting="false" sport="football" team="14" team_naming="full" template="normal" widget="standings">
# </opta-widget>
# </section>
# </div>
# </div>
# </div>
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_TWO">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_TWO');
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer id="page-footer">
# <div class="upperBackground">
# <section class="partners">
# <div class="Primary">
# <a href="http://www.standardchartered.com/home/en/index.html?camp_id=liverpool_source=liverpoolfctv_medium=4" target="_blank" title="Standard Chartered">
# <img alt="Standard Chartered" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/25/thumb_124418_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nike.com/gb/" target="_blank" title="Nike">
# <img alt="Nike" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/09/thumb_108617_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.axa.com/?utm_source=liverpoolfc&amp;utm_medium=logo-partnership&amp;utm_campaign=lfc1819season" target="_blank" title="AXA">
# <img alt="AXA" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/74/thumb_73714_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.expedia.co.uk/" target="_blank" title="Expedia">
# <img alt="Expedia" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/21/thumb_120808_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# <div class="Secondary">
# <a href="http://www.carlsberg.com/" target="_blank" title="Carlsberg">
# <img alt="Carlsberg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/92/thumb_91236_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.scjohnson.com" target="_blank" title="SC Johnson">
# <img alt="SC Johnson" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126678_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.kodansha.com/" target="_blank" title="Kodansha">
# <img alt="Kodansha" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/23/thumb_122892_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.sonos.com" target="_blank" title="Sonos">
# <img alt="Sonos" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125033_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.easports.com/" target="_blank" title="EA Sports">
# <img alt="EA Sports" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125053_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.tourism-mauritius.mu" target="_blank" title="Mauritius">
# <img alt="Mauritius" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/18/thumb_117132_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.facebook.com/PredatorEnergyDrink/" target="_blank" title="Predator Energy Drink">
# <img alt="Predator Energy Drink" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126187_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://mg.co.uk/" target="_blank" title="MG">
# <img alt="MG" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125832_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.hollyfrontier.com/home/default.aspx" target="_blank" title="Holly Frontier">
# <img alt="Holly Frontier" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/11/thumb_110194_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.thinkmarkets.com/uk/" target="_blank" title="ThinkMarkets">
# <img alt="ThinkMarkets" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125313_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.quorn.com/" target="_blank" title="Quorn">
# <img alt="Quorn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125055_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.mondelezinternational.com/" target="_blank" title="Cadbury ROW">
# <img alt="Cadbury ROW" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126098_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.acronis.com/en-gb/" target="_blank" title="Acronis">
# <img alt="Acronis" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/02/thumb_101725_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nipponham.co.jp/eng/" target="_blank" title="NH Foods">
# <img alt="NH Foods" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/86/thumb_85085_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://uk.joiebaby.com/liverpoolfc/" target="_blank" title="Joie Baby">
# <img alt="Joie Baby" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/41/thumb_40979_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# </section>
# </div>
# <div class="lowerBackground">
# <section class="bottomFooter">
# <div class="footerCrest">
# </div>
# <div class="footerCrestLeft">
# </div>
# <div class="footerText">
# <div class="footer-middleBottom">
# <a href="http://www.liverpoolfc.com/legal/privacy-policy" title="Go to Privacy Policy">Privacy Policy</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/terms-and-conditions" title="Go to Terms and Conditions">Terms and Conditions</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/anti-slavery" title="Go to Anti-Slavery">Anti-Slavery</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/cookies" title="Go to Cookies">Cookies</a> <span>|</span>
# <a href="https://faq.liverpoolfc.com/portal/home" title="Go to Help">Help</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/browser-support" title="Go to Browser Support">Browser Support</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/rss-feeds" title="Go to RSS Feeds">RSS Feeds</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/contactus" title="Go to Contact Us">Contact Us</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/accessible/accessible" title="Go to Accessibility">Accessibility</a> <br/>
# </div>
# <div class="footer-left">
#             © Copyright 2021 The Liverpool Football Club and Athletic Grounds Limited. All rights reserved.
#         </div>
# <div class="footer-right">
#             Developed and maintained by the LFC Technology and Transformation Team
#         </div>
# <div class="footer-middle">
#             Match Statistics supplied by Opta Sports Data Limited. Reproduced under licence from Football DataCo Limited. All rights reserved.
#         </div>
# </div>
# </section></div>
#
# </footer></div>
#
#
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/scripts.min.js"></script>
# <script src="https://secure.widget.cloud.opta.net/v3/v3.opta-widgets.js"></script>
# <script>
#             var opta_settings = {
#                    subscription_id: 'da747e372c352a82f3dd6174084858fd',
#                    language: 'en_GB',
#                    timezone: 'Europe/London',
#                    opta_tracking: false
#             };
#         </script>
# <style>
#                             .team-player-list-item .name > span {
# width:40px;
# }
#                         </style>
# <!-- monitoring:3e9fda56df2cdd3b039f189693ab7844fbb2d4f6 -->
# </body>
# </html>

# %%
children = list(soup.children)
print(children)
# Out:
# ['html', '\n', '[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie6 oldie"> <![endif]', '\n', '[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie7 oldie"> <![endif]', '\n', '[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie8 oldie"> <![endif]', '\n', '[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie9"> <![endif]', '\n', '[if (gt IE 9)|!(IE)]><!', ' ', <html class="no-js" id="top"> <!--<![endif]-->
# <script>
#     (function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#
#     if (window.history.replaceState && window.location.href.slice(-1) === '#') {
#         window.history.replaceState({},document.title,window.location.href.slice(0,-1));
#     }
# </script>
# <head>
# <!-- OneTrust Cookies Consent Notice start for liverpoolfc.com -->
# <script src="https://cdn-ukwest.onetrust.com/consent/aa158886-777d-463e-8082-e384a26718f6/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-domain-script="aa158886-777d-463e-8082-e384a26718f6" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# function OptanonWrapper() { }
# </script>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/css/cookie-consent-5.css" rel="stylesheet" type="text/css"/>
# <!-- OneTrust Cookies Consent Notice end for liverpoolfc.com -->
# <title>Liverpool FC - Team</title>
# <meta content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" name="keywords"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Liverpool FC" property="og:site_name"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="67920382572" property="fb:pages"/>
# <meta content="Liverpool FC - Team" property="og:title"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/favicon.png" rel="shortcut icon" type="image/png"/>
# <link href="https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css" rel="stylesheet"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles.css" rel="stylesheet">
# <!--[if  (lt IE 9) & (!IEMobile)]>
#             <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles-ie8.css" />
#         <![endif]-->
# <!--[if lt IE 9]>
#             <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie8.min.js"></script>
#         <![endif]-->
# <!--[if IE 9]>
#         <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie9.min.js"></script>
#         <![endif]-->
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/base.js"></script>
# <link href="//cdn.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//st.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//rcom.dynamicyield.com" rel="dns-prefetch"/>
# <script>
#
# window.DY = window.DY || {};
# DY.recommendationContext = {type: 'OTHER'};
#
# </script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_dynamic.js" type="text/javascript"></script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_static.js" type="text/javascript"></script>
# <style type="text/css">
# a.post-next.post-next-top {
#    display:none;
# }
#
# div.post-next.post-next-bottom {
#    display:none;
# }
# </style>
# <script>
#  // create Lfc element with GPT command queue
#  var Lfc = Lfc || {};
#  Lfc.gtmAdQueue = Lfc.gtmAdQueue || [];
#
#  // Load GPT asynchronously
#  var googletag = googletag || {};
#  googletag.cmd = googletag.cmd || [];
#  (function() {
#    var gads = document.createElement('script');
#    gads.async = true;
#    var useSSL = 'https:' == document.location.protocol;
#    gads.src = (useSSL ? 'https:' : 'http:') +
#        '//www.googletagservices.com/tag/js/gpt.js';
#    var node = document.getElementsByTagName('script')[0];
#    node.parentNode.insertBefore(gads, node);
#  })();
# </script>
# <script>
# $( document ).ready(function() {
#
# $('.masthead .link-login a').attr('href', 'https://www.liverpoolfc.com/my-lfc/login?fragment=&referer='+(document.URL));
#
# // remove age restricted footer logos
# var checkString = window.location.href;
# if( checkString.indexOf("academy") !== -1 || checkString.indexOf("under-23") !== -1 || checkString.indexOf("under-18") !== -1 || checkString.indexOf("soccerschools") !== -1  || checkString.indexOf("soccer-schools") !== -1  || checkString.indexOf("u23") !== -1  || checkString.indexOf("u18") !== -1){
# $('a[title="Carlsberg"], a[title="Betvictor"], a[title="Liverpool Vodka"], a[title="Draft Kings"], a[title="1XBET"]').remove();
# }
#
# if( checkString.indexOf("/women/") !== -1 || checkString.indexOf("/news/women") !== -1 || checkString.indexOf("/team/women") !== -1 || checkString.indexOf("/fans/liverpool-fc-women") !== -1) {
#     $('a[title="Western Union"], a[title="Carlsberg"],a[title="MG"],a[title="Nivea"],a[title="Falken Tyres"],a[title="TigerWit"],a[title="EA Sports"],a[title="Chaokoh"],a[title="NH Foods"],a[title="Lavazza"],a[title="Petro-Canada"],a[title="Liverpool Vodka"],a[title="Levis"],a[title="iugis"],a[title="Mitel"],a[title="Verbier"],a[title="Tribus"],a[title="Cadbury UK"],a[title="Cadbury ROW"],a[title="Holly Frontier"],a[title="Quorn"],a[title="Mauritius"],a[title="Acronis"]').remove();
# }
#
# // remove link
# $('a[title="1XBET"]'). removeAttr("href");
#
# // HOT FIX - REMOVING MORE MENU FROM INTERNATIONAL SITES
# var urlHostName = window.location.hostname;
# if (urlHostName.indexOf('indonesia') !== -1 || urlHostName.indexOf('thailand') !== -1 || urlHostName.indexOf('japan') !== -1) {
# $('.main-menu ul.more-menu').hide();
# }
#
#           })
# </script>
# <style>
# .site-header-inner .masthead .masthead-links .more-menu ul li a {
#   background: none!important;
# }
# .site-header-inner .social-links li.skype {
#   display: none;
# }
# .vixlet, .dugout {
#    display:none !important;
# }
# .video-error__content {
# padding-top:3%!important;
# }
# .video-error__listing {
# margin:15px 0!important;
# }
#
# .video-error__subtitle-mobile,
# .video-error__registered {
# color:white!important;
# }
#
# .video-player-embeddable .video-error--embed .video-error__listing-group ul li {
# margin:0 0 5px 0!important;
# }
# .video-error__call-to-action a.js-subscribe-button {
# font-size:0.8em!important;
# background:white!important;
# text-transform:uppercase!important;
# }
# .video-error__call-to-action a.js-subscribe-button:hover {
# color:#e31b23!important;
# }
#
# @media only screen and (min-width: 551px) {
# .video-error__subtitle-mobile {
# margin:10px 0!important;
# padding:0!important;
# }
# }
#
# @media only screen and (min-width: 775px) and (max-width: 975px) {
# .video-error__listing-group {
# display:none!important;
# }
# }
#
# /*@media screen and (min-width: 700px) {
# .site-header-inner .main-menu .more-menu .more-menu-link>ul li {
# display:block !important;
# }
# }*/
#
# @media screen and (min-width: 1000px) {
# .site-header-inner .masthead .masthead-links .more-menu.noLogin ul {
# top: 100%!important;
# }
# }
#
# /* IE ONLY */
# @media screen\0 {
# .video-player-embeddable .video .shard-overlay {position: absolute !important;}
# }
#
# .home .featured-news-carousel .media-image-wrap .indent {text-indent: -99999px;}
#
# .dy_unit .dy-sliding-drawer-container{bottom: 25%;}
# </style>
# <script>
# var Lfc = Lfc || {};
#
# Lfc.messagesConfig = {
#     messages: [
#
#         // ANDROID APP BANNER
#         {
#             id: 'android-app-banner',
#             maximumDisplayCount: 1,
#             displayCondition: function() {
#                 // don't show on non-Android devices
#                 if (navigator.userAgent.match(/Android/i) === null || navigator.userAgent.indexOf('Windows') > -1) {
#                     return false;
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show if valid app id meta tag exists
#                 //  (e.g. <meta name="google-play-app" content="app-id=tv.liverpoolfc">)
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         return true;
#                     }
#                 }
#             },
#             content: function() {
#                 // get app id from meta tag
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         var linkUrl = 'https://play.google.com/store/apps/details?id=' + appId[1] +
#                                 '&referrer=utm_source%3DWebsite%26utm_medium%3DHEADER_APP_CARD_MAIN_SITE%26utm_content%3DDigital%26utm_campaign%3DClub%2520App';
#
#                         return '<div id="android-app-banner">' +
#                             '<a href="javascript:void(0);" class="close">&times;</a>' +
#                             '<a href="' + linkUrl + '">' +
#                                 '<span class="app-icon"></span>' +
#                                 '<div class="app-info">' +
#                                     '<strong>LFC Official App</strong>' +
#                                     '<span>Liverpool Football Club</span>' +
#                                     '<span>FREE in Google Play</span>' +
#                                 '</div>' +
#                                 '<span class="view">VIEW</span>' +
#                             '</a>' +
#                         '</div>';
#                     }
#                 }
#             },
#             style: "styled-header"
#         },
#
#         // REGISTRATION POP-UP
#         {
#             id : 'registration-popup',
#             minimumInterval : 10*24*60*60*1000, // 10 days = 10*24*60*60*1000
#             displayCondition: function() {
# // temp fix to not display
# return false;
#                 // don't show to logged in users
#                 if (Lfc.Login.isLoggedIn()) {
#                     Lfc.Cookie.set("registration-popup-logout-time", "logged in");
#                     return false;
#                 }
#                 // don't show immediately after logout -- wait 1 day
#                 var now = (new Date()).getTime(),
#                     logOutTime = Lfc.Cookie.get("registration-popup-logout-time");
#
#                 if (logOutTime == "logged in") {
#                     // immediately after logout, store timestamp
#                     Lfc.Cookie.set("registration-popup-logout-time", now);
#                     return false;
#                 } else {
#                     // if one day has not yet passed since first known logged out time, don't show
#                     if (logOutTime && (now - logOutTime < 24*60*60*1000)) { // 1 day = 24*60*60*1000
#                         return false;
#                     };
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show to "A" group people
#                 var abGroup = Lfc.Cookie.getABGroup("registration-popup");
#                 if (!abGroup) {
#                     abGroup = Lfc.Cookie.setABGroup("registration-popup");
#                     dataLayer.push({'event': 'registration-popup-ab-assignment', 'abGroup': abGroup });
#                 }
#                 return abGroup === "A";
#             },
#             onShow: function() {
#                 dataLayer.push({'event': 'registration-popup-shown'});
#             },
#             content : function() {
#                 if ($(window).width() < 1000) {
#                     // header message
#                     return regMessageHeaderMarkup + regMessageHeaderStyling;
#                 } else {
#                     // big popup with login
#                     return regMessagePopupMarkup + regMessagePopupStyling;
#                 }
#             },
#             style: function() {
#                 if ($(window).width() < 1000) {
#                     return 'default-header';
#                 } else {
#                     return 'popup';
#                 }
#             }
#         },
#     ],
#     minimumMessageInterval : 60*60*1000, // 1 hour = 60*60*1000
# }
#
#
# // REGISTRATION POPUP MARKUP & STYLING
# var regMessagePopupMarkup = '<div class="registration-popup-message"> <h1>GET MORE FROM LFC.</h1> <div id="not-logged-in-actions"> <h2>Register and get immediate access to:</h2> <fieldset class="reg-signup"> <div class="new-user-content"> <div class="signUpMessage registerText" style="line-height: 24px;"> <ul> <li class="image-bullet video">Free LFC videos</li> <li class="image-bullet match">Listen to live match commentary</li> <li class="image-bullet win">Exclusive competitions</li> <li class="image-bullet news">Receive the official club newsletter - All in Red</li> <li class="image-bullet forum">Join the conversation on the official LFC forums</li> <li class="image-bullet shirt">The Official Online Store</li> </ul> <p>...and it&rsquo;s completely <span>FREE!</span></p> </div> </div> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild"> <div class="buttonPlaceholder buttonPlaceholderPopUp"> <input type="button" value="Register" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </a> </fieldset> </div> <div id="LoginBox"> <h2>Login</h2> <div class="LoginFormBox"> <form id="WholesaleContact" title="Login" method="post" name="Login" action="/scripts/login.php?login=LfcTVLogin"> <fieldset> <div class="login-content"> <table class="lfcMembershipTable"> <tr class="LoginTableSpacing"> <th><label for="LoginUsernameId">Username</label></th> <td><input id="LoginUsernameId" class="InputLoginBox " type="text" name="username" /></td> <td class="formHelp">Email address</td> </tr> <tr class="LoginTableSpacing"> <th><label for="LoginPasswordId">Password</label></th> <td><input id="LoginPasswordId" class="InputLoginBox" type="password" name="password" /></td> <td class="formHelp"> <p><a href="/my-lfc/login/forgotten-password">Forgotten password?</a></p> </td> </tr> <tr class="remember LoginTableSpacing"> <th><label for="remember_me">Remember</label></th> <td style="vertical-align: middle;" class="rememberSideText formHelp" colspan="2"> <input type="checkbox" name="remember_me" class="remember_checkbox" /> <p class="rememberSideText formHelp">Remember your details on this machine?</p> </td> </tr> </table> </div> <div class="ArticleContent"> <div class="buttonPlaceholder"> <input type="submit" value="Login" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </div> <input type="hidden" name="referer" value="http://www.liverpoolfc.com/" /> </fieldset> </form> <script type="text/javascript"> $("#LoginUsernameId, #LoginPasswordId").on("keydown", function (evt) { if(evt.keyCode == 13) { $("#LoginForm").submit(); } }); <\/script> </div> </div></div>';
#
# var regMessagePopupStyling = '<style> /* header */ #cboxLoadedContent .registration-popup-message h1 { background: #E31B23; color: #FFF; padding: 0px 20px; line-height: 64px; font-size: 30px; } #colorbox #cboxClose { background: none; height: 58px; width: 50px; top: 3px!important; right: 3px; border: none; } #colorbox #cboxClose::after { content: "\\2716"; position: absolute; top: 0; left: 0; right: 0; line-height: 58px; text-align: center; font-size: 24px; text-indent: 0; color: #fff; } /* layout */ #cboxLoadedContent .registration-popup-message #not-logged-in-actions { width: 65%; padding: 20px; } #cboxLoadedContent .registration-popup-message #LoginBox { width: 35%; padding: 20px; } #cboxLoadedContent .registration-popup-message .login-content, #cboxLoadedContent .registration-popup-message .new-user-content { height: 250px; } #cboxLoadedContent .registration-popup-message h2 { border-bottom: 1px solid #DDD; margin: 0; padding: 2px 0 8px; } /* registration benefits */ #cboxLoadedContent .registration-popup-message .signUpMessage > p, #cboxLoadedContent .registration-popup-message .signUpMessage > ul { line-height: 36px; font-size: 16px; margin-bottom: 12px; } #cboxLoadedContent .registration-popup-message .signUpMessage > ul li.image-bullet { background-size: 24px; padding-left: 36px; } #cboxLoadedContent .registration-popup-message .signUpMessage > p { line-height: 36px; font-size: 16px; } /* login form */ #cboxLoadedContent .registration-popup-message #socialSignOn { margin: -10px 0 0; } #cboxLoadedContent .registration-popup-message .socialLogin { text-indent: -9999px; width: 40px; height: 40px; background-size: auto 40px; margin: 0 0 0 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable { clear: both; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th, #cboxLoadedContent .registration-popup-message .lfcMembershipTable td { float: left; width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable input { width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th { text-align: left; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable td.formHelp { text-align: right; padding: 5px 0; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember input { width: 19px; margin-right: 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember td { text-align: left; }<style>';
#
# var regMessageHeaderMarkup = '<div class="richtext"> <h1>GET MORE FROM LFC</h1> <p class="small-content">Register or log in now to access <strong>FREE</strong> benefits</p> <p class="medium-content">Log in now, or register to access a range of <strong>FREE</strong> benefits including videos and exclusive competitions.</p> <p class="buttons"> <a href="javascript:void(0);" class="main-button close">No thanks</a> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild" class="main-button">Yes, please!</a> </p></div>';
#
# var regMessageHeaderStyling = '<style> .header-message { background: #FFF; text-align: center; border-bottom: 2px solid #FFF; overflow: hidden; } .header-message::after { background: #C8C8C8; height: 6px; } .header-message > a.close { display: none; } .header-message .richtext a { text-decoration: none; } .header-message .buttons { margin: 10px 0; } .header-message .buttons a.main-button { margin: 0.2em 0.5em 0; padding: 0.8em 2em; } .header-message .buttons a.main-button.close { background: #FFF; color: #E31B23; border: 1px solid #E31B23; } .header-message p.medium-content { display: none; } @media screen and (min-width: 500px) { .header-message p.small-content { display: none; } .header-message p.medium-content { display: block; margin-bottom: 0; } .header-message .buttons { position: absolute; top: 0; right: 0; width: 11.5em; margin-bottom: 0; margin-right: 20px; } .header-message { min-height: 9em; } .header-message .richtext { margin-right: 14em; } .header-message .buttons a.main-button { display: block; margin: 0.6em 0; } }</style>';
#
# </script>
# <script type="text/javascript">
#
#  googletag.cmd.push(function() {
#
#   //general size mapping
#   var mapResMainRightOne = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
#   var mapResMainRightTwo = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# var mapResMainFixtures = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [468, 60]).
#    addSize([776, 0], [728, 90]).build();
# }
#
#
# 	 //general slots
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_ONE', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_ONE').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightOne).
# 				addService(googletag.pubads());
#
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_TWO', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_TWO').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightTwo).
# 				addService(googletag.pubads());
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# googletag.defineSlot('/87687331/RES_MAIN_FIXTURES', [320, 50], 'div-gpt-ad-RES_MAIN_FIXTURES').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainFixtures).
# 				addService(googletag.pubads());
# }
#
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().enableSingleRequest();
#   googletag.enableServices();
#  });
# </script>
# <style type="text/css">
# .facebookButton{
# display:none!important;
# }
# </style>
# </link></head>
# <body class="main-site-layout sonata-bc template-standard_two_column standard-two-column">
# <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KCFJMVP" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KCFJMVP');
#             </script>
# <!-- End Google Tag Manager -->
# <div class="wrapper">
# <a id="page-top"></a>
# <header class="site-header" id="site-header" role="banner">
# <div class="site-header-inner">
# <div class="masthead">
# <ul class="account-links logged-out-only">
# <li class="subnav">
# <a>Log In</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="link-separator"> </li>
# <li class="subnav">
# <a>Register</a>
# <ul>
# <li class="first"> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=free" target="">Free Registration</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/membership" target="">Join Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=lfctvo" target="">Join LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not Sure?</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="account-links logged-in-only">
# <li>
# <a class="link-logout" href="https://www.liverpoolfc.com/scripts/logout.php" title="Logout">Log out</a>
# </li>
# <li class="link-separator"> </li>
# <li>
# <a class="link-my-lfc" href="https://www.liverpoolfc.com/my-lfc" title="My LFC">My LFC</a>
# </li>
# </ul>
# <div class="masthead-links" id="masthead-links">
# <ul class="more-menu">
# <li class="more-menu-link">
# <a>More</a>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="logo">
# <a class="logo-large" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-medium" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-small" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo-small.png"/>
# </a></div>
# <a class="sponsor" href="//www.sc.com/en/" target="main-sponsor">
#     Main Club Sponsor: Standard Chartered
# </a>
# <div class="search">
# </div>
# <nav class="main-menu">
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="more-menu">
# <li class="more-menu-link">
# <a><span>More</span></a>
# <div class="icon-menu moreIconCss"></div>
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="my-account logged-out-only">
# <a href="https://www.liverpoolfc.com/my-lfc/login" title="Log in">LOG IN</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="my-account logged-in-only">
# <a href="https://www.liverpoolfc.com/my-lfc" title="My LFC">MY LFC</a>
# </li>
# </ul>
# </nav>
# <ul class="social-links">
# <li class="vixlet">
# <a href="http://lfc.onelink.me/684654549?pid=LFC&amp;c=SOCIALICON" target="_blank" title="Go to The Official Liverpool Football Club Xtra page"></a>
# </li>
# <li class="facebook">
# <a href="https://www.facebook.com/LiverpoolFC" target="_blank" title="Go to The Official Liverpool Football Club Facebook page"></a>
# </li>
# <li class="twitter">
# <a href="https://twitter.com/lfc" target="_blank" title="Go to The Official Liverpool Football Club Twitter page"></a>
# </li>
# <li class="dugout">
# ...
# </div>
# <div class="number">9</div>
# <div class="about">
# <div class="name">
# <span>Roberto</span> <span>Firmino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sadio-mane">
# <div class="img-wrap">
# <img alt="Sadio Mane" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125153_misc_general_500.jpeg"/>
# </div>
# <div class="number">10</div>
# <div class="about">
# <div class="name">
# <span>Sadio</span> <span>Mane</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/mohamed-salah">
# <div class="img-wrap">
# <img alt="Mohamed Salah" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125158_misc_general_500.jpeg"/>
# </div>
# <div class="number">11</div>
# <div class="about">
# <div class="name">
# <span>Mohamed</span> <span>Salah</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/takumi-minamino">
# <div class="img-wrap">
# <img alt="Takumi Minamino" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125154_misc_general_500.jpeg"/>
# </div>
# <div class="number">18</div>
# <div class="about">
# <div class="name">
# <span>Takumi</span> <span>Minamino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/diogo-jota">
# <div class="img-wrap">
# <img alt="Diogo Jota" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125136_misc_general_500.jpeg"/>
# </div>
# <div class="number">20</div>
# <div class="about">
# <div class="name">
# <span>Diogo</span> <span>Jota</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/divock-origi">
# <div class="img-wrap">
# <img alt="Divock Origi" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125137_misc_general_500.jpeg"/>
# </div>
# <div class="number">27</div>
# <div class="about">
# <div class="name">
# <span>Divock</span> <span>Origi</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/harvey-elliott">
# <div class="img-wrap">
# <img alt="Harvey Elliott" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125147_misc_general_500.jpeg"/>
# </div>
# <div class="number">67</div>
# <div class="about">
# <div class="name">
# <span>Harvey</span> <span>Elliott</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.fixtures.listing.block.player" id="cms-block-17819">
# <div class="team-player-list">
# <h2>ON LOAN</h2>
# <ul>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-davies">
# <div class="img-wrap">
# <img alt="Ben Davies" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125132_misc_general_500.jpeg"/>
# </div>
# <div class="number">28</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Davies</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/rhys-williams">
# <div class="img-wrap">
# <img alt="Rhys Williams" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125151_misc_general_500.jpeg"/>
# </div>
# <div class="number">46</div>
# <div class="about">
# <div class="name">
# <span>Rhys</span> <span>Williams</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sheyi-ojo">
# <div class="img-wrap">
# <img alt="Sheyi Ojo" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg"/>
# </div>
# <div class="number">54</div>
# <div class="about">
# <div class="name">
# <span>Sheyi</span> <span>Ojo</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-woodburn">
# <div class="img-wrap">
# <img alt="Ben Woodburn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125133_misc_general_500.jpeg"/>
# </div>
# <div class="number">58</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Woodburn</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sepp-van-den-berg">
# <div class="img-wrap">
# <img alt="Sepp van den Berg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/14/thumb_113613_misc_general_500.jpeg"/>
# </div>
# <div class="number">72</div>
# <div class="about">
# <div class="name">
# <span>Sepp</span> <span>van</span> <span>den</span> <span>Berg</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-3194">
# <div class="container-block block-3194">
# </div>
# </div>
# </div>
# </div>
# <div class="rightCol">
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_ONE">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_ONE');
# </script>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-2919">
# <div class="container-block block-2919">
# <div class="cms-block cms-block-element" data-block-type="sonata.block.service.text" id="cms-block-3332">
# <style type="text/css">
#
#     .richtext.linkList a {
#         display: block;
#         padding: 6px;
#         margin-bottom: 0;
#         overflow: hidden;
#         padding-right: 30px;
#         position: relative;
#         color: #333;
#         font-weight: normal;
#     }
#
#     .richtext.linkList a:nth-child(odd) {
#         background: #F6F6F6;
#     }
#
#     .richtext.linkList a:after {
#         border-bottom: 8px solid transparent;
#         border-left: 12px solid #E31B23;
#         border-top: 8px solid transparent;
#         content: "";
#         display: inline-block;
#         height: 0;
#         position: absolute;
#         width: 0;
#         right: 10px;
#         margin-top: -8px;
#         top: 50%;
#     }
#
# @media screen and (max-width: 699px){
# .mainColInner .richtext img {
# width: 100%!important;
# height: auto!important;
# float: left!important;
# margin-bottom: 30px!important;
# }
#
# </style>
# <div class="richtext linkList">
# <h2>First Team Staff</h2>
# <a href="/team/first-team/staff/jurgen-klopp">Jürgen Klopp</a>
# <a href="/team/first-team/staff/peter-krawietz">Peter Krawietz</a>
# <a href="/team/first-team/staff/pepijn-lijnders">Pepijn Lijnders</a>
# <a href="/team/first-team/staff/john-achterberg">John Achterberg</a>
# <a href="/team/first-team/staff/jack-robinson">Jack Robinson</a>
# <a href="/team/first-team/staff/claudio-taffarel">Claudio Taffarel</a>
# <a href="/team/first-team/staff/vitor-matos">Vitor Matos</a>
# <a href="/team/first-team/staff/andreas-kornmayer">Andreas Kornmayer</a>
# <a href="/team/first-team/staff/dr-andreas-schlumberger">Dr Andreas Schlumberger</a>
# <a href="/team/first-team/staff/dr-jim-moxon">Dr Jim Moxon</a>
# <a href="/team/first-team/staff/lee-nobes">Lee Nobes</a>
# <a href="/team/first-team/staff/conall-murtagh">Dr Conall Murtagh</a>
# <a href="/team/first-team/staff/jordan-fairclough">Jordan Fairclough</a>
# <a href="/team/first-team/staff/paul-small">Paul Small </a>
# <a href="/team/first-team/staff/lee-radcliffe">Lee Radcliffe</a>
# <a href="/team/first-team/staff/brendan-mcilduff">Brendan McIlduff</a>
# <a href="/team/first-team/staff/david-rydings">Dr David Rydings</a>
# <a href="/team/first-team/staff/mona-nemmer">Mona Nemmer</a>
# <a href="/team/first-team/staff/mark-leyland">Mark Leyland</a>
# <a href="/team/first-team/staff/daniel-spearritt">Daniel Spearritt</a>
# <a href="/team/first-team/staff/greg-mathieson">Greg Mathieson</a>
# <a href="/team/first-team/staff/james-french">James French</a>
# <a href="/team/first-team/staff/chris-morgan">Chris Morgan</a>
# <a href="/team/first-team/staff/steve-lilley">Steve Lilley</a>
# <a href="/team/first-team/staff/joe-lewis">Joe Lewis</a>
# <a href="/team/first-team/staff/michelle-hudson">Michelle Hudson</a>
# <a href="/team/first-team/staff/motonori-watanabe">Motonori Watanabe</a>
# <a href="/team/first-team/staff/lena-aschenbrenner">Lena Aschenbrenner</a>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.opta.standings.block.service" id="cms-block-3333">
# <section class="opta-wrapper" id="league-table">
# <opta-widget breakpoints="550" competition="8" competition_naming="full" data_detail="full" date_format="dddd D MMMM YYYY" default_nav="1" live="true" lose_before_draw="false" points_in_first_column="false" season="2021" show_crests="false" show_form="0" show_key="false" show_live="true" show_logo="false" show_relegation_average="false" show_title="false" side="combined" sorting="false" sport="football" team="14" team_naming="full" template="normal" widget="standings">
# </opta-widget>
# </section>
# </div>
# </div>
# </div>
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_TWO">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_TWO');
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer id="page-footer">
# <div class="upperBackground">
# <section class="partners">
# <div class="Primary">
# <a href="http://www.standardchartered.com/home/en/index.html?camp_id=liverpool_source=liverpoolfctv_medium=4" target="_blank" title="Standard Chartered">
# <img alt="Standard Chartered" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/25/thumb_124418_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nike.com/gb/" target="_blank" title="Nike">
# <img alt="Nike" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/09/thumb_108617_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.axa.com/?utm_source=liverpoolfc&amp;utm_medium=logo-partnership&amp;utm_campaign=lfc1819season" target="_blank" title="AXA">
# <img alt="AXA" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/74/thumb_73714_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.expedia.co.uk/" target="_blank" title="Expedia">
# <img alt="Expedia" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/21/thumb_120808_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# <div class="Secondary">
# <a href="http://www.carlsberg.com/" target="_blank" title="Carlsberg">
# <img alt="Carlsberg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/92/thumb_91236_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.scjohnson.com" target="_blank" title="SC Johnson">
# <img alt="SC Johnson" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126678_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.kodansha.com/" target="_blank" title="Kodansha">
# <img alt="Kodansha" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/23/thumb_122892_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.sonos.com" target="_blank" title="Sonos">
# <img alt="Sonos" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125033_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.easports.com/" target="_blank" title="EA Sports">
# <img alt="EA Sports" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125053_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.tourism-mauritius.mu" target="_blank" title="Mauritius">
# <img alt="Mauritius" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/18/thumb_117132_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.facebook.com/PredatorEnergyDrink/" target="_blank" title="Predator Energy Drink">
# <img alt="Predator Energy Drink" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126187_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://mg.co.uk/" target="_blank" title="MG">
# <img alt="MG" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125832_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.hollyfrontier.com/home/default.aspx" target="_blank" title="Holly Frontier">
# <img alt="Holly Frontier" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/11/thumb_110194_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.thinkmarkets.com/uk/" target="_blank" title="ThinkMarkets">
# <img alt="ThinkMarkets" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125313_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.quorn.com/" target="_blank" title="Quorn">
# <img alt="Quorn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125055_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.mondelezinternational.com/" target="_blank" title="Cadbury ROW">
# <img alt="Cadbury ROW" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126098_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.acronis.com/en-gb/" target="_blank" title="Acronis">
# <img alt="Acronis" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/02/thumb_101725_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nipponham.co.jp/eng/" target="_blank" title="NH Foods">
# <img alt="NH Foods" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/86/thumb_85085_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://uk.joiebaby.com/liverpoolfc/" target="_blank" title="Joie Baby">
# <img alt="Joie Baby" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/41/thumb_40979_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# </section>
# </div>
# <div class="lowerBackground">
# <section class="bottomFooter">
# <div class="footerCrest">
# </div>
# <div class="footerCrestLeft">
# </div>
# <div class="footerText">
# <div class="footer-middleBottom">
# <a href="http://www.liverpoolfc.com/legal/privacy-policy" title="Go to Privacy Policy">Privacy Policy</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/terms-and-conditions" title="Go to Terms and Conditions">Terms and Conditions</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/anti-slavery" title="Go to Anti-Slavery">Anti-Slavery</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/cookies" title="Go to Cookies">Cookies</a> <span>|</span>
# <a href="https://faq.liverpoolfc.com/portal/home" title="Go to Help">Help</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/browser-support" title="Go to Browser Support">Browser Support</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/rss-feeds" title="Go to RSS Feeds">RSS Feeds</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/contactus" title="Go to Contact Us">Contact Us</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/accessible/accessible" title="Go to Accessibility">Accessibility</a> <br/>
# </div>
# <div class="footer-left">
#             © Copyright 2021 The Liverpool Football Club and Athletic Grounds Limited. All rights reserved.
#         </div>
# <div class="footer-right">
#             Developed and maintained by the LFC Technology and Transformation Team
#         </div>
# <div class="footer-middle">
#             Match Statistics supplied by Opta Sports Data Limited. Reproduced under licence from Football DataCo Limited. All rights reserved.
#         </div>
# </div>
# </section></div>
#
# </footer></div>
#
#
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/scripts.min.js"></script>
# <script src="https://secure.widget.cloud.opta.net/v3/v3.opta-widgets.js"></script>
# <script>
#             var opta_settings = {
#                    subscription_id: 'da747e372c352a82f3dd6174084858fd',
#                    language: 'en_GB',
#                    timezone: 'Europe/London',
#                    opta_tracking: false
#             };
#         </script>
# <style>
#                             .team-player-list-item .name > span {
# width:40px;
# }
#                         </style>
# <!-- monitoring:3e9fda56df2cdd3b039f189693ab7844fbb2d4f6 -->
# </body>
# </html>, '\n']

# %%
print([type(item) for item in list(soup.children)])
# Out:
# [<class 'bs4.element.Doctype'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Comment'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Comment'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Comment'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Comment'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Comment'>, <class 'bs4.element.NavigableString'>, <class 'bs4.element.Tag'>, <class 'bs4.element.NavigableString'>]

# %%
html = list(soup.children)[12]

# %%
html
# Out:
# <html class="no-js" id="top"> <!--<![endif]-->
# <script>
#     (function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#
#     if (window.history.replaceState && window.location.href.slice(-1) === '#') {
#         window.history.replaceState({},document.title,window.location.href.slice(0,-1));
#     }
# </script>
# <head>
# <!-- OneTrust Cookies Consent Notice start for liverpoolfc.com -->
# <script src="https://cdn-ukwest.onetrust.com/consent/aa158886-777d-463e-8082-e384a26718f6/OtAutoBlock.js" type="text/javascript"></script>
# <script charset="UTF-8" data-domain-script="aa158886-777d-463e-8082-e384a26718f6" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
# function OptanonWrapper() { }
# </script>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/css/cookie-consent-5.css" rel="stylesheet" type="text/css"/>
# <!-- OneTrust Cookies Consent Notice end for liverpoolfc.com -->
# <title>Liverpool FC - Team</title>
# <meta content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" name="keywords"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." name="description"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Liverpool FC" property="og:site_name"/>
# <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="67920382572" property="fb:pages"/>
# <meta content="Liverpool FC - Team" property="og:title"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/favicon.png" rel="shortcut icon" type="image/png"/>
# <link href="https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css" rel="stylesheet"/>
# <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles.css" rel="stylesheet">
# <!--[if  (lt IE 9) & (!IEMobile)]>
#             <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles-ie8.css" />
#         <![endif]-->
# <!--[if lt IE 9]>
#             <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie8.min.js"></script>
#         <![endif]-->
# <!--[if IE 9]>
#         <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie9.min.js"></script>
#         <![endif]-->
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/base.js"></script>
# <link href="//cdn.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//st.dynamicyield.com" rel="dns-prefetch"/>
# <link href="//rcom.dynamicyield.com" rel="dns-prefetch"/>
# <script>
#
# window.DY = window.DY || {};
# DY.recommendationContext = {type: 'OTHER'};
#
# </script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_dynamic.js" type="text/javascript"></script>
# <script src="//cdn.dynamicyield.com/api/8772718/api_static.js" type="text/javascript"></script>
# <style type="text/css">
# a.post-next.post-next-top {
#    display:none;
# }
#
# div.post-next.post-next-bottom {
#    display:none;
# }
# </style>
# <script>
#  // create Lfc element with GPT command queue
#  var Lfc = Lfc || {};
#  Lfc.gtmAdQueue = Lfc.gtmAdQueue || [];
#
#  // Load GPT asynchronously
#  var googletag = googletag || {};
#  googletag.cmd = googletag.cmd || [];
#  (function() {
#    var gads = document.createElement('script');
#    gads.async = true;
#    var useSSL = 'https:' == document.location.protocol;
#    gads.src = (useSSL ? 'https:' : 'http:') +
#        '//www.googletagservices.com/tag/js/gpt.js';
#    var node = document.getElementsByTagName('script')[0];
#    node.parentNode.insertBefore(gads, node);
#  })();
# </script>
# <script>
# $( document ).ready(function() {
#
# $('.masthead .link-login a').attr('href', 'https://www.liverpoolfc.com/my-lfc/login?fragment=&referer='+(document.URL));
#
# // remove age restricted footer logos
# var checkString = window.location.href;
# if( checkString.indexOf("academy") !== -1 || checkString.indexOf("under-23") !== -1 || checkString.indexOf("under-18") !== -1 || checkString.indexOf("soccerschools") !== -1  || checkString.indexOf("soccer-schools") !== -1  || checkString.indexOf("u23") !== -1  || checkString.indexOf("u18") !== -1){
# $('a[title="Carlsberg"], a[title="Betvictor"], a[title="Liverpool Vodka"], a[title="Draft Kings"], a[title="1XBET"]').remove();
# }
#
# if( checkString.indexOf("/women/") !== -1 || checkString.indexOf("/news/women") !== -1 || checkString.indexOf("/team/women") !== -1 || checkString.indexOf("/fans/liverpool-fc-women") !== -1) {
#     $('a[title="Western Union"], a[title="Carlsberg"],a[title="MG"],a[title="Nivea"],a[title="Falken Tyres"],a[title="TigerWit"],a[title="EA Sports"],a[title="Chaokoh"],a[title="NH Foods"],a[title="Lavazza"],a[title="Petro-Canada"],a[title="Liverpool Vodka"],a[title="Levis"],a[title="iugis"],a[title="Mitel"],a[title="Verbier"],a[title="Tribus"],a[title="Cadbury UK"],a[title="Cadbury ROW"],a[title="Holly Frontier"],a[title="Quorn"],a[title="Mauritius"],a[title="Acronis"]').remove();
# }
#
# // remove link
# $('a[title="1XBET"]'). removeAttr("href");
#
# // HOT FIX - REMOVING MORE MENU FROM INTERNATIONAL SITES
# var urlHostName = window.location.hostname;
# if (urlHostName.indexOf('indonesia') !== -1 || urlHostName.indexOf('thailand') !== -1 || urlHostName.indexOf('japan') !== -1) {
# $('.main-menu ul.more-menu').hide();
# }
#
#           })
# </script>
# <style>
# .site-header-inner .masthead .masthead-links .more-menu ul li a {
#   background: none!important;
# }
# .site-header-inner .social-links li.skype {
#   display: none;
# }
# .vixlet, .dugout {
#    display:none !important;
# }
# .video-error__content {
# padding-top:3%!important;
# }
# .video-error__listing {
# margin:15px 0!important;
# }
#
# .video-error__subtitle-mobile,
# .video-error__registered {
# color:white!important;
# }
#
# .video-player-embeddable .video-error--embed .video-error__listing-group ul li {
# margin:0 0 5px 0!important;
# }
# .video-error__call-to-action a.js-subscribe-button {
# font-size:0.8em!important;
# background:white!important;
# text-transform:uppercase!important;
# }
# .video-error__call-to-action a.js-subscribe-button:hover {
# color:#e31b23!important;
# }
#
# @media only screen and (min-width: 551px) {
# .video-error__subtitle-mobile {
# margin:10px 0!important;
# padding:0!important;
# }
# }
#
# @media only screen and (min-width: 775px) and (max-width: 975px) {
# .video-error__listing-group {
# display:none!important;
# }
# }
#
# /*@media screen and (min-width: 700px) {
# .site-header-inner .main-menu .more-menu .more-menu-link>ul li {
# display:block !important;
# }
# }*/
#
# @media screen and (min-width: 1000px) {
# .site-header-inner .masthead .masthead-links .more-menu.noLogin ul {
# top: 100%!important;
# }
# }
#
# /* IE ONLY */
# @media screen\0 {
# .video-player-embeddable .video .shard-overlay {position: absolute !important;}
# }
#
# .home .featured-news-carousel .media-image-wrap .indent {text-indent: -99999px;}
#
# .dy_unit .dy-sliding-drawer-container{bottom: 25%;}
# </style>
# <script>
# var Lfc = Lfc || {};
#
# Lfc.messagesConfig = {
#     messages: [
#
#         // ANDROID APP BANNER
#         {
#             id: 'android-app-banner',
#             maximumDisplayCount: 1,
#             displayCondition: function() {
#                 // don't show on non-Android devices
#                 if (navigator.userAgent.match(/Android/i) === null || navigator.userAgent.indexOf('Windows') > -1) {
#                     return false;
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show if valid app id meta tag exists
#                 //  (e.g. <meta name="google-play-app" content="app-id=tv.liverpoolfc">)
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         return true;
#                     }
#                 }
#             },
#             content: function() {
#                 // get app id from meta tag
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         var linkUrl = 'https://play.google.com/store/apps/details?id=' + appId[1] +
#                                 '&referrer=utm_source%3DWebsite%26utm_medium%3DHEADER_APP_CARD_MAIN_SITE%26utm_content%3DDigital%26utm_campaign%3DClub%2520App';
#
#                         return '<div id="android-app-banner">' +
#                             '<a href="javascript:void(0);" class="close">&times;</a>' +
#                             '<a href="' + linkUrl + '">' +
#                                 '<span class="app-icon"></span>' +
#                                 '<div class="app-info">' +
#                                     '<strong>LFC Official App</strong>' +
#                                     '<span>Liverpool Football Club</span>' +
#                                     '<span>FREE in Google Play</span>' +
#                                 '</div>' +
#                                 '<span class="view">VIEW</span>' +
#                             '</a>' +
#                         '</div>';
#                     }
#                 }
#             },
#             style: "styled-header"
#         },
#
#         // REGISTRATION POP-UP
#         {
#             id : 'registration-popup',
#             minimumInterval : 10*24*60*60*1000, // 10 days = 10*24*60*60*1000
#             displayCondition: function() {
# // temp fix to not display
# return false;
#                 // don't show to logged in users
#                 if (Lfc.Login.isLoggedIn()) {
#                     Lfc.Cookie.set("registration-popup-logout-time", "logged in");
#                     return false;
#                 }
#                 // don't show immediately after logout -- wait 1 day
#                 var now = (new Date()).getTime(),
#                     logOutTime = Lfc.Cookie.get("registration-popup-logout-time");
#
#                 if (logOutTime == "logged in") {
#                     // immediately after logout, store timestamp
#                     Lfc.Cookie.set("registration-popup-logout-time", now);
#                     return false;
#                 } else {
#                     // if one day has not yet passed since first known logged out time, don't show
#                     if (logOutTime && (now - logOutTime < 24*60*60*1000)) { // 1 day = 24*60*60*1000
#                         return false;
#                     };
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show to "A" group people
#                 var abGroup = Lfc.Cookie.getABGroup("registration-popup");
#                 if (!abGroup) {
#                     abGroup = Lfc.Cookie.setABGroup("registration-popup");
#                     dataLayer.push({'event': 'registration-popup-ab-assignment', 'abGroup': abGroup });
#                 }
#                 return abGroup === "A";
#             },
#             onShow: function() {
#                 dataLayer.push({'event': 'registration-popup-shown'});
#             },
#             content : function() {
#                 if ($(window).width() < 1000) {
#                     // header message
#                     return regMessageHeaderMarkup + regMessageHeaderStyling;
#                 } else {
#                     // big popup with login
#                     return regMessagePopupMarkup + regMessagePopupStyling;
#                 }
#             },
#             style: function() {
#                 if ($(window).width() < 1000) {
#                     return 'default-header';
#                 } else {
#                     return 'popup';
#                 }
#             }
#         },
#     ],
#     minimumMessageInterval : 60*60*1000, // 1 hour = 60*60*1000
# }
#
#
# // REGISTRATION POPUP MARKUP & STYLING
# var regMessagePopupMarkup = '<div class="registration-popup-message"> <h1>GET MORE FROM LFC.</h1> <div id="not-logged-in-actions"> <h2>Register and get immediate access to:</h2> <fieldset class="reg-signup"> <div class="new-user-content"> <div class="signUpMessage registerText" style="line-height: 24px;"> <ul> <li class="image-bullet video">Free LFC videos</li> <li class="image-bullet match">Listen to live match commentary</li> <li class="image-bullet win">Exclusive competitions</li> <li class="image-bullet news">Receive the official club newsletter - All in Red</li> <li class="image-bullet forum">Join the conversation on the official LFC forums</li> <li class="image-bullet shirt">The Official Online Store</li> </ul> <p>...and it&rsquo;s completely <span>FREE!</span></p> </div> </div> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild"> <div class="buttonPlaceholder buttonPlaceholderPopUp"> <input type="button" value="Register" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </a> </fieldset> </div> <div id="LoginBox"> <h2>Login</h2> <div class="LoginFormBox"> <form id="WholesaleContact" title="Login" method="post" name="Login" action="/scripts/login.php?login=LfcTVLogin"> <fieldset> <div class="login-content"> <table class="lfcMembershipTable"> <tr class="LoginTableSpacing"> <th><label for="LoginUsernameId">Username</label></th> <td><input id="LoginUsernameId" class="InputLoginBox " type="text" name="username" /></td> <td class="formHelp">Email address</td> </tr> <tr class="LoginTableSpacing"> <th><label for="LoginPasswordId">Password</label></th> <td><input id="LoginPasswordId" class="InputLoginBox" type="password" name="password" /></td> <td class="formHelp"> <p><a href="/my-lfc/login/forgotten-password">Forgotten password?</a></p> </td> </tr> <tr class="remember LoginTableSpacing"> <th><label for="remember_me">Remember</label></th> <td style="vertical-align: middle;" class="rememberSideText formHelp" colspan="2"> <input type="checkbox" name="remember_me" class="remember_checkbox" /> <p class="rememberSideText formHelp">Remember your details on this machine?</p> </td> </tr> </table> </div> <div class="ArticleContent"> <div class="buttonPlaceholder"> <input type="submit" value="Login" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </div> <input type="hidden" name="referer" value="http://www.liverpoolfc.com/" /> </fieldset> </form> <script type="text/javascript"> $("#LoginUsernameId, #LoginPasswordId").on("keydown", function (evt) { if(evt.keyCode == 13) { $("#LoginForm").submit(); } }); <\/script> </div> </div></div>';
#
# var regMessagePopupStyling = '<style> /* header */ #cboxLoadedContent .registration-popup-message h1 { background: #E31B23; color: #FFF; padding: 0px 20px; line-height: 64px; font-size: 30px; } #colorbox #cboxClose { background: none; height: 58px; width: 50px; top: 3px!important; right: 3px; border: none; } #colorbox #cboxClose::after { content: "\\2716"; position: absolute; top: 0; left: 0; right: 0; line-height: 58px; text-align: center; font-size: 24px; text-indent: 0; color: #fff; } /* layout */ #cboxLoadedContent .registration-popup-message #not-logged-in-actions { width: 65%; padding: 20px; } #cboxLoadedContent .registration-popup-message #LoginBox { width: 35%; padding: 20px; } #cboxLoadedContent .registration-popup-message .login-content, #cboxLoadedContent .registration-popup-message .new-user-content { height: 250px; } #cboxLoadedContent .registration-popup-message h2 { border-bottom: 1px solid #DDD; margin: 0; padding: 2px 0 8px; } /* registration benefits */ #cboxLoadedContent .registration-popup-message .signUpMessage > p, #cboxLoadedContent .registration-popup-message .signUpMessage > ul { line-height: 36px; font-size: 16px; margin-bottom: 12px; } #cboxLoadedContent .registration-popup-message .signUpMessage > ul li.image-bullet { background-size: 24px; padding-left: 36px; } #cboxLoadedContent .registration-popup-message .signUpMessage > p { line-height: 36px; font-size: 16px; } /* login form */ #cboxLoadedContent .registration-popup-message #socialSignOn { margin: -10px 0 0; } #cboxLoadedContent .registration-popup-message .socialLogin { text-indent: -9999px; width: 40px; height: 40px; background-size: auto 40px; margin: 0 0 0 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable { clear: both; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th, #cboxLoadedContent .registration-popup-message .lfcMembershipTable td { float: left; width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable input { width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th { text-align: left; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable td.formHelp { text-align: right; padding: 5px 0; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember input { width: 19px; margin-right: 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember td { text-align: left; }<style>';
#
# var regMessageHeaderMarkup = '<div class="richtext"> <h1>GET MORE FROM LFC</h1> <p class="small-content">Register or log in now to access <strong>FREE</strong> benefits</p> <p class="medium-content">Log in now, or register to access a range of <strong>FREE</strong> benefits including videos and exclusive competitions.</p> <p class="buttons"> <a href="javascript:void(0);" class="main-button close">No thanks</a> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild" class="main-button">Yes, please!</a> </p></div>';
#
# var regMessageHeaderStyling = '<style> .header-message { background: #FFF; text-align: center; border-bottom: 2px solid #FFF; overflow: hidden; } .header-message::after { background: #C8C8C8; height: 6px; } .header-message > a.close { display: none; } .header-message .richtext a { text-decoration: none; } .header-message .buttons { margin: 10px 0; } .header-message .buttons a.main-button { margin: 0.2em 0.5em 0; padding: 0.8em 2em; } .header-message .buttons a.main-button.close { background: #FFF; color: #E31B23; border: 1px solid #E31B23; } .header-message p.medium-content { display: none; } @media screen and (min-width: 500px) { .header-message p.small-content { display: none; } .header-message p.medium-content { display: block; margin-bottom: 0; } .header-message .buttons { position: absolute; top: 0; right: 0; width: 11.5em; margin-bottom: 0; margin-right: 20px; } .header-message { min-height: 9em; } .header-message .richtext { margin-right: 14em; } .header-message .buttons a.main-button { display: block; margin: 0.6em 0; } }</style>';
#
# </script>
# <script type="text/javascript">
#
#  googletag.cmd.push(function() {
#
#   //general size mapping
#   var mapResMainRightOne = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
#   var mapResMainRightTwo = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# var mapResMainFixtures = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [468, 60]).
#    addSize([776, 0], [728, 90]).build();
# }
#
#
# 	 //general slots
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_ONE', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_ONE').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightOne).
# 				addService(googletag.pubads());
#
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_TWO', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_TWO').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightTwo).
# 				addService(googletag.pubads());
#
# if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
# googletag.defineSlot('/87687331/RES_MAIN_FIXTURES', [320, 50], 'div-gpt-ad-RES_MAIN_FIXTURES').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainFixtures).
# 				addService(googletag.pubads());
# }
#
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().enableSingleRequest();
#   googletag.enableServices();
#  });
# </script>
# <style type="text/css">
# .facebookButton{
# display:none!important;
# }
# </style>
# </link></head>
# <body class="main-site-layout sonata-bc template-standard_two_column standard-two-column">
# <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KCFJMVP" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KCFJMVP');
#             </script>
# <!-- End Google Tag Manager -->
# <div class="wrapper">
# <a id="page-top"></a>
# <header class="site-header" id="site-header" role="banner">
# <div class="site-header-inner">
# <div class="masthead">
# <ul class="account-links logged-out-only">
# <li class="subnav">
# <a>Log In</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="link-separator"> </li>
# <li class="subnav">
# <a>Register</a>
# <ul>
# <li class="first"> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=free" target="">Free Registration</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/membership" target="">Join Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=lfctvo" target="">Join LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not Sure?</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="account-links logged-in-only">
# <li>
# <a class="link-logout" href="https://www.liverpoolfc.com/scripts/logout.php" title="Logout">Log out</a>
# </li>
# <li class="link-separator"> </li>
# <li>
# <a class="link-my-lfc" href="https://www.liverpoolfc.com/my-lfc" title="My LFC">My LFC</a>
# </li>
# </ul>
# <div class="masthead-links" id="masthead-links">
# <ul class="more-menu">
# <li class="more-menu-link">
# <a>More</a>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul>
# <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
# </li>
# <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
# </li>
# <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
# </li>
# <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
# </li>
# <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
# </li>
# <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
# </li>
# <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
# </li>
# <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
# </li>
# <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="logo">
# <a class="logo-large" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-medium" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
# </a>
# <a class="logo-small" href="/" title="Home">
# <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo-small.png"/>
# </a></div>
# <a class="sponsor" href="//www.sc.com/en/" target="main-sponsor">
#     Main Club Sponsor: Standard Chartered
# </a>
# <div class="search">
# </div>
# <nav class="main-menu">
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="more-menu">
# <li class="more-menu-link">
# <a><span>More</span></a>
# <div class="icon-menu moreIconCss"></div>
# <ul>
# <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
# </li>
# <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
# </li>
# <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
# </li>
# <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
# </li>
# <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
# </li>
# <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
# </li>
# <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
# </li>
# </ul>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
# </li>
# <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
# </li>
# <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
# </li>
# <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
# </li>
# <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
# </li>
# <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
# </li>
# <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
# </li>
# <li class=""> <a href="/fans/competitions" target="">Competitions</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
# </li>
# <li class=""> <a href="/redtogether" target="">Red Together</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
# </li>
# <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
# </li>
# <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
# <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
# </li>
# <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
# </li>
# <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
# </li>
# </ul>
# </li>
# <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
# <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
# </li>
# <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
# </li>
# <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="my-account logged-out-only">
# <a href="https://www.liverpoolfc.com/my-lfc/login" title="Log in">LOG IN</a>
# <ul>
# <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
# </li>
# <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
# </li>
# <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
# </li>
# <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
# </li>
# <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
# </li>
# <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
# </li>
# </ul>
# </li>
# <li class="my-account logged-in-only">
# <a href="https://www.liverpoolfc.com/my-lfc" title="My LFC">MY LFC</a>
# </li>
# </ul>
# </nav>
# <ul class="social-links">
# <li class="vixlet">
# <a href="http://lfc.onelink.me/684654549?pid=LFC&amp;c=SOCIALICON" target="_blank" title="Go to The Official Liverpool Football Club Xtra page"></a>
# </li>
# <li class="facebook">
# <a href="https://www.facebook.com/LiverpoolFC" target="_blank" title="Go to The Official Liverpool Football Club Facebook page"></a>
# </li>
# <li class="twitter">
# <a href="https://twitter.com/lfc" target="_blank" title="Go to The Official Liverpool Football Club Twitter page"></a>
# </li>
# <li class="dugout">
# <a href="https://dugout.com/LiverpoolFC" target="_blank" title="Go to The Liverpool Football Club Dugout page"></a>
# </li>
# <li class="instagram">
# <a href="http://instagram.com/liverpoolfc/" target="_blank" title="Go to The Official Liverpool Football Club Instagram page"></a>
# </li>
# <li class="youtube">
# <a href="http://www.youtube.com/liverpoolfc?sub_confirmation=1" target="_blank" title="Go to The Official Liverpool Football Club Youtube page"></a>
# </li>
# <li class="alexa">
# <a href="https://www.amazon.co.uk/Liverpool-Football-Club-LFC-News/dp/B01N7WO4CD" target="_blank" title="Go to The Official Liverpool Football Club Alexa page"></a>
# </li>
# <li class="global">
# <a href="http://www.liverpoolfc.com/fans/lfc-around-the-globe" target="_blank" title="Go to The Official Liverpool Football Club Global page"></a>
# </li>
# </ul>
# ...
# </div>
# <div class="number">9</div>
# <div class="about">
# <div class="name">
# <span>Roberto</span> <span>Firmino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sadio-mane">
# <div class="img-wrap">
# <img alt="Sadio Mane" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125153_misc_general_500.jpeg"/>
# </div>
# <div class="number">10</div>
# <div class="about">
# <div class="name">
# <span>Sadio</span> <span>Mane</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/mohamed-salah">
# <div class="img-wrap">
# <img alt="Mohamed Salah" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125158_misc_general_500.jpeg"/>
# </div>
# <div class="number">11</div>
# <div class="about">
# <div class="name">
# <span>Mohamed</span> <span>Salah</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/takumi-minamino">
# <div class="img-wrap">
# <img alt="Takumi Minamino" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125154_misc_general_500.jpeg"/>
# </div>
# <div class="number">18</div>
# <div class="about">
# <div class="name">
# <span>Takumi</span> <span>Minamino</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/diogo-jota">
# <div class="img-wrap">
# <img alt="Diogo Jota" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125136_misc_general_500.jpeg"/>
# </div>
# <div class="number">20</div>
# <div class="about">
# <div class="name">
# <span>Diogo</span> <span>Jota</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/divock-origi">
# <div class="img-wrap">
# <img alt="Divock Origi" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125137_misc_general_500.jpeg"/>
# </div>
# <div class="number">27</div>
# <div class="about">
# <div class="name">
# <span>Divock</span> <span>Origi</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/harvey-elliott">
# <div class="img-wrap">
# <img alt="Harvey Elliott" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125147_misc_general_500.jpeg"/>
# </div>
# <div class="number">67</div>
# <div class="about">
# <div class="name">
# <span>Harvey</span> <span>Elliott</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.fixtures.listing.block.player" id="cms-block-17819">
# <div class="team-player-list">
# <h2>ON LOAN</h2>
# <ul>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-davies">
# <div class="img-wrap">
# <img alt="Ben Davies" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125132_misc_general_500.jpeg"/>
# </div>
# <div class="number">28</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Davies</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/rhys-williams">
# <div class="img-wrap">
# <img alt="Rhys Williams" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125151_misc_general_500.jpeg"/>
# </div>
# <div class="number">46</div>
# <div class="about">
# <div class="name">
# <span>Rhys</span> <span>Williams</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sheyi-ojo">
# <div class="img-wrap">
# <img alt="Sheyi Ojo" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg"/>
# </div>
# <div class="number">54</div>
# <div class="about">
# <div class="name">
# <span>Sheyi</span> <span>Ojo</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/ben-woodburn">
# <div class="img-wrap">
# <img alt="Ben Woodburn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125133_misc_general_500.jpeg"/>
# </div>
# <div class="number">58</div>
# <div class="about">
# <div class="name">
# <span>Ben</span> <span>Woodburn</span>
# </div>
# </div>
# </a>
# </li>
# <li class="team-player-list-item">
# <a href="/team/first-team/player/sepp-van-den-berg">
# <div class="img-wrap">
# <img alt="Sepp van den Berg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/14/thumb_113613_misc_general_500.jpeg"/>
# </div>
# <div class="number">72</div>
# <div class="about">
# <div class="name">
# <span>Sepp</span> <span>van</span> <span>den</span> <span>Berg</span>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-3194">
# <div class="container-block block-3194">
# </div>
# </div>
# </div>
# </div>
# <div class="rightCol">
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_ONE">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_ONE');
# </script>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-2919">
# <div class="container-block block-2919">
# <div class="cms-block cms-block-element" data-block-type="sonata.block.service.text" id="cms-block-3332">
# <style type="text/css">
#
#     .richtext.linkList a {
#         display: block;
#         padding: 6px;
#         margin-bottom: 0;
#         overflow: hidden;
#         padding-right: 30px;
#         position: relative;
#         color: #333;
#         font-weight: normal;
#     }
#
#     .richtext.linkList a:nth-child(odd) {
#         background: #F6F6F6;
#     }
#
#     .richtext.linkList a:after {
#         border-bottom: 8px solid transparent;
#         border-left: 12px solid #E31B23;
#         border-top: 8px solid transparent;
#         content: "";
#         display: inline-block;
#         height: 0;
#         position: absolute;
#         width: 0;
#         right: 10px;
#         margin-top: -8px;
#         top: 50%;
#     }
#
# @media screen and (max-width: 699px){
# .mainColInner .richtext img {
# width: 100%!important;
# height: auto!important;
# float: left!important;
# margin-bottom: 30px!important;
# }
#
# </style>
# <div class="richtext linkList">
# <h2>First Team Staff</h2>
# <a href="/team/first-team/staff/jurgen-klopp">Jürgen Klopp</a>
# <a href="/team/first-team/staff/peter-krawietz">Peter Krawietz</a>
# <a href="/team/first-team/staff/pepijn-lijnders">Pepijn Lijnders</a>
# <a href="/team/first-team/staff/john-achterberg">John Achterberg</a>
# <a href="/team/first-team/staff/jack-robinson">Jack Robinson</a>
# <a href="/team/first-team/staff/claudio-taffarel">Claudio Taffarel</a>
# <a href="/team/first-team/staff/vitor-matos">Vitor Matos</a>
# <a href="/team/first-team/staff/andreas-kornmayer">Andreas Kornmayer</a>
# <a href="/team/first-team/staff/dr-andreas-schlumberger">Dr Andreas Schlumberger</a>
# <a href="/team/first-team/staff/dr-jim-moxon">Dr Jim Moxon</a>
# <a href="/team/first-team/staff/lee-nobes">Lee Nobes</a>
# <a href="/team/first-team/staff/conall-murtagh">Dr Conall Murtagh</a>
# <a href="/team/first-team/staff/jordan-fairclough">Jordan Fairclough</a>
# <a href="/team/first-team/staff/paul-small">Paul Small </a>
# <a href="/team/first-team/staff/lee-radcliffe">Lee Radcliffe</a>
# <a href="/team/first-team/staff/brendan-mcilduff">Brendan McIlduff</a>
# <a href="/team/first-team/staff/david-rydings">Dr David Rydings</a>
# <a href="/team/first-team/staff/mona-nemmer">Mona Nemmer</a>
# <a href="/team/first-team/staff/mark-leyland">Mark Leyland</a>
# <a href="/team/first-team/staff/daniel-spearritt">Daniel Spearritt</a>
# <a href="/team/first-team/staff/greg-mathieson">Greg Mathieson</a>
# <a href="/team/first-team/staff/james-french">James French</a>
# <a href="/team/first-team/staff/chris-morgan">Chris Morgan</a>
# <a href="/team/first-team/staff/steve-lilley">Steve Lilley</a>
# <a href="/team/first-team/staff/joe-lewis">Joe Lewis</a>
# <a href="/team/first-team/staff/michelle-hudson">Michelle Hudson</a>
# <a href="/team/first-team/staff/motonori-watanabe">Motonori Watanabe</a>
# <a href="/team/first-team/staff/lena-aschenbrenner">Lena Aschenbrenner</a>
# </div>
# </div>
# <div class="cms-block cms-block-element" data-block-type="lfc.opta.standings.block.service" id="cms-block-3333">
# <section class="opta-wrapper" id="league-table">
# <opta-widget breakpoints="550" competition="8" competition_naming="full" data_detail="full" date_format="dddd D MMMM YYYY" default_nav="1" live="true" lose_before_draw="false" points_in_first_column="false" season="2021" show_crests="false" show_form="0" show_key="false" show_live="true" show_logo="false" show_relegation_average="false" show_title="false" side="combined" sorting="false" sport="football" team="14" team_naming="full" template="normal" widget="standings">
# </opta-widget>
# </section>
# </div>
# </div>
# </div>
# <div class="rightAd">
# <div id="div-gpt-ad-RES_MAIN_RIGHT_TWO">
# <script>
#      Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_TWO');
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer id="page-footer">
# <div class="upperBackground">
# <section class="partners">
# <div class="Primary">
# <a href="http://www.standardchartered.com/home/en/index.html?camp_id=liverpool_source=liverpoolfctv_medium=4" target="_blank" title="Standard Chartered">
# <img alt="Standard Chartered" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/25/thumb_124418_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nike.com/gb/" target="_blank" title="Nike">
# <img alt="Nike" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/09/thumb_108617_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.axa.com/?utm_source=liverpoolfc&amp;utm_medium=logo-partnership&amp;utm_campaign=lfc1819season" target="_blank" title="AXA">
# <img alt="AXA" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/74/thumb_73714_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.expedia.co.uk/" target="_blank" title="Expedia">
# <img alt="Expedia" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/21/thumb_120808_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# <div class="Secondary">
# <a href="http://www.carlsberg.com/" target="_blank" title="Carlsberg">
# <img alt="Carlsberg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/92/thumb_91236_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.scjohnson.com" target="_blank" title="SC Johnson">
# <img alt="SC Johnson" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126678_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.kodansha.com/" target="_blank" title="Kodansha">
# <img alt="Kodansha" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/23/thumb_122892_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.sonos.com" target="_blank" title="Sonos">
# <img alt="Sonos" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125033_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.easports.com/" target="_blank" title="EA Sports">
# <img alt="EA Sports" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125053_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.tourism-mauritius.mu" target="_blank" title="Mauritius">
# <img alt="Mauritius" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/18/thumb_117132_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.facebook.com/PredatorEnergyDrink/" target="_blank" title="Predator Energy Drink">
# <img alt="Predator Energy Drink" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126187_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://mg.co.uk/" target="_blank" title="MG">
# <img alt="MG" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125832_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.hollyfrontier.com/home/default.aspx" target="_blank" title="Holly Frontier">
# <img alt="Holly Frontier" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/11/thumb_110194_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.thinkmarkets.com/uk/" target="_blank" title="ThinkMarkets">
# <img alt="ThinkMarkets" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125313_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.quorn.com/" target="_blank" title="Quorn">
# <img alt="Quorn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125055_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.mondelezinternational.com/" target="_blank" title="Cadbury ROW">
# <img alt="Cadbury ROW" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126098_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.acronis.com/en-gb/" target="_blank" title="Acronis">
# <img alt="Acronis" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/02/thumb_101725_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://www.nipponham.co.jp/eng/" target="_blank" title="NH Foods">
# <img alt="NH Foods" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/86/thumb_85085_partnerlogo_partner_footer.png"/>
# </a>
# <a href="https://uk.joiebaby.com/liverpoolfc/" target="_blank" title="Joie Baby">
# <img alt="Joie Baby" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/41/thumb_40979_partnerlogo_partner_footer.png"/>
# </a>
# </div>
# </section>
# </div>
# <div class="lowerBackground">
# <section class="bottomFooter">
# <div class="footerCrest">
# </div>
# <div class="footerCrestLeft">
# </div>
# <div class="footerText">
# <div class="footer-middleBottom">
# <a href="http://www.liverpoolfc.com/legal/privacy-policy" title="Go to Privacy Policy">Privacy Policy</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/terms-and-conditions" title="Go to Terms and Conditions">Terms and Conditions</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/anti-slavery" title="Go to Anti-Slavery">Anti-Slavery</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/legal/cookies" title="Go to Cookies">Cookies</a> <span>|</span>
# <a href="https://faq.liverpoolfc.com/portal/home" title="Go to Help">Help</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/browser-support" title="Go to Browser Support">Browser Support</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/corporate/rss-feeds" title="Go to RSS Feeds">RSS Feeds</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/contactus" title="Go to Contact Us">Contact Us</a> <span>|</span>
# <a href="http://www.liverpoolfc.com/accessible/accessible" title="Go to Accessibility">Accessibility</a> <br/>
# </div>
# <div class="footer-left">
#             © Copyright 2021 The Liverpool Football Club and Athletic Grounds Limited. All rights reserved.
#         </div>
# <div class="footer-right">
#             Developed and maintained by the LFC Technology and Transformation Team
#         </div>
# <div class="footer-middle">
#             Match Statistics supplied by Opta Sports Data Limited. Reproduced under licence from Football DataCo Limited. All rights reserved.
#         </div>
# </div>
# </section></div>
#
# </footer></div>
#
#
# <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/scripts.min.js"></script>
# <script src="https://secure.widget.cloud.opta.net/v3/v3.opta-widgets.js"></script>
# <script>
#             var opta_settings = {
#                    subscription_id: 'da747e372c352a82f3dd6174084858fd',
#                    language: 'en_GB',
#                    timezone: 'Europe/London',
#                    opta_tracking: false
#             };
#         </script>
# <style>
#                             .team-player-list-item .name > span {
# width:40px;
# }
#                         </style>
# <!-- monitoring:3e9fda56df2cdd3b039f189693ab7844fbb2d4f6 -->
# </body>
# </html>

# %%
list(html.children)
# Out:
# [' ',
#  '<![endif]',
#  '\n',
#  <script>
#      (function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#
#      if (window.history.replaceState && window.location.href.slice(-1) === '#') {
#          window.history.replaceState({},document.title,window.location.href.slice(0,-1));
#      }
#  </script>,
#  '\n',
#  <head>
#  <!-- OneTrust Cookies Consent Notice start for liverpoolfc.com -->
#  <script src="https://cdn-ukwest.onetrust.com/consent/aa158886-777d-463e-8082-e384a26718f6/OtAutoBlock.js" type="text/javascript"></script>
#  <script charset="UTF-8" data-domain-script="aa158886-777d-463e-8082-e384a26718f6" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  function OptanonWrapper() { }
#  </script>
#  <link href="https://d3j2s6hdd6a7rg.cloudfront.net/css/cookie-consent-5.css" rel="stylesheet" type="text/css"/>
#  <!-- OneTrust Cookies Consent Notice end for liverpoolfc.com -->
#  <title>Liverpool FC - Team</title>
#  <meta content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" name="keywords"/>
#  <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." name="description"/>
#  <meta content="index, follow" name="robots"/>
#  <meta content="Liverpool FC" property="og:site_name"/>
#  <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." property="og:description"/>
#  <meta content="article" property="og:type"/>
#  <meta content="67920382572" property="fb:pages"/>
#  <meta content="Liverpool FC - Team" property="og:title"/>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta charset="utf-8"/>
#  <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/favicon.png" rel="shortcut icon" type="image/png"/>
#  <link href="https://secure.widget.cloud.opta.net/v3/css/v3.football.opta-widgets.css" rel="stylesheet"/>
#  <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles.css" rel="stylesheet">
#  <!--[if  (lt IE 9) & (!IEMobile)]>
#              <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/css/styles-ie8.css" />
#          <![endif]-->
#  <!--[if lt IE 9]>
#              <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie8.min.js"></script>
#          <![endif]-->
#  <!--[if IE 9]>
#          <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/polyfills-ie9.min.js"></script>
#          <![endif]-->
#  <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/base.js"></script>
#  <link href="//cdn.dynamicyield.com" rel="dns-prefetch"/>
#  <link href="//st.dynamicyield.com" rel="dns-prefetch"/>
#  <link href="//rcom.dynamicyield.com" rel="dns-prefetch"/>
#  <script>
#
#  window.DY = window.DY || {};
#  DY.recommendationContext = {type: 'OTHER'};
#
#  </script>
#  <script src="//cdn.dynamicyield.com/api/8772718/api_dynamic.js" type="text/javascript"></script>
#  <script src="//cdn.dynamicyield.com/api/8772718/api_static.js" type="text/javascript"></script>
#  <style type="text/css">
#  a.post-next.post-next-top {
#     display:none;
#  }
#
#  div.post-next.post-next-bottom {
#     display:none;
#  }
#  </style>
#  <script>
#   // create Lfc element with GPT command queue
#   var Lfc = Lfc || {};
#   Lfc.gtmAdQueue = Lfc.gtmAdQueue || [];
#
#   // Load GPT asynchronously
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
#  </script>
#  <script>
#  $( document ).ready(function() {
#
#  $('.masthead .link-login a').attr('href', 'https://www.liverpoolfc.com/my-lfc/login?fragment=&referer='+(document.URL));
#
#  // remove age restricted footer logos
#  var checkString = window.location.href;
#  if( checkString.indexOf("academy") !== -1 || checkString.indexOf("under-23") !== -1 || checkString.indexOf("under-18") !== -1 || checkString.indexOf("soccerschools") !== -1  || checkString.indexOf("soccer-schools") !== -1  || checkString.indexOf("u23") !== -1  || checkString.indexOf("u18") !== -1){
#  $('a[title="Carlsberg"], a[title="Betvictor"], a[title="Liverpool Vodka"], a[title="Draft Kings"], a[title="1XBET"]').remove();
#  }
#
#  if( checkString.indexOf("/women/") !== -1 || checkString.indexOf("/news/women") !== -1 || checkString.indexOf("/team/women") !== -1 || checkString.indexOf("/fans/liverpool-fc-women") !== -1) {
#      $('a[title="Western Union"], a[title="Carlsberg"],a[title="MG"],a[title="Nivea"],a[title="Falken Tyres"],a[title="TigerWit"],a[title="EA Sports"],a[title="Chaokoh"],a[title="NH Foods"],a[title="Lavazza"],a[title="Petro-Canada"],a[title="Liverpool Vodka"],a[title="Levis"],a[title="iugis"],a[title="Mitel"],a[title="Verbier"],a[title="Tribus"],a[title="Cadbury UK"],a[title="Cadbury ROW"],a[title="Holly Frontier"],a[title="Quorn"],a[title="Mauritius"],a[title="Acronis"]').remove();
#  }
#
#  // remove link
#  $('a[title="1XBET"]'). removeAttr("href");
#
#  // HOT FIX - REMOVING MORE MENU FROM INTERNATIONAL SITES
#  var urlHostName = window.location.hostname;
#  if (urlHostName.indexOf('indonesia') !== -1 || urlHostName.indexOf('thailand') !== -1 || urlHostName.indexOf('japan') !== -1) {
#  $('.main-menu ul.more-menu').hide();
#  }
#
#            })
#  </script>
#  <style>
#  .site-header-inner .masthead .masthead-links .more-menu ul li a {
#    background: none!important;
#  }
#  .site-header-inner .social-links li.skype {
#    display: none;
#  }
#  .vixlet, .dugout {
#     display:none !important;
#  }
#  .video-error__content {
#  padding-top:3%!important;
#  }
#  .video-error__listing {
#  margin:15px 0!important;
#  }
#
#  .video-error__subtitle-mobile,
#  .video-error__registered {
#  color:white!important;
#  }
#
#  .video-player-embeddable .video-error--embed .video-error__listing-group ul li {
#  margin:0 0 5px 0!important;
#  }
#  .video-error__call-to-action a.js-subscribe-button {
#  font-size:0.8em!important;
#  background:white!important;
#  text-transform:uppercase!important;
#  }
#  .video-error__call-to-action a.js-subscribe-button:hover {
#  color:#e31b23!important;
#  }
#
#  @media only screen and (min-width: 551px) {
#  .video-error__subtitle-mobile {
#  margin:10px 0!important;
#  padding:0!important;
#  }
#  }
#
#  @media only screen and (min-width: 775px) and (max-width: 975px) {
#  .video-error__listing-group {
#  display:none!important;
#  }
#  }
#
#  /*@media screen and (min-width: 700px) {
#  .site-header-inner .main-menu .more-menu .more-menu-link>ul li {
#  display:block !important;
#  }
#  }*/
#
#  @media screen and (min-width: 1000px) {
#  .site-header-inner .masthead .masthead-links .more-menu.noLogin ul {
#  top: 100%!important;
#  }
#  }
#
#  /* IE ONLY */
#  @media screen\0 {
#  .video-player-embeddable .video .shard-overlay {position: absolute !important;}
#  }
#
#  .home .featured-news-carousel .media-image-wrap .indent {text-indent: -99999px;}
#
#  .dy_unit .dy-sliding-drawer-container{bottom: 25%;}
#  </style>
#  <script>
#  var Lfc = Lfc || {};
#
#  Lfc.messagesConfig = {
#      messages: [
#
#          // ANDROID APP BANNER
#          {
#              id: 'android-app-banner',
#              maximumDisplayCount: 1,
#              displayCondition: function() {
#                  // don't show on non-Android devices
#                  if (navigator.userAgent.match(/Android/i) === null || navigator.userAgent.indexOf('Windows') > -1) {
#                      return false;
#                  }
#                  // only show on home and news pages
#                  var pathStart = window.location.pathname.substr(0,6);
#                  if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                      return false;
#                  }
#                  // only show if valid app id meta tag exists
#                  //  (e.g. <meta name="google-play-app" content="app-id=tv.liverpoolfc">)
#                  var $meta = $('meta[name="google-play-app"]');
#                  if ($meta.length > 0) {
#                      var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                      if (appId) {
#                          return true;
#                      }
#                  }
#              },
#              content: function() {
#                  // get app id from meta tag
#                  var $meta = $('meta[name="google-play-app"]');
#                  if ($meta.length > 0) {
#                      var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                      if (appId) {
#                          var linkUrl = 'https://play.google.com/store/apps/details?id=' + appId[1] +
#                                  '&referrer=utm_source%3DWebsite%26utm_medium%3DHEADER_APP_CARD_MAIN_SITE%26utm_content%3DDigital%26utm_campaign%3DClub%2520App';
#
#                          return '<div id="android-app-banner">' +
#                              '<a href="javascript:void(0);" class="close">&times;</a>' +
#                              '<a href="' + linkUrl + '">' +
#                                  '<span class="app-icon"></span>' +
#                                  '<div class="app-info">' +
#                                      '<strong>LFC Official App</strong>' +
#                                      '<span>Liverpool Football Club</span>' +
#                                      '<span>FREE in Google Play</span>' +
#                                  '</div>' +
#                                  '<span class="view">VIEW</span>' +
#                              '</a>' +
#                          '</div>';
#                      }
#                  }
#              },
#              style: "styled-header"
#          },
#
#          // REGISTRATION POP-UP
#          {
#              id : 'registration-popup',
#              minimumInterval : 10*24*60*60*1000, // 10 days = 10*24*60*60*1000
#              displayCondition: function() {
#  // temp fix to not display
#  return false;
#                  // don't show to logged in users
#                  if (Lfc.Login.isLoggedIn()) {
#                      Lfc.Cookie.set("registration-popup-logout-time", "logged in");
#                      return false;
#                  }
#                  // don't show immediately after logout -- wait 1 day
#                  var now = (new Date()).getTime(),
#                      logOutTime = Lfc.Cookie.get("registration-popup-logout-time");
#
#                  if (logOutTime == "logged in") {
#                      // immediately after logout, store timestamp
#                      Lfc.Cookie.set("registration-popup-logout-time", now);
#                      return false;
#                  } else {
#                      // if one day has not yet passed since first known logged out time, don't show
#                      if (logOutTime && (now - logOutTime < 24*60*60*1000)) { // 1 day = 24*60*60*1000
#                          return false;
#                      };
#                  }
#                  // only show on home and news pages
#                  var pathStart = window.location.pathname.substr(0,6);
#                  if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                      return false;
#                  }
#                  // only show to "A" group people
#                  var abGroup = Lfc.Cookie.getABGroup("registration-popup");
#                  if (!abGroup) {
#                      abGroup = Lfc.Cookie.setABGroup("registration-popup");
#                      dataLayer.push({'event': 'registration-popup-ab-assignment', 'abGroup': abGroup });
#                  }
#                  return abGroup === "A";
#              },
#              onShow: function() {
#                  dataLayer.push({'event': 'registration-popup-shown'});
#              },
#              content : function() {
#                  if ($(window).width() < 1000) {
#                      // header message
#                      return regMessageHeaderMarkup + regMessageHeaderStyling;
#                  } else {
#                      // big popup with login
#                      return regMessagePopupMarkup + regMessagePopupStyling;
#                  }
#              },
#              style: function() {
#                  if ($(window).width() < 1000) {
#                      return 'default-header';
#                  } else {
#                      return 'popup';
#                  }
#              }
#          },
#      ],
#      minimumMessageInterval : 60*60*1000, // 1 hour = 60*60*1000
#  }
#
#
#  // REGISTRATION POPUP MARKUP & STYLING
#  var regMessagePopupMarkup = '<div class="registration-popup-message"> <h1>GET MORE FROM LFC.</h1> <div id="not-logged-in-actions"> <h2>Register and get immediate access to:</h2> <fieldset class="reg-signup"> <div class="new-user-content"> <div class="signUpMessage registerText" style="line-height: 24px;"> <ul> <li class="image-bullet video">Free LFC videos</li> <li class="image-bullet match">Listen to live match commentary</li> <li class="image-bullet win">Exclusive competitions</li> <li class="image-bullet news">Receive the official club newsletter - All in Red</li> <li class="image-bullet forum">Join the conversation on the official LFC forums</li> <li class="image-bullet shirt">The Official Online Store</li> </ul> <p>...and it&rsquo;s completely <span>FREE!</span></p> </div> </div> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild"> <div class="buttonPlaceholder buttonPlaceholderPopUp"> <input type="button" value="Register" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </a> </fieldset> </div> <div id="LoginBox"> <h2>Login</h2> <div class="LoginFormBox"> <form id="WholesaleContact" title="Login" method="post" name="Login" action="/scripts/login.php?login=LfcTVLogin"> <fieldset> <div class="login-content"> <table class="lfcMembershipTable"> <tr class="LoginTableSpacing"> <th><label for="LoginUsernameId">Username</label></th> <td><input id="LoginUsernameId" class="InputLoginBox " type="text" name="username" /></td> <td class="formHelp">Email address</td> </tr> <tr class="LoginTableSpacing"> <th><label for="LoginPasswordId">Password</label></th> <td><input id="LoginPasswordId" class="InputLoginBox" type="password" name="password" /></td> <td class="formHelp"> <p><a href="/my-lfc/login/forgotten-password">Forgotten password?</a></p> </td> </tr> <tr class="remember LoginTableSpacing"> <th><label for="remember_me">Remember</label></th> <td style="vertical-align: middle;" class="rememberSideText formHelp" colspan="2"> <input type="checkbox" name="remember_me" class="remember_checkbox" /> <p class="rememberSideText formHelp">Remember your details on this machine?</p> </td> </tr> </table> </div> <div class="ArticleContent"> <div class="buttonPlaceholder"> <input type="submit" value="Login" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </div> <input type="hidden" name="referer" value="http://www.liverpoolfc.com/" /> </fieldset> </form> <script type="text/javascript"> $("#LoginUsernameId, #LoginPasswordId").on("keydown", function (evt) { if(evt.keyCode == 13) { $("#LoginForm").submit(); } }); <\/script> </div> </div></div>';
#
#  var regMessagePopupStyling = '<style> /* header */ #cboxLoadedContent .registration-popup-message h1 { background: #E31B23; color: #FFF; padding: 0px 20px; line-height: 64px; font-size: 30px; } #colorbox #cboxClose { background: none; height: 58px; width: 50px; top: 3px!important; right: 3px; border: none; } #colorbox #cboxClose::after { content: "\\2716"; position: absolute; top: 0; left: 0; right: 0; line-height: 58px; text-align: center; font-size: 24px; text-indent: 0; color: #fff; } /* layout */ #cboxLoadedContent .registration-popup-message #not-logged-in-actions { width: 65%; padding: 20px; } #cboxLoadedContent .registration-popup-message #LoginBox { width: 35%; padding: 20px; } #cboxLoadedContent .registration-popup-message .login-content, #cboxLoadedContent .registration-popup-message .new-user-content { height: 250px; } #cboxLoadedContent .registration-popup-message h2 { border-bottom: 1px solid #DDD; margin: 0; padding: 2px 0 8px; } /* registration benefits */ #cboxLoadedContent .registration-popup-message .signUpMessage > p, #cboxLoadedContent .registration-popup-message .signUpMessage > ul { line-height: 36px; font-size: 16px; margin-bottom: 12px; } #cboxLoadedContent .registration-popup-message .signUpMessage > ul li.image-bullet { background-size: 24px; padding-left: 36px; } #cboxLoadedContent .registration-popup-message .signUpMessage > p { line-height: 36px; font-size: 16px; } /* login form */ #cboxLoadedContent .registration-popup-message #socialSignOn { margin: -10px 0 0; } #cboxLoadedContent .registration-popup-message .socialLogin { text-indent: -9999px; width: 40px; height: 40px; background-size: auto 40px; margin: 0 0 0 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable { clear: both; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th, #cboxLoadedContent .registration-popup-message .lfcMembershipTable td { float: left; width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable input { width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th { text-align: left; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable td.formHelp { text-align: right; padding: 5px 0; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember input { width: 19px; margin-right: 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember td { text-align: left; }<style>';
#
#  var regMessageHeaderMarkup = '<div class="richtext"> <h1>GET MORE FROM LFC</h1> <p class="small-content">Register or log in now to access <strong>FREE</strong> benefits</p> <p class="medium-content">Log in now, or register to access a range of <strong>FREE</strong> benefits including videos and exclusive competitions.</p> <p class="buttons"> <a href="javascript:void(0);" class="main-button close">No thanks</a> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild" class="main-button">Yes, please!</a> </p></div>';
#
#  var regMessageHeaderStyling = '<style> .header-message { background: #FFF; text-align: center; border-bottom: 2px solid #FFF; overflow: hidden; } .header-message::after { background: #C8C8C8; height: 6px; } .header-message > a.close { display: none; } .header-message .richtext a { text-decoration: none; } .header-message .buttons { margin: 10px 0; } .header-message .buttons a.main-button { margin: 0.2em 0.5em 0; padding: 0.8em 2em; } .header-message .buttons a.main-button.close { background: #FFF; color: #E31B23; border: 1px solid #E31B23; } .header-message p.medium-content { display: none; } @media screen and (min-width: 500px) { .header-message p.small-content { display: none; } .header-message p.medium-content { display: block; margin-bottom: 0; } .header-message .buttons { position: absolute; top: 0; right: 0; width: 11.5em; margin-bottom: 0; margin-right: 20px; } .header-message { min-height: 9em; } .header-message .richtext { margin-right: 14em; } .header-message .buttons a.main-button { display: block; margin: 0.6em 0; } }</style>';
#
#  </script>
#  <script type="text/javascript">
#
#   googletag.cmd.push(function() {
#
#    //general size mapping
#    var mapResMainRightOne = googletag.sizeMapping().
#     addSize([0, 0], [320, 50]).
#     addSize([500, 0], [486, 60]).
#     addSize([758, 0], [300, 250]).build();
#
#    var mapResMainRightTwo = googletag.sizeMapping().
#     addSize([0, 0], [320, 50]).
#     addSize([500, 0], [486, 60]).
#     addSize([758, 0], [300, 250]).build();
#
#  if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
#  var mapResMainFixtures = googletag.sizeMapping().
#     addSize([0, 0], [320, 50]).
#     addSize([500, 0], [468, 60]).
#     addSize([776, 0], [728, 90]).build();
#  }
#
#
#  	 //general slots
#  		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_ONE', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_ONE').
#  				setTargeting("test","true").
#  				defineSizeMapping(mapResMainRightOne).
#  				addService(googletag.pubads());
#
#  		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_TWO', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_TWO').
#  				setTargeting("test","true").
#  				defineSizeMapping(mapResMainRightTwo).
#  				addService(googletag.pubads());
#
#  if (window.location.pathname.indexOf('/match/2020-21/first-team/fixtures-and-results') !== -1) {
#  googletag.defineSlot('/87687331/RES_MAIN_FIXTURES', [320, 50], 'div-gpt-ad-RES_MAIN_FIXTURES').
#  				setTargeting("test","true").
#  				defineSizeMapping(mapResMainFixtures).
#  				addService(googletag.pubads());
#  }
#
#    googletag.pubads().collapseEmptyDivs();
#    googletag.pubads().enableSingleRequest();
#    googletag.enableServices();
#   });
#  </script>
#  <style type="text/css">
#  .facebookButton{
#  display:none!important;
#  }
#  </style>
#  </link></head>,
#  '\n',
#  <body class="main-site-layout sonata-bc template-standard_two_column standard-two-column">
#  <!-- Google Tag Manager -->
#  <noscript>
#  <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KCFJMVP" style="display:none;visibility:hidden" width="0"></iframe>
#  </noscript>
#  <script>
#                  (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-KCFJMVP');
#              </script>
#  <!-- End Google Tag Manager -->
#  <div class="wrapper">
#  <a id="page-top"></a>
#  <header class="site-header" id="site-header" role="banner">
#  <div class="site-header-inner">
#  <div class="masthead">
#  <ul class="account-links logged-out-only">
#  <li class="subnav">
#  <a>Log In</a>
#  <ul>
#  <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
#  </li>
#  <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
#  </li>
#  <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
#  </li>
#  <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
#  </li>
#  <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
#  </li>
#  </ul>
#  </li>
#  <li class="link-separator"> </li>
#  <li class="subnav">
#  <a>Register</a>
#  <ul>
#  <li class="first"> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=free" target="">Free Registration</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">Tickets</a>
#  </li>
#  <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/membership" target="">Join Membership</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/join/user-details?user_type=lfctvo" target="">Join LFCTV GO</a>
#  </li>
#  <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not Sure?</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="account-links logged-in-only">
#  <li>
#  <a class="link-logout" href="https://www.liverpoolfc.com/scripts/logout.php" title="Logout">Log out</a>
#  </li>
#  <li class="link-separator"> </li>
#  <li>
#  <a class="link-my-lfc" href="https://www.liverpoolfc.com/my-lfc" title="My LFC">My LFC</a>
#  </li>
#  </ul>
#  <div class="masthead-links" id="masthead-links">
#  <ul class="more-menu">
#  <li class="more-menu-link">
#  <a>More</a>
#  <ul>
#  <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
#  </li>
#  <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
#  </li>
#  <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
#  </li>
#  <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
#  </li>
#  <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
#  </li>
#  <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
#  </li>
#  <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul>
#  <li class="first"> <a href="https://video.liverpoolfc.com/" target="">LFCTV GO</a>
#  </li>
#  <li class=""> <a href="http://hospitality.liverpoolfc.com" target="">MATCH HOSPITALITY</a>
#  </li>
#  <li class="bp-min-large-more-min-xlarge-primary"> <a href="http://www.liverpoolfc.com/membership/home" target="">MEMBERSHIP</a>
#  </li>
#  <li class=""> <a href="http://foundation.liverpoolfc.com" target="">FOUNDATION</a>
#  </li>
#  <li class=""> <a href="http://stadiumtours.liverpoolfc.com">STADIUM TOURS</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://events.liverpoolfc.com" target="">MEETING &amp; EVENTS</a>
#  </li>
#  <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="">e ACADEMY</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://store.liverpoolfc.com">SHOP</a>
#  </li>
#  <li class="bp-more-only"> <a href="http://bootroom.liverpoolfc.com">BOOT ROOM</a>
#  </li>
#  <li class="bp-more-only last"> <a href="http://www.liverpoolfc.com/lfcevents" target="">LFC EVENTS</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="logo">
#  <a class="logo-large" href="/" title="Home">
#  <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
#  </a>
#  <a class="logo-medium" href="/" title="Home">
#  <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo.png"/>
#  </a>
#  <a class="logo-small" href="/" title="Home">
#  <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/images/logo-small.png"/>
#  </a></div>
#  <a class="sponsor" href="//www.sc.com/en/" target="main-sponsor">
#      Main Club Sponsor: Standard Chartered
#  </a>
#  <div class="search">
#  </div>
#  <nav class="main-menu">
#  <ul>
#  <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
#  </li>
#  <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
#  </li>
#  <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
#  </li>
#  <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
#  </li>
#  <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
#  </li>
#  <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
#  </li>
#  <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
#  </li>
#  <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
#  </li>
#  <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
#  </li>
#  <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
#  </li>
#  <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
#  </li>
#  <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
#  </li>
#  <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
#  </li>
#  <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
#  </li>
#  <li class=""> <a href="/fans/competitions" target="">Competitions</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
#  </li>
#  <li class=""> <a href="/redtogether" target="">Red Together</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
#  </li>
#  <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
#  </li>
#  <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
#  </li>
#  <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
#  </li>
#  <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
#  </li>
#  <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
#  <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
#  </li>
#  <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  <ul class="more-menu">
#  <li class="more-menu-link">
#  <a><span>More</span></a>
#  <div class="icon-menu moreIconCss"></div>
#  <ul>
#  <li class="bp-medium-more-only log-out-menu-link first"> <a href="https://www.liverpoolfc.com/scripts/logout.php" target="">LOG OUT</a>
#  </li>
#  <li class="active-news"> <a href="https://www.liverpoolfc.com/news" target="">NEWS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/news?categoryId=186" target="">First Team</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=196" target="">Women</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=201" target="">Academy</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=191" target="">Ticket News</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Community</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=181" target="">Announcements</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/news?categoryId=176" target="">Media Watch</a>
#  </li>
#  <li class="last"> <a href="https://nesn.com/liverpool-fc/" target="_blank">LFC on NESN</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://matchcentre.liverpoolfc.com?utm_medium=site-link-liverpoolfc.com&amp;utm_source=home-top-nav-bar&amp;utm_campaign=med-match-centre-2021" target="">Match Centre</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match" target="">FIXTURES</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/match/2021-22/men/fixtures-and-results" target="">Fixtures and Results</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-table" target="">League Table</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/premier-league-calendar" target="">Premier League Calendar</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/women/fixtures-and-results" target="">Liverpool FC Women</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u23s/fixtures-and-results" target="">U23S</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/2021-22/u18s/fixtures-and-results" target="">U18S</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">Opta Stats</a>
#  </li>
#  <li class=""> <a href="https://reachsportshop.com/team/liverpool/" target="_blank">Programme and Magazine</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">App Match Notifications</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/tickets" target="">TICKETS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">Tickets Availability</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/away-travel" target="">Away Travel</a>
#  </li>
#  <li class=""> <a href="https://hospitality.liverpoolfc.com/" target="_blank">Match Hospitality</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">HOW TO BUY TICKETS</a>
#  </li>
#  <li class=""> <a href="https://tickets.tygit.com/u/r/l/Liverpool-FC-Womens" target="_blank">Liverpool FC Women</a>
#  </li>
#  <li class=""> <a href="/corporate/partners/official-match-breaks-hospitality" target="">Official Match Breaks Hospitality</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/tickets/ticket-touting" target="">Ticket Touting</a>
#  </li>
#  </ul>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/team/first-team" target="">TEAM</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/team/first-team" target="">First Team</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/team/women" target="">Women</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/team/academy" target="">Academy</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/behind-closed-doors/home" target="">ANFIELD</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/return-of-supporters-to-anfield" target="">Return of Supporters</a>
#  </li>
#  <li class=""> <a href="https://events.liverpoolfc.com/events/concerts" target="">CONCERTS</a>
#  </li>
#  <li class=""> <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">Stadium Tours</a>
#  </li>
#  <li class=""> <a href="https://events.liverpoolfc.com/" target="_blank">Meetings &amp; Events</a>
#  </li>
#  <li class=""> <a href="https://bootroom.liverpoolfc.com/" target="_blank">Bootroom Sports Cafe</a>
#  </li>
#  <li class=""> <a href="https://championswall.liverpoolfc.com/BRICS/APP/Store/#/LFCWALL/home" target="_blank">Champions Wall</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/local-residents" target="">Local Residents</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/anfieldroadexpansion" target="">Anfield Road</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">FANS</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/membership" target="">Membership</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/watch" target="">LFCTV</a>
#  </li>
#  <li class=""> <a href="https://forums.liverpoolfc.com/" target="_blank">Message Boards</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/official-lfc-supporters-clubs" target="">Official Supporters Clubs</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/social-media/lfc-on-social-media" target="">Social Media</a>
#  </li>
#  <li class=""> <a href="https://open.spotify.com/playlist/78lxjrcD1yI1KnTcx4zY9d" target="_blank">LFC ON SPOTIFY</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">Fan Experience</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/apps-and-games" target="">Apps &amp; Games</a>
#  </li>
#  <li class=""> <a href="/fans/competitions" target="">Competitions</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/supporters-committee/supporters-committee-home" target="">Supporters Committee</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/lfc-supporter-liaison-officer/about-the-supporters-liaison-officer" target="">Supporter Liaison Officer</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/safeguarding" target="">Safeguarding</a>
#  </li>
#  <li class=""> <a href="/redtogether" target="">Red Together</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/accessibility-hub" target="">Accessibility Hub</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/kopkids" target="_blank">Kop Kids</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://store.liverpoolfc.com/" target="">SHOP</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://store.liverpoolfc.com" target="_blank">ONLINE STORE</a>
#  </li>
#  <li class=""> <a href="https://eacademy.liverpoolfc.com/" target="_blank">E ACADEMY</a>
#  </li>
#  <li class=""> <a href="https://picturestore.liverpoolfc.com/LFC" target="_blank">LFC PICTURE STORE</a>
#  </li>
#  <li class=""> <a href="https://store.liverpoolfc.com/stores/finder" target="_blank">CLUB STORES</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/corporate/become-a-wholesale-partner" target="">Wholesale Partners</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary"> <a href="https://www.liverpoolfc.com/corporate/directors" target="">CLUB</a> <ul class="menu_level_1">
#  <li class="first"> <a href="https://www.liverpoolfc.com/history/honours" target="">Honours</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/history" target="">History</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/hillsborough" target="">Hillsborough</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/heysel" target="">Heysel</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/directors" target="">Corporate Information</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/partners" target="">Partners</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/charter" target="">Club Charter</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/theredway" target="">Sustainability</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/brand-protection" target="">Brand Protection</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/corporate/anti-slavery" target="">Anti-Slavery</a>
#  </li>
#  <li class=""> <a href="https://nesn.com/" target="_blank">NESN.com</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/fans/fan-experience" target="">Fan Experience</a>
#  </li>
#  <li class="last"> <a href="https://recruitment.liverpoolfc.com/" target="">Jobs At LFC</a>
#  </li>
#  </ul>
#  </li>
#  <li class="bp-medium-more-min-large-primary last"> <a href="https://help.liverpoolfc.com" target="_blank">HELP</a> <ul class="menu_level_1">
#  <li class="bp-medium-more-min-large-primary first"> <a href="https://faq.liverpoolfc.com/portal/home" target="_blank">FAQs</a>
#  </li>
#  <li class=""> <a href="https://faq.liverpoolfc.com/portal/kb/articles/contact-us" target="_blank">CONTACT</a>
#  </li>
#  <li class="last"> <a href="https://www.liverpoolfc.com/atoz" target="">A - Z</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </li>
#  <li class="my-account logged-out-only">
#  <a href="https://www.liverpoolfc.com/my-lfc/login" title="Log in">LOG IN</a>
#  <ul>
#  <li class="link-login first"> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com" target="">My LFC</a>
#  </li>
#  <li class=""> <a href="https://ticketing.liverpoolfc.com/ClientRequiredFallback.aspx?view=Login&amp;next=%2fCrmDetails.aspx%3f_ga%3d2.72318992.2042741793.1596366965-460835212.1550476886" target="">Tickets</a>
#  </li>
#  <li class=""> <a href="https://store.liverpoolfc.com/customer/account/login/" target="">Online Store</a>
#  </li>
#  <li class=""> <a href="https://members.liverpoolfc.com/login" target="">Membership</a>
#  </li>
#  <li class=""> <a href="https://www.liverpoolfc.com/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">LFCTV GO</a>
#  </li>
#  <li class="separator last"> <a href="http://www.liverpoolfc.com/loginhelp" target="">Not sure?</a>
#  </li>
#  </ul>
#  </li>
#  <li class="my-account logged-in-only">
#  <a href="https://www.liverpoolfc.com/my-lfc" title="My LFC">MY LFC</a>
#  </li>
#  </ul>
#  </nav>
#  <ul class="social-links">
#  <li class="vixlet">
#  <a href="http://lfc.onelink.me/684654549?pid=LFC&amp;c=SOCIALICON" target="_blank" title="Go to The Official Liverpool Football Club Xtra page"></a>
#  </li>
#  <li class="facebook">
#  <a href="https://www.facebook.com/LiverpoolFC" target="_blank" title="Go to The Official Liverpool Football Club Facebook page"></a>
#  </li>
#  <li class="twitter">
# ...
#  </div>
#  <div class="number">10</div>
#  <div class="about">
#  <div class="name">
#  <span>Sadio</span> <span>Mane</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/mohamed-salah">
#  <div class="img-wrap">
#  <img alt="Mohamed Salah" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125158_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">11</div>
#  <div class="about">
#  <div class="name">
#  <span>Mohamed</span> <span>Salah</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/takumi-minamino">
#  <div class="img-wrap">
#  <img alt="Takumi Minamino" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125154_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">18</div>
#  <div class="about">
#  <div class="name">
#  <span>Takumi</span> <span>Minamino</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/diogo-jota">
#  <div class="img-wrap">
#  <img alt="Diogo Jota" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125136_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">20</div>
#  <div class="about">
#  <div class="name">
#  <span>Diogo</span> <span>Jota</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/divock-origi">
#  <div class="img-wrap">
#  <img alt="Divock Origi" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125137_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">27</div>
#  <div class="about">
#  <div class="name">
#  <span>Divock</span> <span>Origi</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/harvey-elliott">
#  <div class="img-wrap">
#  <img alt="Harvey Elliott" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125147_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">67</div>
#  <div class="about">
#  <div class="name">
#  <span>Harvey</span> <span>Elliott</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="cms-block cms-block-element" data-block-type="lfc.fixtures.listing.block.player" id="cms-block-17819">
#  <div class="team-player-list">
#  <h2>ON LOAN</h2>
#  <ul>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/ben-davies">
#  <div class="img-wrap">
#  <img alt="Ben Davies" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125132_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">28</div>
#  <div class="about">
#  <div class="name">
#  <span>Ben</span> <span>Davies</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/rhys-williams">
#  <div class="img-wrap">
#  <img alt="Rhys Williams" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125151_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">46</div>
#  <div class="about">
#  <div class="name">
#  <span>Rhys</span> <span>Williams</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/sheyi-ojo">
#  <div class="img-wrap">
#  <img alt="Sheyi Ojo" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">54</div>
#  <div class="about">
#  <div class="name">
#  <span>Sheyi</span> <span>Ojo</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/ben-woodburn">
#  <div class="img-wrap">
#  <img alt="Ben Woodburn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/26/thumb_125133_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">58</div>
#  <div class="about">
#  <div class="name">
#  <span>Ben</span> <span>Woodburn</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  <li class="team-player-list-item">
#  <a href="/team/first-team/player/sepp-van-den-berg">
#  <div class="img-wrap">
#  <img alt="Sepp van den Berg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/14/thumb_113613_misc_general_500.jpeg"/>
#  </div>
#  <div class="number">72</div>
#  <div class="about">
#  <div class="name">
#  <span>Sepp</span> <span>van</span> <span>den</span> <span>Berg</span>
#  </div>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-3194">
#  <div class="container-block block-3194">
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="rightCol">
#  <div class="rightAd">
#  <div id="div-gpt-ad-RES_MAIN_RIGHT_ONE">
#  <script>
#       Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_ONE');
#  </script>
#  </div>
#  </div>
#  <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-2919">
#  <div class="container-block block-2919">
#  <div class="cms-block cms-block-element" data-block-type="sonata.block.service.text" id="cms-block-3332">
#  <style type="text/css">
#
#      .richtext.linkList a {
#          display: block;
#          padding: 6px;
#          margin-bottom: 0;
#          overflow: hidden;
#          padding-right: 30px;
#          position: relative;
#          color: #333;
#          font-weight: normal;
#      }
#
#      .richtext.linkList a:nth-child(odd) {
#          background: #F6F6F6;
#      }
#
#      .richtext.linkList a:after {
#          border-bottom: 8px solid transparent;
#          border-left: 12px solid #E31B23;
#          border-top: 8px solid transparent;
#          content: "";
#          display: inline-block;
#          height: 0;
#          position: absolute;
#          width: 0;
#          right: 10px;
#          margin-top: -8px;
#          top: 50%;
#      }
#
#  @media screen and (max-width: 699px){
#  .mainColInner .richtext img {
#  width: 100%!important;
#  height: auto!important;
#  float: left!important;
#  margin-bottom: 30px!important;
#  }
#
#  </style>
#  <div class="richtext linkList">
#  <h2>First Team Staff</h2>
#  <a href="/team/first-team/staff/jurgen-klopp">Jürgen Klopp</a>
#  <a href="/team/first-team/staff/peter-krawietz">Peter Krawietz</a>
#  <a href="/team/first-team/staff/pepijn-lijnders">Pepijn Lijnders</a>
#  <a href="/team/first-team/staff/john-achterberg">John Achterberg</a>
#  <a href="/team/first-team/staff/jack-robinson">Jack Robinson</a>
#  <a href="/team/first-team/staff/claudio-taffarel">Claudio Taffarel</a>
#  <a href="/team/first-team/staff/vitor-matos">Vitor Matos</a>
#  <a href="/team/first-team/staff/andreas-kornmayer">Andreas Kornmayer</a>
#  <a href="/team/first-team/staff/dr-andreas-schlumberger">Dr Andreas Schlumberger</a>
#  <a href="/team/first-team/staff/dr-jim-moxon">Dr Jim Moxon</a>
#  <a href="/team/first-team/staff/lee-nobes">Lee Nobes</a>
#  <a href="/team/first-team/staff/conall-murtagh">Dr Conall Murtagh</a>
#  <a href="/team/first-team/staff/jordan-fairclough">Jordan Fairclough</a>
#  <a href="/team/first-team/staff/paul-small">Paul Small </a>
#  <a href="/team/first-team/staff/lee-radcliffe">Lee Radcliffe</a>
#  <a href="/team/first-team/staff/brendan-mcilduff">Brendan McIlduff</a>
#  <a href="/team/first-team/staff/david-rydings">Dr David Rydings</a>
#  <a href="/team/first-team/staff/mona-nemmer">Mona Nemmer</a>
#  <a href="/team/first-team/staff/mark-leyland">Mark Leyland</a>
#  <a href="/team/first-team/staff/daniel-spearritt">Daniel Spearritt</a>
#  <a href="/team/first-team/staff/greg-mathieson">Greg Mathieson</a>
#  <a href="/team/first-team/staff/james-french">James French</a>
#  <a href="/team/first-team/staff/chris-morgan">Chris Morgan</a>
#  <a href="/team/first-team/staff/steve-lilley">Steve Lilley</a>
#  <a href="/team/first-team/staff/joe-lewis">Joe Lewis</a>
#  <a href="/team/first-team/staff/michelle-hudson">Michelle Hudson</a>
#  <a href="/team/first-team/staff/motonori-watanabe">Motonori Watanabe</a>
#  <a href="/team/first-team/staff/lena-aschenbrenner">Lena Aschenbrenner</a>
#  </div>
#  </div>
#  <div class="cms-block cms-block-element" data-block-type="lfc.opta.standings.block.service" id="cms-block-3333">
#  <section class="opta-wrapper" id="league-table">
#  <opta-widget breakpoints="550" competition="8" competition_naming="full" data_detail="full" date_format="dddd D MMMM YYYY" default_nav="1" live="true" lose_before_draw="false" points_in_first_column="false" season="2021" show_crests="false" show_form="0" show_key="false" show_live="true" show_logo="false" show_relegation_average="false" show_title="false" side="combined" sorting="false" sport="football" team="14" team_naming="full" template="normal" widget="standings">
#  </opta-widget>
#  </section>
#  </div>
#  </div>
#  </div>
#  <div class="rightAd">
#  <div id="div-gpt-ad-RES_MAIN_RIGHT_TWO">
#  <script>
#       Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_TWO');
#  </script>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <footer id="page-footer">
#  <div class="upperBackground">
#  <section class="partners">
#  <div class="Primary">
#  <a href="http://www.standardchartered.com/home/en/index.html?camp_id=liverpool_source=liverpoolfctv_medium=4" target="_blank" title="Standard Chartered">
#  <img alt="Standard Chartered" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/25/thumb_124418_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.nike.com/gb/" target="_blank" title="Nike">
#  <img alt="Nike" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/09/thumb_108617_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.axa.com/?utm_source=liverpoolfc&amp;utm_medium=logo-partnership&amp;utm_campaign=lfc1819season" target="_blank" title="AXA">
#  <img alt="AXA" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/74/thumb_73714_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.expedia.co.uk/" target="_blank" title="Expedia">
#  <img alt="Expedia" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/21/thumb_120808_partnerlogo_partner_footer.png"/>
#  </a>
#  </div>
#  <div class="Secondary">
#  <a href="http://www.carlsberg.com/" target="_blank" title="Carlsberg">
#  <img alt="Carlsberg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/92/thumb_91236_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.scjohnson.com" target="_blank" title="SC Johnson">
#  <img alt="SC Johnson" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126678_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.kodansha.com/" target="_blank" title="Kodansha">
#  <img alt="Kodansha" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/23/thumb_122892_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.sonos.com" target="_blank" title="Sonos">
#  <img alt="Sonos" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125033_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.easports.com/" target="_blank" title="EA Sports">
#  <img alt="EA Sports" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125053_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.tourism-mauritius.mu" target="_blank" title="Mauritius">
#  <img alt="Mauritius" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/18/thumb_117132_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.facebook.com/PredatorEnergyDrink/" target="_blank" title="Predator Energy Drink">
#  <img alt="Predator Energy Drink" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126187_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://mg.co.uk/" target="_blank" title="MG">
#  <img alt="MG" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125832_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.hollyfrontier.com/home/default.aspx" target="_blank" title="Holly Frontier">
#  <img alt="Holly Frontier" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/11/thumb_110194_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.thinkmarkets.com/uk/" target="_blank" title="ThinkMarkets">
#  <img alt="ThinkMarkets" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125313_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.quorn.com/" target="_blank" title="Quorn">
#  <img alt="Quorn" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/26/thumb_125055_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.mondelezinternational.com/" target="_blank" title="Cadbury ROW">
#  <img alt="Cadbury ROW" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/27/thumb_126098_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.acronis.com/en-gb/" target="_blank" title="Acronis">
#  <img alt="Acronis" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0002/02/thumb_101725_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://www.nipponham.co.jp/eng/" target="_blank" title="NH Foods">
#  <img alt="NH Foods" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/86/thumb_85085_partnerlogo_partner_footer.png"/>
#  </a>
#  <a href="https://uk.joiebaby.com/liverpoolfc/" target="_blank" title="Joie Baby">
#  <img alt="Joie Baby" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/41/thumb_40979_partnerlogo_partner_footer.png"/>
#  </a>
#  </div>
#  </section>
#  </div>
#  <div class="lowerBackground">
#  <section class="bottomFooter">
#  <div class="footerCrest">
#  </div>
#  <div class="footerCrestLeft">
#  </div>
#  <div class="footerText">
#  <div class="footer-middleBottom">
#  <a href="http://www.liverpoolfc.com/legal/privacy-policy" title="Go to Privacy Policy">Privacy Policy</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/legal/terms-and-conditions" title="Go to Terms and Conditions">Terms and Conditions</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/corporate/anti-slavery" title="Go to Anti-Slavery">Anti-Slavery</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/legal/cookies" title="Go to Cookies">Cookies</a> <span>|</span>
#  <a href="https://faq.liverpoolfc.com/portal/home" title="Go to Help">Help</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/corporate/browser-support" title="Go to Browser Support">Browser Support</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/corporate/rss-feeds" title="Go to RSS Feeds">RSS Feeds</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/contactus" title="Go to Contact Us">Contact Us</a> <span>|</span>
#  <a href="http://www.liverpoolfc.com/accessible/accessible" title="Go to Accessibility">Accessibility</a> <br/>
#  </div>
#  <div class="footer-left">
#              © Copyright 2021 The Liverpool Football Club and Athletic Grounds Limited. All rights reserved.
#          </div>
#  <div class="footer-right">
#              Developed and maintained by the LFC Technology and Transformation Team
#          </div>
#  <div class="footer-middle">
#              Match Statistics supplied by Opta Sports Data Limited. Reproduced under licence from Football DataCo Limited. All rights reserved.
#          </div>
#  </div>
#  </section></div>
#
#  </footer></div>
#
#
#  <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-676/lfc/js/scripts.min.js"></script>
#  <script src="https://secure.widget.cloud.opta.net/v3/v3.opta-widgets.js"></script>
#  <script>
#              var opta_settings = {
#                     subscription_id: 'da747e372c352a82f3dd6174084858fd',
#                     language: 'en_GB',
#                     timezone: 'Europe/London',
#                     opta_tracking: false
#              };
#          </script>
#  <style>
#                              .team-player-list-item .name > span {
#  width:40px;
#  }
#                          </style>
#  <!-- monitoring:3e9fda56df2cdd3b039f189693ab7844fbb2d4f6 -->
#  </body>,
#  '\n']

# %%
print(soup.find('title').get_text())
# Out:
# Liverpool FC - Team

# %%
soup.find_all('div', class_='name')
# Out:
# [<div class="name">
#  <span>Alisson</span> <span>Becker</span>
#  </div>,
#  <div class="name">
#  <span>Adrian</span>
#  </div>,
#  <div class="name">
#  <span>Loris</span> <span>Karius</span>
#  </div>,
#  <div class="name">
#  <span>Caoimhin</span> <span>Kelleher</span>
#  </div>,
#  <div class="name">
#  <span>Marcelo</span> <span>Pitaluga</span>
#  </div>,
#  <div class="name">
#  <span>Virgil</span> <span>van</span> <span>Dijk</span>
#  </div>,
#  <div class="name">
#  <span>Ibrahima</span> <span>Konate</span>
#  </div>,
#  <div class="name">
#  <span>Joe</span> <span>Gomez</span>
#  </div>,
#  <div class="name">
#  <span>Kostas</span> <span>Tsimikas</span>
#  </div>,
#  <div class="name">
#  <span>Andy</span> <span>Robertson</span>
#  </div>,
#  <div class="name">
#  <span>Joel</span> <span>Matip</span>
#  </div>,
#  <div class="name">
#  <span>Nathaniel</span> <span>Phillips</span>
#  </div>,
#  <div class="name">
#  <span>Trent</span> <span>Alexander-Arnold</span>
#  </div>,
#  <div class="name">
#  <span>Neco</span> <span>Williams</span>
#  </div>,
#  <div class="name">
#  <span>Fabinho</span>
#  </div>,
#  <div class="name">
#  <span>Thiago</span> <span>Alcantara</span>
#  </div>,
#  <div class="name">
#  <span>James</span> <span>Milner</span>
#  </div>,
#  <div class="name">
#  <span>Naby</span> <span>Keita</span>
#  </div>,
#  <div class="name">
#  <span>Jordan</span> <span>Henderson</span>
#  </div>,
#  <div class="name">
#  <span>Alex</span> <span>Oxlade-Chamberlain</span>
#  </div>,
#  <div class="name">
#  <span>Curtis</span> <span>Jones</span>
#  </div>,
#  <div class="name">
#  <span>Roberto</span> <span>Firmino</span>
#  </div>,
#  <div class="name">
#  <span>Sadio</span> <span>Mane</span>
#  </div>,
#  <div class="name">
#  <span>Mohamed</span> <span>Salah</span>
#  </div>,
#  <div class="name">
#  <span>Takumi</span> <span>Minamino</span>
#  </div>,
#  <div class="name">
#  <span>Diogo</span> <span>Jota</span>
#  </div>,
#  <div class="name">
#  <span>Divock</span> <span>Origi</span>
#  </div>,
#  <div class="name">
#  <span>Harvey</span> <span>Elliott</span>
#  </div>,
#  <div class="name">
#  <span>Ben</span> <span>Davies</span>
#  </div>,
#  <div class="name">
#  <span>Rhys</span> <span>Williams</span>
#  </div>,
#  <div class="name">
#  <span>Sheyi</span> <span>Ojo</span>
#  </div>,
#  <div class="name">
#  <span>Ben</span> <span>Woodburn</span>
#  </div>,
#  <div class="name">
#  <span>Sepp</span> <span>van</span> <span>den</span> <span>Berg</span>
#  </div>]

# %%
player = soup.find_all("div", {'class':'name'})

# %%
player.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-64978442e7fb> in <module>
# ----> 1 player.text
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for i in soup.find_all( 'h2'):
    print(soup.get_text())
# Out:
# Liverpool statistics, latest results and form 2021/2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LEAGUES
#
#
# MATCHES
#
#
# STATS
#
#
# BLOG
#
#
# FAV
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MEMBERS
#
#
#
#
#
# ARATAUBEBRCHCZDED2DKENE2E3E4E5ESE2FIFRF2GRKRNLITI2JPNOPLPTRUSCSETRUA
#
#
#
#
# Premier League
#
#
# ----------------------
#
# Dashboard
#
# ----------------------
#
# ENG - Premier League
# ITA - Serie A
# SPA - La Liga
# FRA - Ligue 1
# GER - Bundesliga
#
#
# Champions League
# Europa League
# Copa Libertadores
# Champions League (W)
#
#
# EURO 2020
# World Cup 2018
# WC Qualification Europe
# WC Qual. South-America
# Euro 2020 Qualification
# UEFA Nations League
#
# ----------------------
#
# See 'Search league' box
# Display all leagues
#
# ----------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Premier League
#
#
#
#
# 2021/22 ▼
#
# 2021/22
# 2020/21
# 2019/20
# 2018/19
# 2017/18
# 2016/17
# 2015/16
# 2014/15
# 2013/14
#
#
#
#
#
#
#
#
#
#
#
#
# Statistics ▼
#
#  Tables
# Home / Away tables
# Form tables
# Half-time stats
# Stats by month
# Wide table
# Scorers table
# Run-in analysis
# Relative performance
# Relative form
# Home advantage
#  Matches
# Matches by date
# Matches by matchday
# Results grid
# Results filter
# Current streaks
#  Goals per match
# Over / Under
# Total Goals
# Goal ranges
# Average goals
# Scored / conceded
# Both teams scored
# Goal margins
#  Goal timing
# Goals per 10 min.
# Goals per 15 min.
# First goal timing
# Scored in both halves
#  Leading / losing
# Lead durations
# Scored / conceded first
# Leading / Trailing at HT
# Goal types
# Equalizers scored
# Equalizers conceded
#
#
#
#
#
#
#  other competitions ▼
#
# Premier LeagueChampionshipLeague OneLeague TwoNational LeagueNational L. NorthNational L. SouthIsthmian leagueNorthern leagueSouthern CentralSouthern SouthIsthmian Div. 1 NorthIsthmian Div. 1 South C.Isthmian Div. 1 South E.PL 2 Div. 1PL 2 Div. 2Women Super LeagueWomen ChampionshipProfessional Development League
#
#
#
#
#
# Teams ▼
#
# Arsenal
# Aston Villa
# Brentford
# Brighton
# Burnley
# Chelsea
# Crystal Palace
# Everton
# Leeds Utd
# Leicester City
# Liverpool
# Manchester City
# Manchester Utd
# Newcastle Utd
# Norwich City
# Southampton
# Tottenham
# Watford
# West Ham Utd
# Wolverhampton
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LATEST
# MATCHES
# FORM
# H2H
# GOALS
# HALF
# TIMING
# FIRST
#
#
#
#
#
#
#
#
# advertisement
#
#
#
#
#
# Liverpool stats
#
#
#
#
# Our website is made possible by displaying online advertisements to our visitors.
#
# If you are using an ad blocker, please consider supporting us by disabling the blocking of ads for our website in your ad blocker. Thank you.
# Alternatively you may also want to become a
# member.
#
#
#
#
#
#
#
#
#
#
#
# Liverpool
# (this season in the league)
#
#
#
#
# Latest results
#
#
# 1 Dec
# Everton - LIV
#
#
# 1 - 4
#
#  0 - 1 Jordan Henderson (9)A. Townsend  (16) 0 - 2 M. Salah (19)Allan  (31)D. Gray (38) 1 - 2 T. Alcantara  (39)Lucas Digne  (40)D. Gray  (44)HT: 1-2A. Robertson  (63) 1 - 3 M. Salah (64) 1 - 4 D. Jota (79)Virgil van Dijk  (80)FT: 1-4
#
#
#
# 27 Nov
# LIV - Southampton
#
#
# 4 - 0
#
# D. Jota (2) 1 - 0 J. Bednarek  (11)D. Jota (32) 2 - 0 T. Alcantara (37) 3 - 0 HT: 3-0Virgil van Dijk (52) 4 - 0 FT: 4-0
#
#
#
# 20 Nov
# LIV - Arsenal
#
#
# 4 - 0
#
# J. Klopp  (33)M. Arteta  (33)Sadio Mane (39) 1 - 0 Sadio Mane  (44)HT: 1-0D. Jota (52) 2 - 0 Fabinho  (70)M. Salah (73) 3 - 0 T. Minamino (77) 4 - 0 FT: 4-0
#
#
#
# 7 Nov
# West Ham Utd - LIV
#
#
# 3 - 2
#
# Alisson (o.g.) (4) 1 - 0  1 - 1 T. Alexander-Arnold (41)T. Soucek  (45)HT: 1-1T. Alexander-Arnold  (55)Pablo Fornals (67) 2 - 1 Kurt Zouma (74) 3 - 1  3 - 2 D. Origi (83)FT: 3-2
#
#
#
# 30 Oct
# LIV - Brighton
#
#
# 2 - 2
#
# Jordan Henderson (4) 1 - 0 Sadio Mane (24) 2 - 0  2 - 1 E. Mwepu (41)HT: 2-1 2 - 2 L. Trossard (65)T. Minamino  (88)T. Lamptey  (90)Shane Duffy  (90)A. Robertson  (90)FT: 2-2
#
#
#
# 24 Oct
# Manchester Utd - LIV
#
#
# 0 - 5
#
#  0 - 1 N. Keita (5) 0 - 2 D. Jota (13) 0 - 3 M. Salah (38)L. Shaw  (41)C. Ronaldo  (45)Fred  (45) 0 - 4 M. Salah (45)HT: 0-4B. Fernandes  (46) 0 - 5 M. Salah (50)Harry Maguire  (55)P. Pogba  (61)Aaron Wan-Bissaka  (86)FT: 0-5
#
#
#
# 16 Oct
# Watford - LIV
#
#
# 0 - 5
#
#  0 - 1 Sadio Mane (9) 0 - 2 R. Firmino (37)HT: 0-2 0 - 3 R. Firmino (52) 0 - 4 M. Salah (54) 0 - 5 R. Firmino (90)FT: 0-5
#
#
#
# 3 Oct
# LIV - Manchester City
#
#
# 2 - 2
#
# Ruben Dias  (26)J. Milner  (42)HT: 0-0Joao Cancelo  (56)Sadio Mane (59) 1 - 0 D. Jota  (65) 1 - 1 P. Foden (69)M. Salah (76) 2 - 1 Bernardo Silva  (77) 2 - 2 K. De Bruyne (81)Fabinho  (83)FT: 2-2
#
#
#
#
#
#
# Seasonal match statistics
#
#
#
# Played
# W
#
# D
#
#
# L
#
#
#
# W D L %
#
#
#
# Home
#
# 7
# 4
# 3
# 0
#
#
#
#
#
#
# Away
#
# 7
# 5
# 1
# 1
#
#
#
#
#
#
# Total
#
# 14
# 9
# 4
# 1
#
#
#
#
#
#
#
# Points per game:
#
# 2.21
#
#
#
#
# Relative form
# Stats
# AllLast 8
# Diff.
# Points per Game2.21
# 2.13
# -3.6%
# Average goals scored3.07
# 3.50
# +14.0%
# Average goals conceded0.86
# 1.00
# +16.3%
#
#
#
#
#
# Form
# With the 1-4 away win at Everton, Liverpool are on a 3-match winning run in the league. The team has won 5 of their last 8 matches in Premier League. Liverpool have conceded an average of 0.86 goals per game since the beginning of the season in the league. Liverpool form stats indicate an average number of goals conceded per game of 1.00 in the last 8 league matches, which is 16.3% higher than their current season's average.
#
#
#
#
#
#
# advertisement
#
#
#
#
#
# advertisement
#
#
#
#
#
#
# Results
#
#
#
#
#
# 2.5+
#
# CS
#
# FTS
#
#
# HT
#
#
#
#
#
# 14 Aug
#
#
#
# Norwich City
#
#
#
# 0 - 3
#
# J. Milner  (25) 0 - 1 D. Jota (26)HT: 0-1T. Cantwell  (53) 0 - 2 R. Firmino (65) 0 - 3 M. Salah (74)FT: 0-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-1
#
#
# stats
#
#
#
#
# 21 Aug
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 0
#
# D. Jota (18) 1 - 0 HT: 1-0Sadio Mane (69) 2 - 0 FT: 2-0
#
#
#
#
# Burnley
#
#
# -
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 28 Aug
#
#
#
#
# Liverpool
#
#
#
#
# 1 - 1
#
#  0 - 1 K. Havertz (22)Antonio Rudiger  (45)R. James  (45)M. Salah pen. (45) 1 - 1 Edouard Mendy  (45)FT: 1-1
#
#
#
#
# Chelsea
#
#
# -
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 12 Sep
#
#
#
# Leeds Utd
#
#
#
# 0 - 3
#
# L. Cooper  (12)Fabinho  (16) 0 - 1 M. Salah (20)D. Llorente  (31)HT: 0-1 0 - 2 Fabinho (50)Pascal Struijk  (60) 0 - 3 Sadio Mane (90)FT: 0-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-1
#
#
# stats
#
#
#
#
# 18 Sep
#
#
#
#
# Liverpool
#
#
#
#
# 3 - 0
#
# Jordan Henderson  (40)Sadio Mane (43) 1 - 0 HT: 1-0K. Tsimikas  (75)M. Salah (78) 2 - 0 M. Salah  (79)Joel Ward  (83)N. Keita (89) 3 - 0 FT: 3-0
#
#
#
#
# Crystal Palace
#
#
# +
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 25 Sep
#
#
#
# Brentford
#
#
#
# 3 - 3
#
# Ethan Pinnock (27) 1 - 0  1 - 1 D. Jota (31)F. Onyeka  (44)HT: 1-1 1 - 2 M. Salah (54)Vitaly Janelt (63) 2 - 2  2 - 3 C. Jones (67)A. Robertson  (70)Y. Wissa (82) 3 - 3 FT: 3-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 3 Oct
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 2
#
# Ruben Dias  (26)J. Milner  (42)HT: 0-0Joao Cancelo  (56)Sadio Mane (59) 1 - 0 D. Jota  (65) 1 - 1 P. Foden (69)M. Salah (76) 2 - 1 Bernardo Silva  (77) 2 - 2 K. De Bruyne (81)Fabinho  (83)FT: 2-2
#
#
#
#
# Manchester City
#
#
# +
#
#
# -
#
#
# -
#
#
# 0-0
#
#
# stats
#
#
#
#
# 16 Oct
#
#
#
# Watford
#
#
#
# 0 - 5
#
#  0 - 1 Sadio Mane (9) 0 - 2 R. Firmino (37)HT: 0-2 0 - 3 R. Firmino (52) 0 - 4 M. Salah (54) 0 - 5 R. Firmino (90)FT: 0-5
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-2
#
#
# stats
#
#
#
#
# 24 Oct
#
#
#
# Manchester Utd
#
#
#
# 0 - 5
#
#  0 - 1 N. Keita (5) 0 - 2 D. Jota (13) 0 - 3 M. Salah (38)L. Shaw  (41)C. Ronaldo  (45)Fred  (45) 0 - 4 M. Salah (45)HT: 0-4B. Fernandes  (46) 0 - 5 M. Salah (50)Harry Maguire  (55)P. Pogba  (61)Aaron Wan-Bissaka  (86)FT: 0-5
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-4
#
#
# stats
#
#
#
#
# 30 Oct
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 2
#
# Jordan Henderson (4) 1 - 0 Sadio Mane (24) 2 - 0  2 - 1 E. Mwepu (41)HT: 2-1 2 - 2 L. Trossard (65)T. Minamino  (88)T. Lamptey  (90)Shane Duffy  (90)A. Robertson  (90)FT: 2-2
#
#
#
#
# Brighton
#
#
# +
#
#
# -
#
#
# -
#
#
# 2-1
#
#
# stats
#
#
#
#
# 7 Nov
#
#
#
# West Ham Utd
#
#
#
# 3 - 2
#
# Alisson (o.g.) (4) 1 - 0  1 - 1 T. Alexander-Arnold (41)T. Soucek  (45)HT: 1-1T. Alexander-Arnold  (55)Pablo Fornals (67) 2 - 1 Kurt Zouma (74) 3 - 1  3 - 2 D. Origi (83)FT: 3-2
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 20 Nov
#
#
#
#
# Liverpool
#
#
#
#
# 4 - 0
#
# J. Klopp  (33)M. Arteta  (33)Sadio Mane (39) 1 - 0 Sadio Mane  (44)HT: 1-0D. Jota (52) 2 - 0 Fabinho  (70)M. Salah (73) 3 - 0 T. Minamino (77) 4 - 0 FT: 4-0
#
#
#
#
# Arsenal
#
#
# +
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 27 Nov
#
#
#
#
# Liverpool
#
#
#
#
# 4 - 0
#
# D. Jota (2) 1 - 0 J. Bednarek  (11)D. Jota (32) 2 - 0 T. Alcantara (37) 3 - 0 HT: 3-0Virgil van Dijk (52) 4 - 0 FT: 4-0
#
#
#
#
# Southampton
#
#
# +
#
#
# +
#
#
# -
#
#
# 3-0
#
#
# stats
#
#
#
#
# 1 Dec
#
#
#
# Everton
#
#
#
# 1 - 4
#
#  0 - 1 Jordan Henderson (9)A. Townsend  (16) 0 - 2 M. Salah (19)Allan  (31)D. Gray (38) 1 - 2 T. Alcantara  (39)Lucas Digne  (40)D. Gray  (44)HT: 1-2A. Robertson  (63) 1 - 3 M. Salah (64) 1 - 4 D. Jota (79)Virgil van Dijk  (80)FT: 1-4
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-2
#
#
# stats
#
#
#
#
#
#
# Filter Liverpool results
#
#
#
#
#
#
#
#
#
# Points Per Game
#
#
#
# Home
#
#
# Away
#
# Opponent
#
#
#
# 4 Dec
#
#
# Wolverhampton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 11 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Aston Villa
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 16 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Newcastle Utd
#
#
# 2.14
#
#
# 0.43
#
#
#
#
#
# 19 Dec
#
#
# Tottenham
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.14
#
#
# 2.29
#
#
#
#
#
# 26 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Leeds Utd
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 28 Dec
#
#
# Leicester City
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 2 Jan
#
#
# Chelsea
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.00
#
#
# 2.29
#
#
#
#
#
# 15 Jan
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Brentford
#
#
# 2.14
#
#
# 1.29
#
#
#
#
#
# 23 Jan
#
#
# Crystal Palace
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 9 Feb
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Leicester City
#
#
# 2.14
#
#
# 1.29
#
#
#
#
#
# 12 Feb
#
#
# Burnley
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.00
#
#
# 2.29
#
#
#
#
#
# 19 Feb
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Norwich City
#
#
# 2.14
#
#
# 0.71
#
#
#
#
#
# 26 Feb
#
#
# Arsenal
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.29
#
#
# 2.29
#
#
#
#
#
# 5 Mar
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# West Ham Utd
#
#
# 2.14
#
#
# 1.86
#
#
#
#
#
# 12 Mar
#
#
# Brighton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.29
#
#
# 2.29
#
#
#
#
#
# 19 Mar
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Manchester Utd
#
#
# 2.14
#
#
# 1.57
#
#
#
#
#
# 2 Apr
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Watford
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 9 Apr
#
#
# Manchester City
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.29
#
#
# 2.29
#
#
#
#
#
# 16 Apr
#
#
# Aston Villa
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 23 Apr
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Everton
#
#
# 2.14
#
#
# 0.71
#
#
#
#
#
# 30 Apr
#
#
# Newcastle Utd
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 0.57
#
#
# 2.29
#
#
#
#
#
# 7 May
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Tottenham
#
#
# 2.14
#
#
# 1.17
#
#
#
#
#
# 15 May
#
#
# Southampton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 22 May
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Wolverhampton
#
#
# 2.14
#
#
# 1.57
#
#
#
#
# Average of Opponent PPG values above
#
#
# 1.33
#
#
#
#
#
#
#
#
#
#
# The Points Per Game values are calculated based on Home results only for the home team and away results only for the visiting team.
#
#
#
# Run-in overview
#
#
# Of their 24 remaining matches in the English Premier League, Liverpool will be playing as many matches at home and away (12 in each case).
# Considering the opponents' Points Per Game (PPG) values above, Liverpool's remaining away matches feature a higher combined opposition PPG average than their remaining home matches.
# Liverpool's opponents to be played in home games currently have a combined average of 1.10 Points Per Game in their away matches played so far this season in the league.
# As for the hosts that Liverpool will be visiting, so far this season they have a combined average of 1.56 Points Per Game at home in the league.
#
#
#
# View opponents PPG values for all teams
#
#
#
#
# Dates based on GMT time. Please note that match schedules and timing are subject to changes.
#
#
#
#
# Player stats
#
#
#
# Player
# Pos.
# App.
# Goals
#
#
#
#
# 1
#
# Alisson
# G
# 13
# -
# stats
#
#
# 62
#
# Caoimhin Kelleher
# G
# 1
# -
# stats
#
#
#
# 26
#
# A. Robertson
# D
# 10
# -
# stats
#
#
# 5
#
# Ibrahima Konaté
# D
# 4
# -
# stats
#
#
# 32
#
# Joël Matip
# D
# 10
# -
# stats
#
#
# 21
#
# K. Tsimikas
# D
# 6
# -
# stats
#
#
# 66
#
# T. Alexander-Arnold
# D
# 12
# 1
# stats
#
#
# 4
#
# Virgil van Dijk
# D
# 14
# 1
# stats
#
#
#
# 15
#
# A. Oxlade-Chamberlai
# M
# 9
# -
# stats
#
#
# 17
#
# C. Jones
# M
# 5
# 1
# stats
#
#
# 3
#
# Fabinho
# M
# 10
# 1
# stats
#
#
# 67
#
# H. Elliott
# M
# 4
# -
# stats
#
#
# 7
#
# J. Milner
# M
# 7
# -
# stats
#
#
# 14
#
# Jordan Henderson
# M
# 13
# 2
# stats
#
#
# 8
#
# N. Keita
# M
# 7
# 2
# stats
#
#
# 6
#
# T. Alcantara
# M
# 8
# 1
# stats
#
#
#
# 20
#
# D. Jota
# F
# 13
# 8
# stats
#
#
# 11
#
# M. Salah
# F
# 14
# 13
# stats
#
#
# 9
#
# R. Firmino
# F
# 8
# 4
# stats
#
#
# 10
#
# Sadio Mané
# F
# 14
# 7
# stats
#
#
#
#
#
# D. Origi
# -
# 2
# 1
# stats
#
#
#
#
# J. Gomez
# -
# 2
# -
# stats
#
#
#
#
# J. Klopp
# -
# 0
# -
# stats
#
#
#
#
# N. Williams
# -
# 1
# -
# stats
#
#
#
#
# T. Minamino
# -
# 5
# 1
# stats
#
#
#
#
# T. Morton
# -
# 1
# -
# stats
#
#
#
# Column titles:
# Pos.: Position
# App.: Appearances
#
#
#
#
#
#
#
# Historical statistics
#
#
#
#   Liverpool
# (current season vs completed previous season)
#
#
# Season
# Pld
# AvgPts
# AvgGF
# AvgGA
# W
# D
# L
# CS
# FTS
#
#
# 2021/2022
# 14
# 2.21
# 3.07
# 0.86
# 64%
# 29%
# 7%
# 57%
# 0%
#
#
# 2020/2021
# 381.82
# 1.791.11
# 53%
# 24%
# 24%
# 32%21%
#
#
#
# 2021/2022 (at home)
# 7
# 2.14
# 2.57
# 0.71
# 57%
# 43%
# 0%
# 57%
# 0%
#
#
# 2020/2021 (at home)
# 191.74
# 1.531.05
# 53%
# 16%
# 32%
# 26%32%
#
#
#
# 2021/2022 (away)
# 7
# 2.29
# 3.57
# 1.00
# 71%
# 14%
# 14%
# 57%
# 0%
#
#
# 2020/2021 (away)
# 191.89
# 2.051.16
# 53%
# 32%
# 16%
# 37%11%
#
#
#
#
#
#
#
# Comparison with past seasons (first 14 matches)
#
#
#
#  Liverpool's record
# after 14 matches in the same league/division
#
#
#
#
#
#
# GP
#
#
# W
#
#
# D
#
#
# L
#
#
# GF
#
#
# GA
#
#
# Pts
# *
#
# Comparison
#
#
#
# 2021-2022
# 14
# 9
# 4
# 1
# 43
# 12
# 31
# -
#
#
# 2020-2021
# 14
# 9
# 4
# 1
# 36
# 19
# 31
# 0 pts
#
#
# 2019-2020
# 14
# 13
# 1
# 0
# 32
# 12
# 40
#
# -9 pts
#
#
# 2018-2019
# 14
# 11
# 3
# 0
# 27
# 5
# 36
#
# -5 pts
#
#
# 2017-2018
# 14
# 7
# 5
# 2
# 28
# 18
# 26
# +
# 5 pts
#
#
# 2016-2017
# 14
# 9
# 3
# 2
# 35
# 18
# 30
# +
# 1 pts
#
#
# 2015-2016
# 14
# 6
# 5
# 3
# 18
# 15
# 23
# +
# 8 pts
#
#
# 2014-2015
# 14
# 6
# 2
# 6
# 19
# 19
# 20
# +
# 11 pts
#
#
# 2013-2014
# 14
# 8
# 3
# 3
# 30
# 17
# 27
# +
# 4 pts
#
#
# 2012-2013
# 14
# 3
# 7
# 4
# 18
# 18
# 16
# +
# 15 pts
#
#
# 2011-2012
# 14
# 6
# 5
# 3
# 17
# 13
# 23
# +
# 8 pts
#
#
# 2010-2011
# 14
# 5
# 4
# 5
# 16
# 17
# 19
# +
# 12 pts
#
#
# * Pts: any deducted or added points are NOT taken into account
#
#
# With 31 points so far this season, Liverpool have picked up as many points as they did last season after 14 matches, yet their total in the current season is 9 points lower than it was two seasons ago at the same stage.
#
#
#
#
#
#
#
#
#
#
#
# Current Streaks & Sequences
#
#
# CURRENT SEQUENCES
#
# Home
#
# Away
#
# Total
#
#
# Consecutive wins
# 213
#
# Consecutive draws
# ---
#
# Consecutive defeats
# ---
#
# No win
# ---
#
# No draw
# 244
#
# No defeat
# 713
#
# 1 goal scored or more
# 7714
#
# 1 goal conceded or more
# -21
#
# No goal scored
# ---
#
# No goal conceded
# 2--
#
# Over 2.5 goals
# 5711
#
# Under 2.5 goals
# ---
#
# 2 goals scored or more
# 5711
#
# Current Sequences table
#
#
#
#
#
#
#
# Home vs Away comparisons
#
#
# Home / Away points
#
# Home
#
# Away
#
#
# % Points
#
#
#
#
# 48%
#
#
#
# 52%
#
#
#
#
# Home / Away PPG
#
#  Points Per Game at Home (PPGH)2.14
#
#
#  Points Per Game Away (PPGA)2.29
#
#
#  Home advantage (PPGH - PPGA)
# -0.15
#
#
#
#
#
# Home / Away goals
#
# Home
#
# Away
#
#
# % Goals scored
#
#
#
#
# 42%
#
#
#
# 58%
#
#
# % Goals conceded
#
#
#
#
# 42%
#
#
#
# 58%
#
#
# League average (% goals)
#
#
#
#
# 54%
#
#
#
# 46%
#
#
#
#
#
#
# Matches played at home have accounted for only 48% of Liverpool's total points and only 42% of the goals they have scored so far this season in Premier League.
#
#
#
#
# League Home / Away tables
#
#
#
#
# Comparison with league average
#
#
#
#
#
# Liverpool (14 matches) compared to league average
#
# Liverpool
# League average
#
#
#
#
#
#
# Points per game
#
#
# 2.21
#
#
#
# 1.36
#
#
#
#
#
#
#
# % Wins
#
#
# 64%
#
#
#
# 36%
#
#
#
#
#
#
#
# % Draws
#
#
# 29%
#
#
#
# 28%
#
#
#
#
#
#
#
# % Defeats
#
#
#
#
# 7%
#
# 36%
#
#
#
#
#
#
#
# Goals scored per game
#
#
# 3.07
#
#
#
# 1.39
#
#
#
#
#
#
#
# Goals conceded per game
#
#
#
#
# 0.86
#
# 1.39
#
#
#
#
#
#
#
# Total goals per game
#
#
# 3.93
#
#
#
# 2.78
#
#
#
#
#
#
#
# % over 2.5 goals
#
#
# 86%
#
#
#
# 53%
#
#
#
#
#
#
#
# % over 3.5 goals
#
#
# 64%
#
#
#
# 31%
#
#
#
#
#
#
#
# % both teams scored
#
#
#
#
# 43%
#
# 50%
#
#
#
#
#
#
# Liverpool at home (7 matches) compared to league average at home
#
# (home matches) Liverpool
# League average
#
#
#
#
#
#
# Points per game
#
#
# 2.14
#
#
#
# 1.47
#
#
#
#
#
#
#
# % Wins
#
#
# 57%
#
#
#
# 40%
#
#
#
#
#
#
#
# % Draws
#
#
# 43%
#
#
#
# 28%
#
#
#
#
#
#
#
# % Defeats
#
#
#
#
# 0%
#
# 32%
#
#
#
#
#
#
#
# Goals scored per game
#
#
# 2.57
#
#
#
# 1.50
#
#
#
#
#
#
#
# Goals conceded per game
#
#
#
#
# 0.71
#
# 1.27
#
#
#
#
#
#
#
# Total goals per game
#
#
# 3.29
#
#
#
# 2.78
#
#
#
#
#
#
#
# % over 2.5 goals
#
#
# 71%
#
#
#
# 53%
#
#
#
#
#
#
#
# % over 3.5 goals
#
#
# 57%
#
#
#
# 31%
#
#
#
#
#
#
#
# % both teams scored
#
#
#
#
# 43%
#
# 50%
#
#
#
#
#
#
# Liverpool away (7 matches) compared to league average away
#
# (away matches) Liverpool
# League average
#
#
#
#
#
#
# Points per game
#
#
# 2.29
#
#
#
# 1.25
#
#
#
#
#
#
#
# % Wins
#
#
# 71%
#
#
#
# 32%
#
#
#
#
#
#
#
# % Draws
#
#
#
#
# 14%
#
# 28%
#
#
#
#
#
#
#
# % Defeats
#
#
#
#
# 14%
#
# 40%
#
#
#
#
#
#
#
# Goals scored per game
#
#
# 3.57
#
#
#
# 1.27
#
#
#
#
#
#
#
# Goals conceded per game
#
#
#
#
# 1.00
#
# 1.50
#
#
#
#
#
#
#
# Total goals per game
#
#
# 4.57
#
#
#
# 2.78
#
#
#
#
#
#
#
# % over 2.5 goals
#
#
# 100%
#
#
#
# 53%
#
#
#
#
#
#
#
# % over 3.5 goals
#
#
# 71%
#
#
#
# 31%
#
#
#
#
#
#
#
# % both teams scored
#
#
#
#
# 43%
#
# 50%
#
#
#
#
#
#
#
#
#
#
#
# The 'League average' indicator refers to the average value for all teams in the league since the beginning of the season.
#
#
#
#
# Liverpool goals statistics indicate an average of 3.07 goals scored per game so far this season, which is higher than the average number of 1.39 goals scored by each team per match this season in the league, all teams combined in Premier League.
#
#
#
#
# First goal, leading & trailing
#
#
#
#
#   Liverpool
#
#  Leading & trailing stats (total)
# (this season in the league)
#
#
#
# OPENING GOALS (total)
#
# Matches
#
#
# Team scored first
# 11 / 1479%
#
# Opponent scored first
# 3 / 1421%
#
#
#
#
# HALF-TIME LEAD (total)
#
# Matches
#
#
# Team was leading at half-time
# 10 / 1471%
#
# Opponent was leading at half-time
# 0 / 140%
#
#
#
#
# LEAD STATUS AVERAGE MINUTES (total)
#
# per match
#
#
# Average minutes leading
# 52.8 min.
#
# Average minutes level in goals
# 31.0 min.
#
# Average minutes trailing
# 6.2 min.
#
#
# Note: in the table above, to allow for averaging duration values based on a total of 90 minutes per game, goals scored on the 45th minute and during added time of the first half are all considered to be scored on the 45th minute, and goals scored on the 90th minute and during added time of the second half are also considered scored on the 90th minute.
#
#
#
# In this example, Liverpool have been in the lead for an average duration of 52.8 minutes per match (based on a 90-minute match duration), which is longer than the average duration of 6.2 minutes per match during which their opponents were in the lead in those matches.
#
#
#
#
#
#   Liverpool
#
#  Equalizer goals (total)
# (this season in the league)
#
#
#
#
# Matches played
# 14
#
#
#
#
# DEFENDING THE LEAD (total)
#
#
# Goals giving the lead
# 14
#
# Equalizer goals conceded
# 5
#
# Opponents' equalizing rate
# * (1)36%
#
#
#
#
# EQUALIZING (total)
#
#
# Goals giving the lead to the opponent
# 4
#
# Equalizer goals scored
# 3
#
# Equalizing rate
# * (2)75%
#
#
#
#
# NON-CRUCIAL GOALS (total)
#
#
# Non-crucial goals scored
# 26
#
# Non-crucial goals conceded
# 3
#
#
# (1) (Equalizer goals conceded / Goals giving lead) * 100
# (2) (Equalizer goals scored / Goals giving lead to opponent) * 100
#
#
# Non-crucial goals scored: goals scored that increased an existing lead, or decreased the opponent's existing lead.
# Non-crucial goals conceded: goals conceded that decreased an existing lead, or increased the opponent's existing lead.
#
# Note regarding the Goals giving the lead and the Goals giving the lead to the opponent values: both the team and the opponent team might take the lead more than once during a single match,
# so the total number of goals giving the lead to a team might be higher than the number of matches played by the team.
# For more info on how many times each team has taken the lead per match or how many times per match their opponents have taken the lead, you may want to view the following pages:
# Goals giving the lead and equalizers conceded
# Goals giving lead to opponent and equalizers scored
#
# Lead-defending abilityLiverpool have taken the lead 14 times and have conceded an equalizer on 5 instances, translating into a lead-defending rate of 64% (for an opponents' equalizing rate of 36%).
#
#
# Equalizing abilityOf the 4 times that Liverpool's opponents have taken the lead, Liverpool have managed to score an equalizer on 3 instances, translating into an equalizing rate of 75%.
#
#
#
#
#
#
#   Liverpool
#
#  Leading & trailing stats (home)
# (this season in the league, home matches)
#
#
#
# OPENING GOALS (home)
#
# Matches
#
#
# Team scored first
# 6 / 786%
#
# Opponent scored first
# 1 / 714%
#
#
#
#
# HALF-TIME LEAD (home)
#
# Matches
#
#
# Team was leading at half-time
# 5 / 771%
#
# Opponent was leading at half-time
# 0 / 70%
#
#
#
#
# LEAD STATUS AVERAGE MINUTES (home)
#
# per match
#
#
# Average minutes leading
# 47.7 min.
#
# Average minutes level in goals
# 39.0 min.
#
# Average minutes trailing
# 3.3 min.
#
#
# Note: in the table above, to allow for averaging duration values based on a total of 90 minutes per game, goals scored on the 45th minute and during added time of the first half are all considered to be scored on the 45th minute, and goals scored on the 90th minute and during added time of the second half are also considered scored on the 90th minute.
#
#
#
# In this example, Liverpool have been in the lead for an average duration of 47.7 minutes per match played at home (based on a 90-minute match duration), which is longer than the average duration of 3.3 minutes per match during which their opponents were in the lead in those matches.
#
#
#
#
#
#   Liverpool
#
#  Equalizer goals (home)
# (this season in the league, home matches)
#
#
#
# Matches played
# 7
#
#
#
#
# DEFENDING THE LEAD (home)
#
#
# Goals giving the lead
# 7
#
# Equalizer goals conceded
# 3
#
# Opponents' equalizing rate
# * (1)43%
#
#
#
#
# EQUALIZING (home)
#
#
# Goals giving the lead to the opponent
# 1
#
# Equalizer goals scored
# 1
#
# Equalizing rate
# * (2)100%
#
#
#
#
# NON-CRUCIAL GOALS (home)
#
#
# Non-crucial goals scored
# 10
#
# Non-crucial goals conceded
# 1
#
#
# (1) (Equalizer goals conceded / Goals giving lead) * 100
# (2) (Equalizer goals scored / Goals giving lead to opponent) * 100
#
#
# Non-crucial goals scored: goals scored that increased an existing lead, or decreased the opponent's existing lead.
# Non-crucial goals conceded: goals conceded that decreased an existing lead, or increased the opponent's existing lead.
#
# Note regarding the Goals giving the lead and the Goals giving the lead to the opponent values: both the team and the opponent team might take the lead more than once during a single match,
# so the total number of goals giving the lead to a team might be higher than the number of matches played by the team.
# For more info on how many times each team has taken the lead per match or how many times per match their opponents have taken the lead, you may want to view the following pages:
# Goals giving the lead and equalizers conceded
# Goals giving lead to opponent and equalizers scored
#
# Lead-defending ability (at home)In home matches, Liverpool have taken the lead 7 times and have conceded an equalizer on 3 occasions, translating into a home lead-defending rate of 57% (for an opponents' equalizing rate of 43%).
#
#
# Equalizing ability (at home)Of the 1 time that Liverpool's opponents have taken the lead when Liverpool were playing at home, Liverpool have managed to score an equalizer on 1 occasion, translating into a home equalizing rate of 100%.
#
#
#
#
#
#
#
#   Liverpool
#
#  Leading & trailing stats (away)
# (this season in the league, away matches)
#
#
#
# OPENING GOALS (away)
#
# Matches
#
#
# Team scored first
# 5 / 771%
#
# Opponent scored first
# 2 / 729%
#
#
#
#
# HALF-TIME LEAD (away)
#
# Matches
#
#
# Team was leading at half-time
# 5 / 771%
#
# Opponent was leading at half-time
# 0 / 70%
#
#
#
#
# LEAD STATUS AVERAGE MINUTES (away)
#
# per match
#
#
# Average minutes leading
# 57.9 min.
#
# Average minutes level in goals
# 23.0 min.
#
# Average minutes trailing
# 9.1 min.
#
#
# Note: in the table above, to allow for averaging duration values based on a total of 90 minutes per game, goals scored on the 45th minute and during added time of the first half are all considered to be scored on the 45th minute, and goals scored on the 90th minute and during added time of the second half are also considered scored on the 90th minute.
#
#
#
# In this example, Liverpool have been in the lead for an average duration of 57.9 minutes per match played away (based on a 90-minute match duration), which is longer than the average duration of 9.1 minutes per match during which their opponents were in the lead in those matches.
#
#
#
#
#
#   Liverpool
#
#  Equalizer goals (away)
# (this season in the league, away matches)
#
#
#
# Matches played
# 7
#
#
#
#
# DEFENDING THE LEAD (away)
#
#
# Goals giving the lead
# 7
#
# Equalizer goals conceded
# 2
#
# Opponents' equalizing rate
# * (1)29%
#
#
#
#
# EQUALIZING (away)
#
#
# Goals giving the lead to the opponent
# 3
#
# Equalizer goals scored
# 2
#
# Equalizing rate
# * (2)67%
#
#
#
#
# NON-CRUCIAL GOALS (away)
#
#
# Non-crucial goals scored
# 16
#
# Non-crucial goals conceded
# 2
#
#
# (1) (Equalizer goals conceded / Goals giving lead) * 100
# (2) (Equalizer goals scored / Goals giving lead to opponent) * 100
#
#
# Non-crucial goals scored: goals scored that increased an existing lead, or decreased the opponent's existing lead.
# Non-crucial goals conceded: goals conceded that decreased an existing lead, or increased the opponent's existing lead.
#
# Note regarding the Goals giving the lead and the Goals giving the lead to the opponent values: both the team and the opponent team might take the lead more than once during a single match,
# so the total number of goals giving the lead to a team might be higher than the number of matches played by the team.
# For more info on how many times each team has taken the lead per match or how many times per match their opponents have taken the lead, you may want to view the following pages:
# Goals giving the lead and equalizers conceded
# Goals giving lead to opponent and equalizers scored
#
# Lead-defending ability (away)In away matches, Liverpool have taken the lead 7 times and have conceded an equalizer on 2 occasions, translating into an away lead-defending rate of 71% (for an opponents' equalizing rate of 29%).
#
#
# Equalizing ability (away)Of the 3 times that Liverpool's opponents have taken the lead when Liverpool were playing away, Liverpool have managed to score an equalizer on 2 occasions, translating into an away equalizing rate of 67%.
#
#
#
#
#
#
#
#
#
#
# Liverpool's progression
#
#
#
#
#
#
#
#
#
#
# Line graph variation: win: +2, draw: 0, defeat: -1
#
#
#
#
#
#
#
#
#
#
# Results table
#
#
# GP
# Pts
# Home
# Away
# h2h
#
#
# 1
# Chelsea
# 14
# 33
# 1 - 1
#
# 2 Jan
#
# h2h
#
#
# 2
# Manchester City
# 14
# 32
# 2 - 2
#
# 9 Apr
#
# h2h
#
# 3
# Liverpool
# 14
# 31
#
#
#
# 4
# West Ham Utd
# 14
# 24
#
# 5 Mar
#
# 3 - 2
# h2h
#
#
# 5
# Arsenal
# 14
# 23
# 4 - 0
#
# 26 Feb
#
# h2h
#
#
# 6
# Tottenham
# 13
# 22
#
# 7 May
#
#
# 19 Dec
#
# h2h
#
#
# 7
# Manchester Utd
# 14
# 21
#
# 19 Mar
#
# 0 - 5
# h2h
#
#
# 8
# Wolverhampton
# 14
# 21
#
# 22 May
#
#
# 4 Dec
#
# h2h
#
#
# 9
# Brighton
# 14
# 19
# 2 - 2
#
# 12 Mar
#
# h2h
#
#
# 10
# Leicester City
# 14
# 19
#
# 9 Feb
#
#
# 28 Dec
#
# h2h
#
#
# 11
# Crystal Palace
# 14
# 16
# 3 - 0
#
# 23 Jan
#
# h2h
#
#
# 12
# Brentford
# 14
# 16
#
# 15 Jan
#
# 3 - 3
# h2h
#
#
# 13
# Aston Villa
# 14
# 16
#
# 11 Dec
#
#
# 16 Apr
#
# h2h
#
#
# 14
# Everton
# 14
# 15
#
# 23 Apr
#
# 1 - 4
# h2h
#
#
# 15
# Leeds Utd
# 14
# 15
#
# 26 Dec
#
# 0 - 3
# h2h
#
#
# 16
# Southampton
# 14
# 15
# 4 - 0
#
# 15 May
#
# h2h
#
#
# 17
# Watford
# 14
# 13
#
# 2 Apr
#
# 0 - 5
# h2h
#
#
# 18
# Burnley
# 13
# 10
# 2 - 0
#
# 12 Feb
#
# h2h
#
#
# 19
# Norwich City
# 14
# 10
#
# 19 Feb
#
# 0 - 3
# h2h
#
#
# 20
# Newcastle Utd
# 14
# 7
#
# 16 Dec
#
#
# 30 Apr
#
# h2h
#
#
#
# Liverpool stats rank the team in 3rd position in the Premier League table with 31 points, 1 point behind Manchester City and 7 points above West Ham Utd.
# The above table shows Liverpool results against each league opponent.
# The tables below provide additional statistics regarding Liverpool's season in the English Premier League.
#
#
#
#
#
#
# Goals scored & conceded
#
#
# SCORING
#
# Home
#
# Away
#
# All
#
#
# Goals scored
# 182543
#
# Goals scored per match
# 2.573.57 3.07
#
# Goals conceded
# 5712
#
# Goals conceded per match
# 0.711.00 0.86
#
# Scored+conc. per match
# 3.294.573.93
#
# Matches over 1.5 goals
# 100%100%100%
#
# Matches over 2.5 goals
# 71%100%86%
#
# Matches over 3.5 goals
# 57%71%64%
#
# Matches over 4.5 goals
# 0%71%36%
#
# Matches over 5.5 goals
# 0%14%7%
#
# Over 0.5 g. at half-time
# 86%100%93%
#
# Over 1.5 g. at half-time
# 43%71%57%
#
# Over 2.5 g. at half-time
# 29%29%29%
#
#
# Liverpool over 2.5 stats indicate a 86% value for the proportion of matches involving the team that had a total of over 2.5 goals, which is higher than the league average value of 53% of league matches that the over under stats indicate had a total number of goals over 2.5 this season in Premier League.
#
#
#
#
# League goals statistics
#
#
#
#
#
# Scoring patterns
#
#
# GOAL / NO GOAL
#
# Home
#
# Away
#
# Total
#
#
# Clean sheets
# 57%57%57%
#
# Won-to-nil
# 57%57%57%
#
# Scored in both halves
# 57%100%79%
#
# Both teams scored
# 43%43%43%
#
# Failed to score
# 0%0%0%
#
# Lost-to-nil
# 0%0%0%
#
# Conceded in both halves
# 14%29%21%
#
#
# League Scored in Both Halves stats
#
#
#
#
#
# Total goals in Liverpool matches
#
#
# SCORED + CONCEDED
#
# Home
#
# Away
#
# Total
#
#
# Match total goals = 0
# 0%0%0%
#
# Match total goals = 1
# 0%0%0%
#
# Match total goals = 2
# 29%0%14%
#
# Match total goals = 3
# 14%29%21%
#
# Match total goals = 4
# 57%0%29%
#
# Match total goals = 5+
# 0%71%36%
#
# Match total goals = 0 or 1
# 0%0%0%
#
# Match total goals = 2 or 3
# 43%29%36%
#
# Match total goals = 4+
# 57%71%64%
#
#
# League Total Goals stats
#
#
#
#
#
# Goal margins
#
#
#
# WINNING MARGINS
#  1  2
#  3  4+
#
#
#
# Home wins
#  01
# 12
#
#
#
# Away wins
#  00
# 32
#
#
#
# Home & Away wins
#  01
# 44
#
#
#
# LOSING MARGINS
#  1  2
#  3  4+
#
#
#
# Home defeats
#  00
# 00
#
#
#
# Away defeats
#  10
# 00
#
#
#
# Home & Away defeats
#  10
# 00
#
#
#
# A majority of Liverpool's wins have been obtained with a margin of 2 goals or more (9 wins), while 0 of their wins had a one-goal margin.
#
#
#
#
# League Goal Margin stats
#
#
#
#
#
# Half-time lead
#
#
# Half-time
#
# Home
#
# Away
#
# Total
#
#
# Leading at HT
# 55 10
# 71%
#
# Drawing at HT
# 22 4
# 29%
#
# Losing at HT
# 00 0
# 0%
#
# Total
# 7714
#
#
# League Half-time stats
#
#
#
#
#
# Team corners (corners awarded)
#
#
# Avg
# 2.5+
# 3.5+
# 4.5+
# 5.5+
# 6.5+
#
# Home
# 7.00
# 100%
# 86%
# 86%
# 57%
# 43%
# Away
# 8.29
# 86%
# 71%
# 71%
# 71%
# 71%
# Total
# 7.64
# 93%
# 79%
# 79%
# 64%
# 57%
#
#
#
# Opponents corners (corners conceded)
#
#
# Avg
# 2.5+
# 3.5+
# 4.5+
# 5.5+
# 6.5+
#
# Home
# 3.86
# 86%
# 57%
# 29%
# 14%
# 14%
# Away
# 2.86
# 57%
# 14%
# 14%
# 14%
# 0%
# Total
# 3.36
# 71%
# 36%
# 21%
# 14%
# 7%
#
#
#
# Total corners (team + opponents)
#
#
# Avg
# 9.5+
# 10.5+
# 11.5+
# 12.5+
# 13.5+
#
# Home
# 10.86
# 57%
# 57%
# 57%
# 29%
# 29%
# Away
# 11.14
# 71%
# 57%
# 57%
# 57%
# 29%
# Total
# 11.00
# 64%
# 57%
# 57%
# 43%
# 29%
#
#
#
# The average of 11.00 total corners for Liverpool refers to how the corner stats evaluate the total number of corners per match (corners awarded + corners conceded) in matches involving the team this season in Premier League.
#
#
#
#
# League Corner Stats
#
#
#
#
#
# Goal times
#
#
#
#
#   Liverpool
#
# (this season in the league)
#
#
#
# GOALS PER TIME SEGMENT (total)
# 0-15
# GF
# 6
#
#
# GA
# 1
#
# 16-30
# GF
# 5
#
#
# GA
# 2
#
# 31-45
# GF
# 10
#
#
# GA
# 2
#
#
# 46-60
# GF
# 8
#
#
# GA
# 0
#
# 61-75
# GF
# 6
#
#
# GA
# 5
#
# 76-90
# GF
# 8
#
#
# GA
# 2
#
#
#
# 1st half
#
# GF
# 21
#
#
# 49%
#
#
#
# GA
# 5
#
#
# 42%
#
#
#
#
# 2nd half
#
# GF
# 22
#
#
# 51%
#
#
#
# GA
# 7
#
#
# 58%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (total)
#
#
#  Avg. minute
# goals scored
# 47
#
#  Avg. minute
# goals conceded
# 53
#
#
#
#
#
#
#   Liverpool
#
# (this season in the league, home matches)
#
#
#
# GOALS PER TIME SEGMENT (home)
# 0-15
# GF
# 2
#
#
# GA
# 0
#
# 16-30
# GF
# 2
#
#
# GA
# 1
#
# 31-45
# GF
# 5
#
#
# GA
# 1
#
#
# 46-60
# GF
# 3
#
#
# GA
# 0
#
# 61-75
# GF
# 2
#
#
# GA
# 2
#
# 76-90
# GF
# 4
#
#
# GA
# 1
#
#
#
# 1st half
#
# GF
# 9
#
#
# 50%
#
#
#
# GA
# 2
#
#
# 40%
#
#
#
#
# 2nd half
#
# GF
# 9
#
#
# 50%
#
#
#
# GA
# 3
#
#
# 60%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (home)
#
#
# Avg. minute
# goals scored
# 48
#
# Avg. minute
# goals conceded
# 56
#
#
#
#
#
#
#   Liverpool
#
# (this season in the league, away matches)
#
#
#
# GOALS PER TIME SEGMENT (away)
# 0-15
# GF
# 4
#
#
# GA
# 1
#
# 16-30
# GF
# 3
#
#
# GA
# 1
#
# 31-45
# GF
# 5
#
#
# GA
# 1
#
#
# 46-60
# GF
# 5
#
#
# GA
# 0
#
# 61-75
# GF
# 4
#
#
# GA
# 3
#
# 76-90
# GF
# 4
#
#
# GA
# 1
#
#
#
# 1st half
#
# GF
# 12
#
#
# 48%
#
#
#
# GA
# 3
#
#
# 43%
#
#
#
#
# 2nd half
#
# GF
# 13
#
#
# 52%
#
#
#
# GA
# 4
#
#
# 57%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (away)
#
#
# Avg. minute
# goals scored
# 47
#
# Avg. minute
# goals conceded
# 51
#
#
#
#
#
# League Goal Times
#
#
# Liverpool scores
#
#
#
#
#
# FT at home
#
#
#
#
# 2-2
#
# 2
#
#
#
# 29%
#
#
#
#
# 4-0
#
# 2
#
#
#
# 29%
#
#
#
#
# 1-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-0
#
# 1
#
#
#
# 14%
#
#
#
#
# 2-0
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
# FT away
#
#
#
#
# 0-5
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-3
#
# 2
#
#
#
# 29%
#
#
#
#
# 1-4
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-3
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-2
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Half-time at home
#
#
#
#
# 1-0
#
# 3
#
#
#
# 43%
#
#
#
#
# 2-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 1-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-0
#
# 1
#
#
#
# 14%
#
#
#
#
# 0-0
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
# Half-time away
#
#
#
#
# 1-1
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-1
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-4
#
# 1
#
#
#
# 14%
#
#
#
#
# 1-2
#
# 1
#
#
#
# 14%
#
#
#
#
# 0-2
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This season in the league
#
#
# Liverpool have won 71% of their away matches.
#
#
# Liverpool have scored in each of their last 14 matches.
#
#
# 86% of Liverpool's matches had over 2.5 goals scored in total.
#
#
# Liverpool have scored in 100% of their home matches.
#
#
# Liverpool did not concede any goal in 57% of their away matches.
#
#
# Liverpool have scored in 100% of their away matches.
#
#
# Liverpool have scored the opening goal in 79% of their matches.
#
#
# Liverpool were leading at half-time in 71% of their matches.
#
#
# Liverpool have scored in each of their last 7 away matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 11 matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 5 home matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 7 away matches.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Liverpool table
#
#
#
#
#
# League table
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 14
#
# 33
#
#
#
#
#
# Manchester C.
# 14
#
# 32
#
#
#
#
#
# Liverpool
# 14
#
# 31
#
#
#
#
#
# West Ham Utd
# 14
#
# 24
#
#
#
#
#
# Arsenal
# 14
#
# 23
#
#
#
#
#
# Tottenham
# 13
#
# 22
#
#
#
#
#
# Manchester Utd
# 14
#
# 21
#
#
#
#
#
# Wolverhampton
# 14
#
# 21
#
#
#
#
#
# Brighton
# 14
#
# 19
#
#
#
#
#
# Leicester City
# 14
#
# 19
#
#
#
#
#
# Crystal Palace
# 14
#
# 16
#
#
#
#
#
# Brentford
# 14
#
# 16
#
#
#
#
#
# Aston Villa
# 14
#
# 16
#
#
#
#
#
# Everton
# 14
#
# 15
#
#
#
#
#
# Leeds Utd
# 14
#
# 15
#
#
#
#
#
# Southampton
# 14
#
# 15
#
#
#
#
#
# Watford
# 14
#
# 13
#
#
#
#
#
# Burnley
# 13
#
# 10
#
#
#
#
#
# Norwich City
# 14
#
# 10
#
#
#
#
#
# Newcastle Utd
# 14
#
# 7
#
#
#
#
#
#
#
#
# Form table (last 8)
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 8
#
# 20
#
#
#
#
#
# Manchester C.
# 8
#
# 19
#
#
#
#
#
# Liverpool
# 8
#
# 17
#
#
#
#
#
# Wolverhampton
# 8
#
# 15
#
#
#
#
#
# Arsenal
# 8
#
# 14
#
#
#
#
#
# West Ham Utd
# 8
#
# 13
#
#
#
#
#
# Tottenham
# 8
#
# 13
#
#
#
#
#
# Leeds Utd
# 8
#
# 12
#
#
#
#
#
# Leicester City
# 8
#
# 12
#
#
#
#
#
# Southampton
# 8
#
# 11
#
#
#
#
#
# Crystal Palace
# 8
#
# 10
#
#
#
#
#
# Norwich City
# 8
#
# 10
#
#
#
#
#
# Burnley
# 8
#
# 9
#
#
#
#
#
# Manchester Utd
# 8
#
# 8
#
#
#
#
#
# Brentford
# 8
#
# 7
#
#
#
#
#
# Watford
# 8
#
# 6
#
#
#
#
#
# Brighton
# 8
#
# 6
#
#
#
#
#
# Aston Villa
# 8
#
# 6
#
#
#
#
#
# Newcastle Utd
# 8
#
# 4
#
#
#
#
#
# Everton
# 8
#
# 2
#
#
#
#
#
#
#
#
#  Home
#
#
# GP
# Pts
#
#
#
#
# Manchester C.
# 7
#
# 16
#
#
#
#
#
# Arsenal
# 7
#
# 16
#
#
#
#
#
# Liverpool
# 7
#
# 15
#
#
#
#
#
# Tottenham
# 7
#
# 15
#
#
#
#
#
# Chelsea
# 7
#
# 14
#
#
#
#
#
# West Ham Utd
# 7
#
# 11
#
#
#
#
#
# Crystal Palace
# 7
#
# 10
#
#
#
#
#
# Aston Villa
# 7
#
# 10
#
#
#
#
#
# Southampton
# 7
#
# 10
#
#
#
#
#
# Manchester Utd
# 7
#
# 10
#
#
#
#
#
# Everton
# 7
#
# 10
#
#
#
#
#
# Leicester City
# 7
#
# 10
#
#
#
#
#
# Wolverhampton
# 7
#
# 10
#
#
#
#
#
# Leeds Utd
# 7
#
# 9
#
#
#
#
#
# Brighton
# 7
#
# 9
#
#
#
#
#
# Brentford
# 7
#
# 7
#
#
#
#
#
# Watford
# 7
#
# 7
#
#
#
#
#
# Burnley
# 6
#
# 6
#
#
#
#
#
# Norwich City
# 7
#
# 5
#
#
#
#
#
# Newcastle Utd
# 7
#
# 4
#
#
#
#
#
#
#
#
#  Away
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 7
#
# 19
#
#
#
#
#
# Liverpool
# 7
#
# 16
#
#
#
#
#
# Manchester C.
# 7
#
# 16
#
#
#
#
#
# West Ham Utd
# 7
#
# 13
#
#
#
#
#
# Wolverhampton
# 7
#
# 11
#
#
#
#
#
# Manchester Utd
# 7
#
# 11
#
#
#
#
#
# Brighton
# 7
#
# 10
#
#
#
#
#
# Brentford
# 7
#
# 9
#
#
#
#
#
# Leicester City
# 7
#
# 9
#
#
#
#
#
# Tottenham
# 6
#
# 7
#
#
#
#
#
# Arsenal
# 7
#
# 7
#
#
#
#
#
# Watford
# 7
#
# 6
#
#
#
#
#
# Crystal Palace
# 7
#
# 6
#
#
#
#
#
# Leeds Utd
# 7
#
# 6
#
#
#
#
#
# Aston Villa
# 7
#
# 6
#
#
#
#
#
# Everton
# 7
#
# 5
#
#
#
#
#
# Southampton
# 7
#
# 5
#
#
#
#
#
# Norwich City
# 7
#
# 5
#
#
#
#
#
# Burnley
# 7
#
# 4
#
#
#
#
#
# Newcastle Utd
# 7
#
# 3
#
#
#
#
#
#
#
#
# Offense
#
#
# GP
# GF
#
#
#
#
# Liverpool
# 14
#
# 43
#
#
#
#
#
# Chelsea
# 14
#
# 33
#
#
#
#
#
# Manchester C.
# 14
#
# 29
#
#
#
#
#
# West Ham Utd
# 14
#
# 25
#
#
#
#
#
# Manchester Utd
# 14
#
# 24
#
#
#
#
#
# Leicester City
# 14
#
# 22
#
#
#
#
#
# Aston Villa
# 14
#
# 19
#
#
#
#
#
# Crystal Palace
# 14
#
# 19
#
#
#
#
#
# Watford
# 14
#
# 19
#
#
#
#
#
# Arsenal
# 14
#
# 17
#
#
#
#
#
# Brentford
# 14
#
# 17
#
#
#
#
#
# Everton
# 14
#
# 17
#
#
#
#
#
# Newcastle Utd
# 14
#
# 16
#
#
#
#
#
# Burnley
# 13
#
# 14
#
#
#
#
#
# Brighton
# 14
#
# 13
#
#
#
#
#
# Leeds Utd
# 14
#
# 13
#
#
#
#
#
# Southampton
# 14
#
# 13
#
#
#
#
#
# Tottenham
# 13
#
# 13
#
#
#
#
#
# Wolverhampton
# 14
#
# 12
#
#
#
#
#
# Norwich City
# 14
#
# 8
#
#
#
#
#
#
#
#
# Defense
#
#
# GP
# GA
#
#
#
#
# Chelsea
# 14
#
# 6
#
#
#
#
#
# Manchester C.
# 14
#
# 8
#
#
#
#
#
# Wolverhampton
# 14
#
# 12
#
#
#
#
#
# Liverpool
# 14
#
# 12
#
#
#
#
#
# Brighton
# 14
#
# 15
#
#
#
#
#
# West Ham Utd
# 14
#
# 17
#
#
#
#
#
# Tottenham
# 13
#
# 17
#
#
#
#
#
# Brentford
# 14
#
# 19
#
#
#
#
#
# Southampton
# 14
#
# 20
#
#
#
#
#
# Leeds Utd
# 14
#
# 20
#
#
#
#
#
# Crystal Palace
# 14
#
# 20
#
#
#
#
#
# Burnley
# 13
#
# 20
#
#
#
#
#
# Arsenal
# 14
#
# 20
#
#
#
#
#
# Aston Villa
# 14
#
# 23
#
#
#
#
#
# Manchester Utd
# 14
#
# 24
#
#
#
#
#
# Everton
# 14
#
# 24
#
#
#
#
#
# Leicester City
# 14
#
# 25
#
#
#
#
#
# Watford
# 14
#
# 26
#
#
#
#
#
# Norwich City
# 14
#
# 28
#
#
#
#
#
# Newcastle Utd
# 14
#
# 30
#
#
#
#
#
#
# advertisement
#
#
#
#
#
#
#
# Segments Table
#
#
#
#
#
# 0 pt
#
# 33 pts
#
#
#
# 5th Segment
# 4th Segment
# 3rd Segment
# 2nd Segment
# 1st Segment
#
#
# up to 6.2 pts
# from 6.3 to 12.9 pts
# from 13.0 to 19.6 pts
# from 19.7 to 26.3 pts
# from 26.4 to 33 pts
#
#
#
#
#
# (13)  10
# Burnley
# (14)  10
# Norwich City
# (14)  7
# Newcastle Utd
#
#
# (14)  19
# Brighton
# (14)  19
# Leicester City
# (14)  16
# Crystal Palace
# (14)  16
# Brentford
# (14)  16
# Aston Villa
# (14)  15
# Everton
# (14)  15
# Leeds Utd
# (14)  15
# Southampton
# (14)  13
# Watford
#
#
# (14)  24
# West Ham Utd
# (14)  23
# Arsenal
# (13)  22
# Tottenham
# (14)  21
# Manchester Utd
# (14)  21
# Wolverhampton
#
#
# (14)  33
# Chelsea
# (14)  32
# Manchester City
# (14)  31
# Liverpool
#
#
#
#
#
# The Segments Table is a visual representation splitting the teams into 5 segments. Each team is assigned to a specific segment, depending on the team's number of points. Each of the 5 segments spans one-fifth (20%) of the total points held by the team ranked 1st in the league. For each team, the number of matches played appears in green between brackets, and the number of points is displayed in black.
#
#
#
#
#
#
#
#
#
#
#
# International edition
#
#
#
#
#
#
#
# Among the player statistics, the number of goals scored at home and away by the players at the top of the goal scorers list can be displayed on England - Premier League top scorers
# for the season.
# The Liverpool results and statistical indicators can help provide insights on Liverpool's ranking
# in a variety of tables, for example to check how far the team or other teams are from the league leaders in the table.
# The type of data that can be featured includes the team's league matches and goal scoring indicators such as the average number of goals scored at home or away,
# streaks and sequences of results, offense and defense stats, how Liverpool's record compare with league average values all teams combined, along with form stats such as the
# average points per game in the team's last 8 results in England - Premier League.
#
#
#
#
#
#
#
#
#
#
#
# Follow us on Twitter
#
#
#
#
#
# F.A.Q.
# Contact
# Privacy Policy
#
#
# Change consent
#
#
#
# Terms & conditions of use
# Cookie usage and options
# About us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please note that match schedules and timing are subject to changes. Products, services, promotional offers and other offerings from partners and advertisers are subject to terms and conditions.
# By using this website you certify that you agree with the terms and conditions of use and the privacy policy and that you are over the age of 18 or that you have the permission of a parent or guardian to use this website, after your parent or guardian has carefully reviewed and agreed to the terms and conditions of use and the privacy policy.
# This website is not associated or endorsed by any league (whether professional, collegiate or other types of leagues / competitions), federation, association, club or team.
# All trademarks, brands, images, logos and names appearing on this website belong to their respective owners.
#
#  Useful links (third-party websites):
# GamCare (www.gamcare.org.uk)
# BeGambleAware (www.begambleaware.org)
#
#
#
#
#
#
#
#
#
# Copyright 1998-2021 SoccerSTATS.com
#
#
#
#
#
#
#
#
#
#
#
#
#
# advertisement
#
#
# advertisement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Liverpool statistics, latest results and form 2021/2022
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LEAGUES
#
#
# MATCHES
#
#
# STATS
#
#
# BLOG
#
#
# FAV
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MEMBERS
#
#
#
#
#
# ARATAUBEBRCHCZDED2DKENE2E3E4E5ESE2FIFRF2GRKRNLITI2JPNOPLPTRUSCSETRUA
#
#
#
#
# Premier League
#
#
# ----------------------
#
# Dashboard
#
# ----------------------
#
# ENG - Premier League
# ITA - Serie A
# SPA - La Liga
# FRA - Ligue 1
# GER - Bundesliga
#
#
# Champions League
# Europa League
# Copa Libertadores
# Champions League (W)
#
#
# EURO 2020
# World Cup 2018
# WC Qualification Europe
# WC Qual. South-America
# Euro 2020 Qualification
# UEFA Nations League
#
# ----------------------
#
# See 'Search league' box
# Display all leagues
#
# ----------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Premier League
#
#
#
#
# 2021/22 ▼
#
# 2021/22
# 2020/21
# 2019/20
# 2018/19
# 2017/18
# 2016/17
# 2015/16
# 2014/15
# 2013/14
#
#
#
#
#
#
#
#
#
#
#
#
# Statistics ▼
#
#  Tables
# Home / Away tables
# Form tables
# Half-time stats
# Stats by month
# Wide table
# Scorers table
# Run-in analysis
# Relative performance
# Relative form
# Home advantage
#  Matches
# Matches by date
# Matches by matchday
# Results grid
# Results filter
# Current streaks
#  Goals per match
# Over / Under
# Total Goals
# Goal ranges
# Average goals
# Scored / conceded
# Both teams scored
# Goal margins
#  Goal timing
# Goals per 10 min.
# Goals per 15 min.
# First goal timing
# Scored in both halves
#  Leading / losing
# Lead durations
# Scored / conceded first
# Leading / Trailing at HT
# Goal types
# Equalizers scored
# Equalizers conceded
#
#
#
#
#
#
#  other competitions ▼
#
# Premier LeagueChampionshipLeague OneLeague TwoNational LeagueNational L. NorthNational L. SouthIsthmian leagueNorthern leagueSouthern CentralSouthern SouthIsthmian Div. 1 NorthIsthmian Div. 1 South C.Isthmian Div. 1 South E.PL 2 Div. 1PL 2 Div. 2Women Super LeagueWomen ChampionshipProfessional Development League
#
#
#
#
#
# Teams ▼
#
# Arsenal
# Aston Villa
# Brentford
# Brighton
# Burnley
# Chelsea
# Crystal Palace
# Everton
# Leeds Utd
# Leicester City
# Liverpool
# Manchester City
# Manchester Utd
# Newcastle Utd
# Norwich City
# Southampton
# Tottenham
# Watford
# West Ham Utd
# Wolverhampton
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LATEST
# MATCHES
# FORM
# H2H
# GOALS
# HALF
# TIMING
# FIRST
#
#
#
#
#
#
#
#
# advertisement
#
#
#
#
#
# Liverpool stats
#
#
#
#
# Our website is made possible by displaying online advertisements to our visitors.
#
# If you are using an ad blocker, please consider supporting us by disabling the blocking of ads for our website in your ad blocker. Thank you.
# Alternatively you may also want to become a
# member.
#
#
#
#
#
#
#
#
#
#
#
# Liverpool
# (this season in the league)
#
#
#
#
# Latest results
#
#
# 1 Dec
# Everton - LIV
#
#
# 1 - 4
#
#  0 - 1 Jordan Henderson (9)A. Townsend  (16) 0 - 2 M. Salah (19)Allan  (31)D. Gray (38) 1 - 2 T. Alcantara  (39)Lucas Digne  (40)D. Gray  (44)HT: 1-2A. Robertson  (63) 1 - 3 M. Salah (64) 1 - 4 D. Jota (79)Virgil van Dijk  (80)FT: 1-4
#
#
#
# 27 Nov
# LIV - Southampton
#
#
# 4 - 0
#
# D. Jota (2) 1 - 0 J. Bednarek  (11)D. Jota (32) 2 - 0 T. Alcantara (37) 3 - 0 HT: 3-0Virgil van Dijk (52) 4 - 0 FT: 4-0
#
#
#
# 20 Nov
# LIV - Arsenal
#
#
# 4 - 0
#
# J. Klopp  (33)M. Arteta  (33)Sadio Mane (39) 1 - 0 Sadio Mane  (44)HT: 1-0D. Jota (52) 2 - 0 Fabinho  (70)M. Salah (73) 3 - 0 T. Minamino (77) 4 - 0 FT: 4-0
#
#
#
# 7 Nov
# West Ham Utd - LIV
#
#
# 3 - 2
#
# Alisson (o.g.) (4) 1 - 0  1 - 1 T. Alexander-Arnold (41)T. Soucek  (45)HT: 1-1T. Alexander-Arnold  (55)Pablo Fornals (67) 2 - 1 Kurt Zouma (74) 3 - 1  3 - 2 D. Origi (83)FT: 3-2
#
#
#
# 30 Oct
# LIV - Brighton
#
#
# 2 - 2
#
# Jordan Henderson (4) 1 - 0 Sadio Mane (24) 2 - 0  2 - 1 E. Mwepu (41)HT: 2-1 2 - 2 L. Trossard (65)T. Minamino  (88)T. Lamptey  (90)Shane Duffy  (90)A. Robertson  (90)FT: 2-2
#
#
#
# 24 Oct
# Manchester Utd - LIV
#
#
# 0 - 5
#
#  0 - 1 N. Keita (5) 0 - 2 D. Jota (13) 0 - 3 M. Salah (38)L. Shaw  (41)C. Ronaldo  (45)Fred  (45) 0 - 4 M. Salah (45)HT: 0-4B. Fernandes  (46) 0 - 5 M. Salah (50)Harry Maguire  (55)P. Pogba  (61)Aaron Wan-Bissaka  (86)FT: 0-5
#
#
#
# 16 Oct
# Watford - LIV
#
#
# 0 - 5
#
#  0 - 1 Sadio Mane (9) 0 - 2 R. Firmino (37)HT: 0-2 0 - 3 R. Firmino (52) 0 - 4 M. Salah (54) 0 - 5 R. Firmino (90)FT: 0-5
#
#
#
# 3 Oct
# LIV - Manchester City
#
#
# 2 - 2
#
# Ruben Dias  (26)J. Milner  (42)HT: 0-0Joao Cancelo  (56)Sadio Mane (59) 1 - 0 D. Jota  (65) 1 - 1 P. Foden (69)M. Salah (76) 2 - 1 Bernardo Silva  (77) 2 - 2 K. De Bruyne (81)Fabinho  (83)FT: 2-2
#
#
#
#
#
#
# Seasonal match statistics
#
#
#
# Played
# W
#
# D
#
#
# L
#
#
#
# W D L %
#
#
#
# Home
#
# 7
# 4
# 3
# 0
#
#
#
#
#
#
# Away
#
# 7
# 5
# 1
# 1
#
#
#
#
#
#
# Total
#
# 14
# 9
# 4
# 1
#
#
#
#
#
#
#
# Points per game:
#
# 2.21
#
#
#
#
# Relative form
# Stats
# AllLast 8
# Diff.
# Points per Game2.21
# 2.13
# -3.6%
# Average goals scored3.07
# 3.50
# +14.0%
# Average goals conceded0.86
# 1.00
# +16.3%
#
#
#
#
#
# Form
# With the 1-4 away win at Everton, Liverpool are on a 3-match winning run in the league. The team has won 5 of their last 8 matches in Premier League. Liverpool have conceded an average of 0.86 goals per game since the beginning of the season in the league. Liverpool form stats indicate an average number of goals conceded per game of 1.00 in the last 8 league matches, which is 16.3% higher than their current season's average.
#
#
#
#
#
#
# advertisement
#
#
#
#
#
# advertisement
#
#
#
#
#
#
# Results
#
#
#
#
#
# 2.5+
#
# CS
#
# FTS
#
#
# HT
#
#
#
#
#
# 14 Aug
#
#
#
# Norwich City
#
#
#
# 0 - 3
#
# J. Milner  (25) 0 - 1 D. Jota (26)HT: 0-1T. Cantwell  (53) 0 - 2 R. Firmino (65) 0 - 3 M. Salah (74)FT: 0-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-1
#
#
# stats
#
#
#
#
# 21 Aug
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 0
#
# D. Jota (18) 1 - 0 HT: 1-0Sadio Mane (69) 2 - 0 FT: 2-0
#
#
#
#
# Burnley
#
#
# -
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 28 Aug
#
#
#
#
# Liverpool
#
#
#
#
# 1 - 1
#
#  0 - 1 K. Havertz (22)Antonio Rudiger  (45)R. James  (45)M. Salah pen. (45) 1 - 1 Edouard Mendy  (45)FT: 1-1
#
#
#
#
# Chelsea
#
#
# -
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 12 Sep
#
#
#
# Leeds Utd
#
#
#
# 0 - 3
#
# L. Cooper  (12)Fabinho  (16) 0 - 1 M. Salah (20)D. Llorente  (31)HT: 0-1 0 - 2 Fabinho (50)Pascal Struijk  (60) 0 - 3 Sadio Mane (90)FT: 0-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-1
#
#
# stats
#
#
#
#
# 18 Sep
#
#
#
#
# Liverpool
#
#
#
#
# 3 - 0
#
# Jordan Henderson  (40)Sadio Mane (43) 1 - 0 HT: 1-0K. Tsimikas  (75)M. Salah (78) 2 - 0 M. Salah  (79)Joel Ward  (83)N. Keita (89) 3 - 0 FT: 3-0
#
#
#
#
# Crystal Palace
#
#
# +
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 25 Sep
#
#
#
# Brentford
#
#
#
# 3 - 3
#
# Ethan Pinnock (27) 1 - 0  1 - 1 D. Jota (31)F. Onyeka  (44)HT: 1-1 1 - 2 M. Salah (54)Vitaly Janelt (63) 2 - 2  2 - 3 C. Jones (67)A. Robertson  (70)Y. Wissa (82) 3 - 3 FT: 3-3
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 3 Oct
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 2
#
# Ruben Dias  (26)J. Milner  (42)HT: 0-0Joao Cancelo  (56)Sadio Mane (59) 1 - 0 D. Jota  (65) 1 - 1 P. Foden (69)M. Salah (76) 2 - 1 Bernardo Silva  (77) 2 - 2 K. De Bruyne (81)Fabinho  (83)FT: 2-2
#
#
#
#
# Manchester City
#
#
# +
#
#
# -
#
#
# -
#
#
# 0-0
#
#
# stats
#
#
#
#
# 16 Oct
#
#
#
# Watford
#
#
#
# 0 - 5
#
#  0 - 1 Sadio Mane (9) 0 - 2 R. Firmino (37)HT: 0-2 0 - 3 R. Firmino (52) 0 - 4 M. Salah (54) 0 - 5 R. Firmino (90)FT: 0-5
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-2
#
#
# stats
#
#
#
#
# 24 Oct
#
#
#
# Manchester Utd
#
#
#
# 0 - 5
#
#  0 - 1 N. Keita (5) 0 - 2 D. Jota (13) 0 - 3 M. Salah (38)L. Shaw  (41)C. Ronaldo  (45)Fred  (45) 0 - 4 M. Salah (45)HT: 0-4B. Fernandes  (46) 0 - 5 M. Salah (50)Harry Maguire  (55)P. Pogba  (61)Aaron Wan-Bissaka  (86)FT: 0-5
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# +
#
#
# -
#
#
# 0-4
#
#
# stats
#
#
#
#
# 30 Oct
#
#
#
#
# Liverpool
#
#
#
#
# 2 - 2
#
# Jordan Henderson (4) 1 - 0 Sadio Mane (24) 2 - 0  2 - 1 E. Mwepu (41)HT: 2-1 2 - 2 L. Trossard (65)T. Minamino  (88)T. Lamptey  (90)Shane Duffy  (90)A. Robertson  (90)FT: 2-2
#
#
#
#
# Brighton
#
#
# +
#
#
# -
#
#
# -
#
#
# 2-1
#
#
# stats
#
#
#
#
# 7 Nov
#
#
#
# West Ham Utd
#
#
#
# 3 - 2
#
# Alisson (o.g.) (4) 1 - 0  1 - 1 T. Alexander-Arnold (41)T. Soucek  (45)HT: 1-1T. Alexander-Arnold  (55)Pablo Fornals (67) 2 - 1 Kurt Zouma (74) 3 - 1  3 - 2 D. Origi (83)FT: 3-2
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-1
#
#
# stats
#
#
#
#
# 20 Nov
#
#
#
#
# Liverpool
#
#
#
#
# 4 - 0
#
# J. Klopp  (33)M. Arteta  (33)Sadio Mane (39) 1 - 0 Sadio Mane  (44)HT: 1-0D. Jota (52) 2 - 0 Fabinho  (70)M. Salah (73) 3 - 0 T. Minamino (77) 4 - 0 FT: 4-0
#
#
#
#
# Arsenal
#
#
# +
#
#
# +
#
#
# -
#
#
# 1-0
#
#
# stats
#
#
#
#
# 27 Nov
#
#
#
#
# Liverpool
#
#
#
#
# 4 - 0
#
# D. Jota (2) 1 - 0 J. Bednarek  (11)D. Jota (32) 2 - 0 T. Alcantara (37) 3 - 0 HT: 3-0Virgil van Dijk (52) 4 - 0 FT: 4-0
#
#
#
#
# Southampton
#
#
# +
#
#
# +
#
#
# -
#
#
# 3-0
#
#
# stats
#
#
#
#
# 1 Dec
#
#
#
# Everton
#
#
#
# 1 - 4
#
#  0 - 1 Jordan Henderson (9)A. Townsend  (16) 0 - 2 M. Salah (19)Allan  (31)D. Gray (38) 1 - 2 T. Alcantara  (39)Lucas Digne  (40)D. Gray  (44)HT: 1-2A. Robertson  (63) 1 - 3 M. Salah (64) 1 - 4 D. Jota (79)Virgil van Dijk  (80)FT: 1-4
#
#
#
#
#
# Liverpool
#
#
#
# +
#
#
# -
#
#
# -
#
#
# 1-2
#
#
# stats
#
#
#
#
#
#
# Filter Liverpool results
#
#
#
#
#
#
#
#
#
# Points Per Game
#
#
#
# Home
#
#
# Away
#
# Opponent
#
#
#
# 4 Dec
#
#
# Wolverhampton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 11 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Aston Villa
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 16 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Newcastle Utd
#
#
# 2.14
#
#
# 0.43
#
#
#
#
#
# 19 Dec
#
#
# Tottenham
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.14
#
#
# 2.29
#
#
#
#
#
# 26 Dec
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Leeds Utd
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 28 Dec
#
#
# Leicester City
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 2 Jan
#
#
# Chelsea
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.00
#
#
# 2.29
#
#
#
#
#
# 15 Jan
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Brentford
#
#
# 2.14
#
#
# 1.29
#
#
#
#
#
# 23 Jan
#
#
# Crystal Palace
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 9 Feb
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Leicester City
#
#
# 2.14
#
#
# 1.29
#
#
#
#
#
# 12 Feb
#
#
# Burnley
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.00
#
#
# 2.29
#
#
#
#
#
# 19 Feb
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Norwich City
#
#
# 2.14
#
#
# 0.71
#
#
#
#
#
# 26 Feb
#
#
# Arsenal
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.29
#
#
# 2.29
#
#
#
#
#
# 5 Mar
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# West Ham Utd
#
#
# 2.14
#
#
# 1.86
#
#
#
#
#
# 12 Mar
#
#
# Brighton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.29
#
#
# 2.29
#
#
#
#
#
# 19 Mar
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Manchester Utd
#
#
# 2.14
#
#
# 1.57
#
#
#
#
#
# 2 Apr
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Watford
#
#
# 2.14
#
#
# 0.86
#
#
#
#
#
# 9 Apr
#
#
# Manchester City
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 2.29
#
#
# 2.29
#
#
#
#
#
# 16 Apr
#
#
# Aston Villa
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 23 Apr
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Everton
#
#
# 2.14
#
#
# 0.71
#
#
#
#
#
# 30 Apr
#
#
# Newcastle Utd
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 0.57
#
#
# 2.29
#
#
#
#
#
# 7 May
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Tottenham
#
#
# 2.14
#
#
# 1.17
#
#
#
#
#
# 15 May
#
#
# Southampton
#
#
# h2h
#
#
#
# Liverpool
#
#
#
# 1.43
#
#
# 2.29
#
#
#
#
#
# 22 May
#
#
#
# Liverpool
#
#
#
# h2h
#
#
# Wolverhampton
#
#
# 2.14
#
#
# 1.57
#
#
#
#
# Average of Opponent PPG values above
#
#
# 1.33
#
#
#
#
#
#
#
#
#
#
# The Points Per Game values are calculated based on Home results only for the home team and away results only for the visiting team.
#
#
#
# Run-in overview
#
#
# Of their 24 remaining matches in the English Premier League, Liverpool will be playing as many matches at home and away (12 in each case).
# Considering the opponents' Points Per Game (PPG) values above, Liverpool's remaining away matches feature a higher combined opposition PPG average than their remaining home matches.
# ...
#
#
#
#
#
#
#
#   Liverpool
#
#  Leading & trailing stats (away)
# (this season in the league, away matches)
#
#
#
# OPENING GOALS (away)
#
# Matches
#
#
# Team scored first
# 5 / 771%
#
# Opponent scored first
# 2 / 729%
#
#
#
#
# HALF-TIME LEAD (away)
#
# Matches
#
#
# Team was leading at half-time
# 5 / 771%
#
# Opponent was leading at half-time
# 0 / 70%
#
#
#
#
# LEAD STATUS AVERAGE MINUTES (away)
#
# per match
#
#
# Average minutes leading
# 57.9 min.
#
# Average minutes level in goals
# 23.0 min.
#
# Average minutes trailing
# 9.1 min.
#
#
# Note: in the table above, to allow for averaging duration values based on a total of 90 minutes per game, goals scored on the 45th minute and during added time of the first half are all considered to be scored on the 45th minute, and goals scored on the 90th minute and during added time of the second half are also considered scored on the 90th minute.
#
#
#
# In this example, Liverpool have been in the lead for an average duration of 57.9 minutes per match played away (based on a 90-minute match duration), which is longer than the average duration of 9.1 minutes per match during which their opponents were in the lead in those matches.
#
#
#
#
#
#   Liverpool
#
#  Equalizer goals (away)
# (this season in the league, away matches)
#
#
#
# Matches played
# 7
#
#
#
#
# DEFENDING THE LEAD (away)
#
#
# Goals giving the lead
# 7
#
# Equalizer goals conceded
# 2
#
# Opponents' equalizing rate
# * (1)29%
#
#
#
#
# EQUALIZING (away)
#
#
# Goals giving the lead to the opponent
# 3
#
# Equalizer goals scored
# 2
#
# Equalizing rate
# * (2)67%
#
#
#
#
# NON-CRUCIAL GOALS (away)
#
#
# Non-crucial goals scored
# 16
#
# Non-crucial goals conceded
# 2
#
#
# (1) (Equalizer goals conceded / Goals giving lead) * 100
# (2) (Equalizer goals scored / Goals giving lead to opponent) * 100
#
#
# Non-crucial goals scored: goals scored that increased an existing lead, or decreased the opponent's existing lead.
# Non-crucial goals conceded: goals conceded that decreased an existing lead, or increased the opponent's existing lead.
#
# Note regarding the Goals giving the lead and the Goals giving the lead to the opponent values: both the team and the opponent team might take the lead more than once during a single match,
# so the total number of goals giving the lead to a team might be higher than the number of matches played by the team.
# For more info on how many times each team has taken the lead per match or how many times per match their opponents have taken the lead, you may want to view the following pages:
# Goals giving the lead and equalizers conceded
# Goals giving lead to opponent and equalizers scored
#
# Lead-defending ability (away)In away matches, Liverpool have taken the lead 7 times and have conceded an equalizer on 2 occasions, translating into an away lead-defending rate of 71% (for an opponents' equalizing rate of 29%).
#
#
# Equalizing ability (away)Of the 3 times that Liverpool's opponents have taken the lead when Liverpool were playing away, Liverpool have managed to score an equalizer on 2 occasions, translating into an away equalizing rate of 67%.
#
#
#
#
#
#
#
#
#
#
# Liverpool's progression
#
#
#
#
#
#
#
#
#
#
# Line graph variation: win: +2, draw: 0, defeat: -1
#
#
#
#
#
#
#
#
#
#
# Results table
#
#
# GP
# Pts
# Home
# Away
# h2h
#
#
# 1
# Chelsea
# 14
# 33
# 1 - 1
#
# 2 Jan
#
# h2h
#
#
# 2
# Manchester City
# 14
# 32
# 2 - 2
#
# 9 Apr
#
# h2h
#
# 3
# Liverpool
# 14
# 31
#
#
#
# 4
# West Ham Utd
# 14
# 24
#
# 5 Mar
#
# 3 - 2
# h2h
#
#
# 5
# Arsenal
# 14
# 23
# 4 - 0
#
# 26 Feb
#
# h2h
#
#
# 6
# Tottenham
# 13
# 22
#
# 7 May
#
#
# 19 Dec
#
# h2h
#
#
# 7
# Manchester Utd
# 14
# 21
#
# 19 Mar
#
# 0 - 5
# h2h
#
#
# 8
# Wolverhampton
# 14
# 21
#
# 22 May
#
#
# 4 Dec
#
# h2h
#
#
# 9
# Brighton
# 14
# 19
# 2 - 2
#
# 12 Mar
#
# h2h
#
#
# 10
# Leicester City
# 14
# 19
#
# 9 Feb
#
#
# 28 Dec
#
# h2h
#
#
# 11
# Crystal Palace
# 14
# 16
# 3 - 0
#
# 23 Jan
#
# h2h
#
#
# 12
# Brentford
# 14
# 16
#
# 15 Jan
#
# 3 - 3
# h2h
#
#
# 13
# Aston Villa
# 14
# 16
#
# 11 Dec
#
#
# 16 Apr
#
# h2h
#
#
# 14
# Everton
# 14
# 15
#
# 23 Apr
#
# 1 - 4
# h2h
#
#
# 15
# Leeds Utd
# 14
# 15
#
# 26 Dec
#
# 0 - 3
# h2h
#
#
# 16
# Southampton
# 14
# 15
# 4 - 0
#
# 15 May
#
# h2h
#
#
# 17
# Watford
# 14
# 13
#
# 2 Apr
#
# 0 - 5
# h2h
#
#
# 18
# Burnley
# 13
# 10
# 2 - 0
#
# 12 Feb
#
# h2h
#
#
# 19
# Norwich City
# 14
# 10
#
# 19 Feb
#
# 0 - 3
# h2h
#
#
# 20
# Newcastle Utd
# 14
# 7
#
# 16 Dec
#
#
# 30 Apr
#
# h2h
#
#
#
# Liverpool stats rank the team in 3rd position in the Premier League table with 31 points, 1 point behind Manchester City and 7 points above West Ham Utd.
# The above table shows Liverpool results against each league opponent.
# The tables below provide additional statistics regarding Liverpool's season in the English Premier League.
#
#
#
#
#
#
# Goals scored & conceded
#
#
# SCORING
#
# Home
#
# Away
#
# All
#
#
# Goals scored
# 182543
#
# Goals scored per match
# 2.573.57 3.07
#
# Goals conceded
# 5712
#
# Goals conceded per match
# 0.711.00 0.86
#
# Scored+conc. per match
# 3.294.573.93
#
# Matches over 1.5 goals
# 100%100%100%
#
# Matches over 2.5 goals
# 71%100%86%
#
# Matches over 3.5 goals
# 57%71%64%
#
# Matches over 4.5 goals
# 0%71%36%
#
# Matches over 5.5 goals
# 0%14%7%
#
# Over 0.5 g. at half-time
# 86%100%93%
#
# Over 1.5 g. at half-time
# 43%71%57%
#
# Over 2.5 g. at half-time
# 29%29%29%
#
#
# Liverpool over 2.5 stats indicate a 86% value for the proportion of matches involving the team that had a total of over 2.5 goals, which is higher than the league average value of 53% of league matches that the over under stats indicate had a total number of goals over 2.5 this season in Premier League.
#
#
#
#
# League goals statistics
#
#
#
#
#
# Scoring patterns
#
#
# GOAL / NO GOAL
#
# Home
#
# Away
#
# Total
#
#
# Clean sheets
# 57%57%57%
#
# Won-to-nil
# 57%57%57%
#
# Scored in both halves
# 57%100%79%
#
# Both teams scored
# 43%43%43%
#
# Failed to score
# 0%0%0%
#
# Lost-to-nil
# 0%0%0%
#
# Conceded in both halves
# 14%29%21%
#
#
# League Scored in Both Halves stats
#
#
#
#
#
# Total goals in Liverpool matches
#
#
# SCORED + CONCEDED
#
# Home
#
# Away
#
# Total
#
#
# Match total goals = 0
# 0%0%0%
#
# Match total goals = 1
# 0%0%0%
#
# Match total goals = 2
# 29%0%14%
#
# Match total goals = 3
# 14%29%21%
#
# Match total goals = 4
# 57%0%29%
#
# Match total goals = 5+
# 0%71%36%
#
# Match total goals = 0 or 1
# 0%0%0%
#
# Match total goals = 2 or 3
# 43%29%36%
#
# Match total goals = 4+
# 57%71%64%
#
#
# League Total Goals stats
#
#
#
#
#
# Goal margins
#
#
#
# WINNING MARGINS
#  1  2
#  3  4+
#
#
#
# Home wins
#  01
# 12
#
#
#
# Away wins
#  00
# 32
#
#
#
# Home & Away wins
#  01
# 44
#
#
#
# LOSING MARGINS
#  1  2
#  3  4+
#
#
#
# Home defeats
#  00
# 00
#
#
#
# Away defeats
#  10
# 00
#
#
#
# Home & Away defeats
#  10
# 00
#
#
#
# A majority of Liverpool's wins have been obtained with a margin of 2 goals or more (9 wins), while 0 of their wins had a one-goal margin.
#
#
#
#
# League Goal Margin stats
#
#
#
#
#
# Half-time lead
#
#
# Half-time
#
# Home
#
# Away
#
# Total
#
#
# Leading at HT
# 55 10
# 71%
#
# Drawing at HT
# 22 4
# 29%
#
# Losing at HT
# 00 0
# 0%
#
# Total
# 7714
#
#
# League Half-time stats
#
#
#
#
#
# Team corners (corners awarded)
#
#
# Avg
# 2.5+
# 3.5+
# 4.5+
# 5.5+
# 6.5+
#
# Home
# 7.00
# 100%
# 86%
# 86%
# 57%
# 43%
# Away
# 8.29
# 86%
# 71%
# 71%
# 71%
# 71%
# Total
# 7.64
# 93%
# 79%
# 79%
# 64%
# 57%
#
#
#
# Opponents corners (corners conceded)
#
#
# Avg
# 2.5+
# 3.5+
# 4.5+
# 5.5+
# 6.5+
#
# Home
# 3.86
# 86%
# 57%
# 29%
# 14%
# 14%
# Away
# 2.86
# 57%
# 14%
# 14%
# 14%
# 0%
# Total
# 3.36
# 71%
# 36%
# 21%
# 14%
# 7%
#
#
#
# Total corners (team + opponents)
#
#
# Avg
# 9.5+
# 10.5+
# 11.5+
# 12.5+
# 13.5+
#
# Home
# 10.86
# 57%
# 57%
# 57%
# 29%
# 29%
# Away
# 11.14
# 71%
# 57%
# 57%
# 57%
# 29%
# Total
# 11.00
# 64%
# 57%
# 57%
# 43%
# 29%
#
#
#
# The average of 11.00 total corners for Liverpool refers to how the corner stats evaluate the total number of corners per match (corners awarded + corners conceded) in matches involving the team this season in Premier League.
#
#
#
#
# League Corner Stats
#
#
#
#
#
# Goal times
#
#
#
#
#   Liverpool
#
# (this season in the league)
#
#
#
# GOALS PER TIME SEGMENT (total)
# 0-15
# GF
# 6
#
#
# GA
# 1
#
# 16-30
# GF
# 5
#
#
# GA
# 2
#
# 31-45
# GF
# 10
#
#
# GA
# 2
#
#
# 46-60
# GF
# 8
#
#
# GA
# 0
#
# 61-75
# GF
# 6
#
#
# GA
# 5
#
# 76-90
# GF
# 8
#
#
# GA
# 2
#
#
#
# 1st half
#
# GF
# 21
#
#
# 49%
#
#
#
# GA
# 5
#
#
# 42%
#
#
#
#
# 2nd half
#
# GF
# 22
#
#
# 51%
#
#
#
# GA
# 7
#
#
# 58%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (total)
#
#
#  Avg. minute
# goals scored
# 47
#
#  Avg. minute
# goals conceded
# 53
#
#
#
#
#
#
#   Liverpool
#
# (this season in the league, home matches)
#
#
#
# GOALS PER TIME SEGMENT (home)
# 0-15
# GF
# 2
#
#
# GA
# 0
#
# 16-30
# GF
# 2
#
#
# GA
# 1
#
# 31-45
# GF
# 5
#
#
# GA
# 1
#
#
# 46-60
# GF
# 3
#
#
# GA
# 0
#
# 61-75
# GF
# 2
#
#
# GA
# 2
#
# 76-90
# GF
# 4
#
#
# GA
# 1
#
#
#
# 1st half
#
# GF
# 9
#
#
# 50%
#
#
#
# GA
# 2
#
#
# 40%
#
#
#
#
# 2nd half
#
# GF
# 9
#
#
# 50%
#
#
#
# GA
# 3
#
#
# 60%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (home)
#
#
# Avg. minute
# goals scored
# 48
#
# Avg. minute
# goals conceded
# 56
#
#
#
#
#
#
#   Liverpool
#
# (this season in the league, away matches)
#
#
#
# GOALS PER TIME SEGMENT (away)
# 0-15
# GF
# 4
#
#
# GA
# 1
#
# 16-30
# GF
# 3
#
#
# GA
# 1
#
# 31-45
# GF
# 5
#
#
# GA
# 1
#
#
# 46-60
# GF
# 5
#
#
# GA
# 0
#
# 61-75
# GF
# 4
#
#
# GA
# 3
#
# 76-90
# GF
# 4
#
#
# GA
# 1
#
#
#
# 1st half
#
# GF
# 12
#
#
# 48%
#
#
#
# GA
# 3
#
#
# 43%
#
#
#
#
# 2nd half
#
# GF
# 13
#
#
# 52%
#
#
#
# GA
# 4
#
#
# 57%
#
#
#
#
# '31-45' and '76-90' include added time
#
# GF: Goals scored ('goals for')
#
# GA: Goals conceded ('goals against')
#
#
#
#
# AVERAGE MINUTES (away)
#
#
# Avg. minute
# goals scored
# 47
#
# Avg. minute
# goals conceded
# 51
#
#
#
#
#
# League Goal Times
#
#
# Liverpool scores
#
#
#
#
#
# FT at home
#
#
#
#
# 2-2
#
# 2
#
#
#
# 29%
#
#
#
#
# 4-0
#
# 2
#
#
#
# 29%
#
#
#
#
# 1-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-0
#
# 1
#
#
#
# 14%
#
#
#
#
# 2-0
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
# FT away
#
#
#
#
# 0-5
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-3
#
# 2
#
#
#
# 29%
#
#
#
#
# 1-4
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-3
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-2
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Half-time at home
#
#
#
#
# 1-0
#
# 3
#
#
#
# 43%
#
#
#
#
# 2-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 1-1
#
# 1
#
#
#
# 14%
#
#
#
#
# 3-0
#
# 1
#
#
#
# 14%
#
#
#
#
# 0-0
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
# Half-time away
#
#
#
#
# 1-1
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-1
#
# 2
#
#
#
# 29%
#
#
#
#
# 0-4
#
# 1
#
#
#
# 14%
#
#
#
#
# 1-2
#
# 1
#
#
#
# 14%
#
#
#
#
# 0-2
#
# 1
#
#
#
# 14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# This season in the league
#
#
# Liverpool have won 71% of their away matches.
#
#
# Liverpool have scored in each of their last 14 matches.
#
#
# 86% of Liverpool's matches had over 2.5 goals scored in total.
#
#
# Liverpool have scored in 100% of their home matches.
#
#
# Liverpool did not concede any goal in 57% of their away matches.
#
#
# Liverpool have scored in 100% of their away matches.
#
#
# Liverpool have scored the opening goal in 79% of their matches.
#
#
# Liverpool were leading at half-time in 71% of their matches.
#
#
# Liverpool have scored in each of their last 7 away matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 11 matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 5 home matches.
#
#
# Liverpool have scored 2 goals or more in each of their last 7 away matches.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Liverpool table
#
#
#
#
#
# League table
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 14
#
# 33
#
#
#
#
#
# Manchester C.
# 14
#
# 32
#
#
#
#
#
# Liverpool
# 14
#
# 31
#
#
#
#
#
# West Ham Utd
# 14
#
# 24
#
#
#
#
#
# Arsenal
# 14
#
# 23
#
#
#
#
#
# Tottenham
# 13
#
# 22
#
#
#
#
#
# Manchester Utd
# 14
#
# 21
#
#
#
#
#
# Wolverhampton
# 14
#
# 21
#
#
#
#
#
# Brighton
# 14
#
# 19
#
#
#
#
#
# Leicester City
# 14
#
# 19
#
#
#
#
#
# Crystal Palace
# 14
#
# 16
#
#
#
#
#
# Brentford
# 14
#
# 16
#
#
#
#
#
# Aston Villa
# 14
#
# 16
#
#
#
#
#
# Everton
# 14
#
# 15
#
#
#
#
#
# Leeds Utd
# 14
#
# 15
#
#
#
#
#
# Southampton
# 14
#
# 15
#
#
#
#
#
# Watford
# 14
#
# 13
#
#
#
#
#
# Burnley
# 13
#
# 10
#
#
#
#
#
# Norwich City
# 14
#
# 10
#
#
#
#
#
# Newcastle Utd
# 14
#
# 7
#
#
#
#
#
#
#
#
# Form table (last 8)
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 8
#
# 20
#
#
#
#
#
# Manchester C.
# 8
#
# 19
#
#
#
#
#
# Liverpool
# 8
#
# 17
#
#
#
#
#
# Wolverhampton
# 8
#
# 15
#
#
#
#
#
# Arsenal
# 8
#
# 14
#
#
#
#
#
# West Ham Utd
# 8
#
# 13
#
#
#
#
#
# Tottenham
# 8
#
# 13
#
#
#
#
#
# Leeds Utd
# 8
#
# 12
#
#
#
#
#
# Leicester City
# 8
#
# 12
#
#
#
#
#
# Southampton
# 8
#
# 11
#
#
#
#
#
# Crystal Palace
# 8
#
# 10
#
#
#
#
#
# Norwich City
# 8
#
# 10
#
#
#
#
#
# Burnley
# 8
#
# 9
#
#
#
#
#
# Manchester Utd
# 8
#
# 8
#
#
#
#
#
# Brentford
# 8
#
# 7
#
#
#
#
#
# Watford
# 8
#
# 6
#
#
#
#
#
# Brighton
# 8
#
# 6
#
#
#
#
#
# Aston Villa
# 8
#
# 6
#
#
#
#
#
# Newcastle Utd
# 8
#
# 4
#
#
#
#
#
# Everton
# 8
#
# 2
#
#
#
#
#
#
#
#
#  Home
#
#
# GP
# Pts
#
#
#
#
# Manchester C.
# 7
#
# 16
#
#
#
#
#
# Arsenal
# 7
#
# 16
#
#
#
#
#
# Liverpool
# 7
#
# 15
#
#
#
#
#
# Tottenham
# 7
#
# 15
#
#
#
#
#
# Chelsea
# 7
#
# 14
#
#
#
#
#
# West Ham Utd
# 7
#
# 11
#
#
#
#
#
# Crystal Palace
# 7
#
# 10
#
#
#
#
#
# Aston Villa
# 7
#
# 10
#
#
#
#
#
# Southampton
# 7
#
# 10
#
#
#
#
#
# Manchester Utd
# 7
#
# 10
#
#
#
#
#
# Everton
# 7
#
# 10
#
#
#
#
#
# Leicester City
# 7
#
# 10
#
#
#
#
#
# Wolverhampton
# 7
#
# 10
#
#
#
#
#
# Leeds Utd
# 7
#
# 9
#
#
#
#
#
# Brighton
# 7
#
# 9
#
#
#
#
#
# Brentford
# 7
#
# 7
#
#
#
#
#
# Watford
# 7
#
# 7
#
#
#
#
#
# Burnley
# 6
#
# 6
#
#
#
#
#
# Norwich City
# 7
#
# 5
#
#
#
#
#
# Newcastle Utd
# 7
#
# 4
#
#
#
#
#
#
#
#
#  Away
#
#
# GP
# Pts
#
#
#
#
# Chelsea
# 7
#
# 19
#
#
#
#
#
# Liverpool
# 7
#
# 16
#
#
#
#
#
# Manchester C.
# 7
#
# 16
#
#
#
#
#
# West Ham Utd
# 7
#
# 13
#
#
#
#
#
# Wolverhampton
# 7
#
# 11
#
#
#
#
#
# Manchester Utd
# 7
#
# 11
#
#
#
#
#
# Brighton
# 7
#
# 10
#
#
#
#
#
# Brentford
# 7
#
# 9
#
#
#
#
#
# Leicester City
# 7
#
# 9
#
#
#
#
#
# Tottenham
# 6
#
# 7
#
#
#
#
#
# Arsenal
# 7
#
# 7
#
#
#
#
#
# Watford
# 7
#
# 6
#
#
#
#
#
# Crystal Palace
# 7
#
# 6
#
#
#
#
#
# Leeds Utd
# 7
#
# 6
#
#
#
#
#
# Aston Villa
# 7
#
# 6
#
#
#
#
#
# Everton
# 7
#
# 5
#
#
#
#
#
# Southampton
# 7
#
# 5
#
#
#
#
#
# Norwich City
# 7
#
# 5
#
#
#
#
#
# Burnley
# 7
#
# 4
#
#
#
#
#
# Newcastle Utd
# 7
#
# 3
#
#
#
#
#
#
#
#
# Offense
#
#
# GP
# GF
#
#
#
#
# Liverpool
# 14
#
# 43
#
#
#
#
#
# Chelsea
# 14
#
# 33
#
#
#
#
#
# Manchester C.
# 14
#
# 29
#
#
#
#
#
# West Ham Utd
# 14
#
# 25
#
#
#
#
#
# Manchester Utd
# 14
#
# 24
#
#
#
#
#
# Leicester City
# 14
#
# 22
#
#
#
#
#
# Aston Villa
# 14
#
# 19
#
#
#
#
#
# Crystal Palace
# 14
#
# 19
#
#
#
#
#
# Watford
# 14
#
# 19
#
#
#
#
#
# Arsenal
# 14
#
# 17
#
#
#
#
#
# Brentford
# 14
#
# 17
#
#
#
#
#
# Everton
# 14
#
# 17
#
#
#
#
#
# Newcastle Utd
# 14
#
# 16
#
#
#
#
#
# Burnley
# 13
#
# 14
#
#
#
#
#
# Brighton
# 14
#
# 13
#
#
#
#
#
# Leeds Utd
# 14
#
# 13
#
#
#
#
#
# Southampton
# 14
#
# 13
#
#
#
#
#
# Tottenham
# 13
#
# 13
#
#
#
#
#
# Wolverhampton
# 14
#
# 12
#
#
#
#
#
# Norwich City
# 14
#
# 8
#
#
#
#
#
#
#
#
# Defense
#
#
# GP
# GA
#
#
#
#
# Chelsea
# 14
#
# 6
#
#
#
#
#
# Manchester C.
# 14
#
# 8
#
#
#
#
#
# Wolverhampton
# 14
#
# 12
#
#
#
#
#
# Liverpool
# 14
#
# 12
#
#
#
#
#
# Brighton
# 14
#
# 15
#
#
#
#
#
# West Ham Utd
# 14
#
# 17
#
#
#
#
#
# Tottenham
# 13
#
# 17
#
#
#
#
#
# Brentford
# 14
#
# 19
#
#
#
#
#
# Southampton
# 14
#
# 20
#
#
#
#
#
# Leeds Utd
# 14
#
# 20
#
#
#
#
#
# Crystal Palace
# 14
#
# 20
#
#
#
#
#
# Burnley
# 13
#
# 20
#
#
#
#
#
# Arsenal
# 14
#
# 20
#
#
#
#
#
# Aston Villa
# 14
#
# 23
#
#
#
#
#
# Manchester Utd
# 14
#
# 24
#
#
#
#
#
# Everton
# 14
#
# 24
#
#
#
#
#
# Leicester City
# 14
#
# 25
#
#
#
#
#
# Watford
# 14
#
# 26
#
#
#
#
#
# Norwich City
# 14
#
# 28
#
#
#
#
#
# Newcastle Utd
# 14
#
# 30
#
#
#
#
#
#
# advertisement
#
#
#
#
#
#
#
# Segments Table
#
#
#
#
#
# 0 pt
#
# 33 pts
#
#
#
# 5th Segment
# 4th Segment
# 3rd Segment
# 2nd Segment
# 1st Segment
#
#
# up to 6.2 pts
# from 6.3 to 12.9 pts
# from 13.0 to 19.6 pts
# from 19.7 to 26.3 pts
# from 26.4 to 33 pts
#
#
#
#
#
# (13)  10
# Burnley
# (14)  10
# Norwich City
# (14)  7
# Newcastle Utd
#
#
# (14)  19
# Brighton
# (14)  19
# Leicester City
# (14)  16
# Crystal Palace
# (14)  16
# Brentford
# (14)  16
# Aston Villa
# (14)  15
# Everton
# (14)  15
# Leeds Utd
# (14)  15
# Southampton
# (14)  13
# Watford
#
#
# (14)  24
# West Ham Utd
# (14)  23
# Arsenal
# (13)  22
# Tottenham
# (14)  21
# Manchester Utd
# (14)  21
# Wolverhampton
#
#
# (14)  33
# Chelsea
# (14)  32
# Manchester City
# (14)  31
# Liverpool
#
#
#
#
#
# The Segments Table is a visual representation splitting the teams into 5 segments. Each team is assigned to a specific segment, depending on the team's number of points. Each of the 5 segments spans one-fifth (20%) of the total points held by the team ranked 1st in the league. For each team, the number of matches played appears in green between brackets, and the number of points is displayed in black.
#
#
#
#
#
#
#
#
#
#
#
# International edition
#
#
#
#
#
#
#
# Among the player statistics, the number of goals scored at home and away by the players at the top of the goal scorers list can be displayed on England - Premier League top scorers
# for the season.
# The Liverpool results and statistical indicators can help provide insights on Liverpool's ranking
# in a variety of tables, for example to check how far the team or other teams are from the league leaders in the table.
# The type of data that can be featured includes the team's league matches and goal scoring indicators such as the average number of goals scored at home or away,
# streaks and sequences of results, offense and defense stats, how Liverpool's record compare with league average values all teams combined, along with form stats such as the
# average points per game in the team's last 8 results in England - Premier League.
#
#
#
#
#
#
#
#
#
#
#
# Follow us on Twitter
#
#
#
#
#
# F.A.Q.
# Contact
# Privacy Policy
#
#
# Change consent
#
#
#
# Terms & conditions of use
# Cookie usage and options
# About us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please note that match schedules and timing are subject to changes. Products, services, promotional offers and other offerings from partners and advertisers are subject to terms and conditions.
# By using this website you certify that you agree with the terms and conditions of use and the privacy policy and that you are over the age of 18 or that you have the permission of a parent or guardian to use this website, after your parent or guardian has carefully reviewed and agreed to the terms and conditions of use and the privacy policy.
# This website is not associated or endorsed by any league (whether professional, collegiate or other types of leagues / competitions), federation, association, club or team.
# All trademarks, brands, images, logos and names appearing on this website belong to their respective owners.
#
#  Useful links (third-party websites):
# GamCare (www.gamcare.org.uk)
# BeGambleAware (www.begambleaware.org)
#
#
#
#
#
#
#
#
#
# Copyright 1998-2021 SoccerSTATS.com
#
#
#
#
#
#
#
#
#
#
#
#
#
# advertisement
#
#
# advertisement

# %%
page = soup.find_all("div",{"class":"name"})
for j in page:
    item = j.find('span')
    text = item.get_text().strip()
    print(text)
# Out:
# Alisson
# Adrian
# Loris
# Caoimhin
# Marcelo
# Virgil
# Ibrahima
# Joe
# Kostas
# Andy
# Joel
# Nathaniel
# Trent
# Neco
# Fabinho
# Thiago
# James
# Naby
# Jordan
# Alex
# Curtis
# Roberto
# Sadio
# Mohamed
# Takumi
# Diogo
# Divock
# Harvey
# Ben
# Rhys
# Sheyi
# Ben
# Sepp

# %%
for pg in soup.find_all(class_="name"):
    print(pg.get_text(strip=True, separator=' '))
# Out:
# Alisson Becker
# Adrian
# Loris Karius
# Caoimhin Kelleher
# Marcelo Pitaluga
# Virgil van Dijk
# Ibrahima Konate
# Joe Gomez
# Kostas Tsimikas
# Andy Robertson
# Joel Matip
# Nathaniel Phillips
# Trent Alexander-Arnold
# Neco Williams
# Fabinho
# Thiago Alcantara
# James Milner
# Naby Keita
# Jordan Henderson
# Alex Oxlade-Chamberlain
# Curtis Jones
# Roberto Firmino
# Sadio Mane
# Mohamed Salah
# Takumi Minamino
# Diogo Jota
# Divock Origi
# Harvey Elliott
# Ben Davies
# Rhys Williams
# Sheyi Ojo
# Ben Woodburn
# Sepp van den Berg

# %%
df = []
page2 = soup.find_all("div", {"class":"postbody"})
for k in page2:
    item2 = k.find('blockquote', class_="postcontent restore")
    post = k.find('span', class_='date')
    post_text = post.get_text().strip()
    text2 = item2.get_text().strip()
    print(post_text)
    print(text2)
    df.append([post_text, text2])
# Out:
# 13-11-21,19:02
# Back in action one week today at Anfield for the visit of Mikel Artetas Arsenal side.
#
# 4th v 5th in the league, which seemed rather unlikely a few weeks ago.
#
# Harvey Elliott, Naby Keita, Roberto Firmino and James Milner are the only definite absentees at this moment. Question marks over Joe Gomez and Curtis Jones.
#
# Game is live on Sky Sports.
# 13-11-21,19:08
# Alisson
#
# Trent
# Matip
# Van Dijk
# Tsimikas
#
# Henderson
# Fabinho
# Thiago
#
# Salah
# Mane
# Jota
# 13-11-21,19:59
# Mane has broken ribs, or back, or sacroiliac doesnt he?
# 14-11-21,09:47
# Originally Posted by FIOS
#
#
# Mane has broken ribs, or back, or sacroiliac doesnt he?
#
#
# Swap Mane for the fan who wins a raffle an hour before kick off.
# 14-11-21,10:10
# So Hendo now has an injury. Jones, Milner, Keita all in doubt. Looks like Fab, Thiago and Ox for Arsenal.
# 14-11-21,10:32
# At this moment the only players unavailable for certain  are Bobby and Elliot. Everyone else have a possibility to be available for selection unless otherwise notified.
#
# Glass is half full, unlike others.
# 14-11-21,11:20
# AnyWinWhereWeScoreThreeGoalsAndConcedeNoneWillDo.
# 14-11-21,11:32
# Originally Posted by Klopp Hopper
#
#
# So Hendo now has an injury. Jones, Milner, Keita all in doubt. Looks like Fab, Thiago and Ox for Arsenal.
#
#
# I very much doubt Henderson is injured, like others have said its probably been agreed he could return after Albania
# 14-11-21,11:39
# Sky just saying that Henderson pulled out of the England squad as a precaution and it's nothing serious.
# 14-11-21,14:02
# Hope we smash these. Arsenal fans getting cocky again.
# 14-11-21,14:12
# Originally Posted by Gegenpressing
#
#
# Hope we smash these. Arsenal fans getting cocky again.
#
#
# Just got to tighten the defence, we WILL score goals, itâs just about how many we concede
# 14-11-21,14:15
# A lot of laughing at Arsenal at the start of the season and now they are a win away from going above us.
# 14-11-21,14:23
# Originally Posted by spider-neil
#
#
# A lot of laughing at Arsenal at the start of the season and now they are a win away from going above us.
#
#
# Good job they wont win then
# 14-11-21,14:25
# Originally Posted by spider-neil
#
#
# A lot of laughing at Arsenal at the start of the season and now they are a win away from going above us.
#
#
# I still think they’re a team that will go on runs but will also go on runs of bad form as well.
# 14-11-21,14:30
# Originally Posted by Gegenpressing
#
#
# I still think theyâre a team that will go on runs but will also go on runs of bad form as well.
#
#
# We are the first top team they have faced since they lost 5-0 to City in August too.
#
# Their fixtures over Christmas are unkind as well.
# 14-11-21,14:31
# Originally Posted by SalahDressing
#
#
# We are the first top team they have faced since they lost 5-0 to City in August too.
#
# Their fixtures over Christmas are unkind as well.
#
#
# Absolutely. They still had to win those games though, I suppose.
# 14-11-21,15:10
# Originally Posted by spider-neil
#
#
# A lot of laughing at Arsenal at the start of the season and now they are a win away from going above us.
#
#
#  Klopp out.
# 15-11-21,00:00
# Originally Posted by SalahDressing
#
#
# We are the first top team they have faced since they lost 5-0 to City in August too.
#
# Their fixtures over Christmas are unkind as well.
#
#
# I'm less bothered about this kind of thing these days - we've dropped points to Brighton and Brentford. It's the Premier League, every match has the potential to be tough - apart from Norwich, maybe!
# 15-11-21,00:08
# Originally Posted by RobertoBaggio94
#
#
# Alisson
#
# Trent
# Matip
# Van Dijk
# Tsimikas
#
# Henderson
# Fabinho
# Thiago
#
# Salah
# Mane
# Jota
#
#
# This, but I think Origi or Minamino might make the team somewhere esp if Hendo/Mane injuries are serious, which seems like they're not.
# 15-11-21,01:12
# Looks like Hendo and Mane are doubts for Arsenal. If so, this is the team surely...
#
#
# Alisson
#
# Arnold - Matip - Virgil - Robbo
#
# Chambo - Fabinho - Thiago
#
# Salah - Origi - Jota
# 15-11-21,10:20
# Play the kids!
# 15-11-21,11:16
# Originally Posted by Alison Becker
#
#
# Looks like Hendo and Mane are doubts for Arsenal. If so, this is the team surely...
#
#
# Alisson
#
# Arnold - Matip - Virgil - Robbo
#
# Chambo - Fabinho - Thiago
#
# Salah - Origi - Jota
#
#
# Wouldnt play Robertson, hes been awful lately, and Id probs play konate over matip, not sure about mane but Id be shocked if Henderson didnt play
# 15-11-21,11:39
# Originally Posted by Redeyes77
#
#
# Wouldnt play Robertson, hes been awful lately, and Id probs play konate over matip, not sure about mane but Id be shocked if Henderson didnt play
#
#
# Agreed. Id loan him out to Aston Villa for the rest of the season along with Jones.
# 15-11-21,11:47
# Originally Posted by Klopp Hopper
#
#
# Agreed. I’d loan him out to Aston Villa for the rest of the season along with Jones.
#
#
# Why Villa?
#
# What's wrong with Norwich?
# 15-11-21,12:00
# Originally Posted by Klopp Hopper
#
#
# Agreed. Id loan him out to Aston Villa for the rest of the season along with Jones.
#
#
# Ha ha nice one
# 15-11-21,15:18
# Originally Posted by kas74
#
#
# Why Villa?
#
# What's wrong with Norwich?
#
#
# Ive got no idea. I just make this **** up. Maybe because of Stevie G?
# 15-11-21,15:36
# Henderson really should be calling time on his international career after the WC.
# 15-11-21,15:49
# Originally Posted by SachaTomek
#
#
# Henderson really should be calling time on his international career after the WC.
#
#
# Ideally for us yes but knowing Hendo hell want to continue on until hes physically unable to draw another breathe of air.
# 15-11-21,15:51
# Originally Posted by XO_OX
#
#
# Ideally for us yes but knowing Hendo he’ll want to continue on until hes physically unable to draw another breathe of air.
#
#
# He shouldn't make the same mistake Gerrard did after 2012.
# 16-11-21,02:01
# Referee: Michael Oliver. Assistants: Stuart Burt, Simon Bennett. Fourth official: Andy Madley. VAR: Chris Kavanagh. Assistant VAR: Sian Massey-Ellis.

# %%
import pandas as pd
df = pd.DataFrame(df)
df.columns = ['date','post']
df[['date', 'time']] = df['date'].str.split(',',expand=True)

# %%
df = df[['date', 'time', 'post']]
df.dtypes
# Out:
# date    object
# time    object
# post    object
# dtype: object

# %%
df['date']= pd.to_datetime(df['date'])
df['time']= pd.to_datetime(df['time'])
df['post']= df['post'].astype(str)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/nqp9stcn0mj7kkyqr_jt__4r0000gn/T/ipykernel_57292/770897825.py in <module>
# ----> 1 df
#       2
#
# NameError: name 'df' is not defined

# %%
df2 = df

# %%
df2['post'] = df2['post'].str.lstrip('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/3p/nqp9stcn0mj7kkyqr_jt__4r0000gn/T/ipykernel_57292/836963292.py in <module>
# ----> 1 df2['post'] = df2['post'].str.lstrip('\n')
#
# NameError: name 'df2' is not defined
